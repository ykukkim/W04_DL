# %% [markdown]
# # Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Libraries

# %%
#Importing Libraries and Packages
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, IterableDataset
from torch.utils.tensorboard import SummaryWriter

# calculate train time, writing train data to files etc.
import os
import logging
import pandas as pd
import numpy as np
import time
from collections import defaultdict
from sklearn.preprocessing import MinMaxScaler
from pathlib import Path
from random import randint
from scipy import signal

import pdb

# %% [markdown]
# # Dataset

# %%
# Data split
class Split_data:

    def __init__(self, dir_path: str, frequency: str, random_seed: str):

        self.directory = dir_path
        self.random_seed = random_seed
        self.frequency = frequency

    def splitset(self, split_ratio, shuffle_dataset=True):
        train_idx = defaultdict(list)
        val_idx = defaultdict(list)
        indices_idx = 0
        ratio_idx = 0
        for root, subdir, files in os.walk(self.directory):
            if "desktop.ini" in files: files.remove('desktop.ini')
            dataset_size = len(files)
            if dataset_size > 0:
                indices = list(range(dataset_size - 1))
                split = int(np.floor(split_ratio[ratio_idx] * len(files)))
                for i in range(self.frequency):
                    if shuffle_dataset:
                        np.random.shuffle(indices)
                    train_idx[indices_idx].append(indices[split:])
                    val_idx[indices_idx].append(indices[:split])
                ratio_idx += 1
                indices_idx += 1

        return train_idx, val_idx

class CoolDataset(IterableDataset):

    def __init__(self, dir_path: str, input_size: str, seq_length: str, samples_per_events: str, indices, trainorval: str,
                 convolution=True):

        super().__init__()
        self.files = tuple(Path(dir_path).glob("**/*.csv"))
        self.indices = indices
        self.seq_length = seq_length
        self.input_size = input_size
        self.SAMPLES_PER_EVENT = samples_per_events
        self.window = signal.gaussian(8, std=3)
        self.convolution = convolution
        self.trainorval  = trainorval
        self.scaler = MinMaxScaler(feature_range=(0,1))

        assert seq_length % 2 == 0, "Please pass an even seq length"

    def __iter__(self):

        # Initialise Counter for events and files
        self.file_nr = 0
        self.event_in_file = 0
        self._sample_nr = 0

        return self

    def __next__(self):
        # Reads the current file and looks for event
        df, fname = self.read_file(self.files[self.indices[self.file_nr]])  # could be cached so you dont read it anew every iteration
        if len(df) >= self.seq_length:
            events = df[df["FO"] == 1]
            if df['class'][0] == 3 and self.trainorval == 'train':
                self.SAMPLES_PER_EVENT = 4

            if events.shape[0] > 0:

                if self._sample_nr < self.SAMPLES_PER_EVENT:
                    # just give back the current event again, with different sampling, until we have generated
                    # SAMPLES_PER_EVENT such samples
                    event_frame = events.iloc[self.event_in_file].name
                    input_data, output_data = self.sample_seq_around_event_frame(df, event_frame)
                    self._sample_nr += 1

                elif self._sample_nr == self.SAMPLES_PER_EVENT:

                    self.event_in_file += 1  # work on the next event in this file
                    self._sample_nr = 0  # reset for the next event

                    # check whether we are done with this file
                    # otherwise we return the next event on the beginning of the next iteration
                    if self.event_in_file >= len(events):
                        self.file_nr += 1
                        # If there still are files to run, it resets the variables
                        if self.file_nr < len(self.indices):
                            logging.info("File is complete. Going to new file...")
                            self.event_in_file = 0
                            self._sample_nr = 0
                            return next(self)
                        else:
                            # processed the last file, we are done
                            logging.info("File is complete. All files done. Stopping...")
                            raise StopIteration
                    elif self.event_in_file < len(events):
                        event_frame = events.iloc[self.event_in_file].name
                        input_data, output_data = self.sample_seq_around_event_frame(df, event_frame)
                        self._sample_nr += 1

            else:
                logging.info("No events detected")
                self.file_nr += 1
                self.event_in_file = 0
                self._sample_nr = 0
                return next(self)

        else:
            logging.info("data length is too short")
            self.file_nr += 1
            self.event_in_file = 0
            self._sample_nr = 0
            return next(self)
        return input_data, output_data

    def sample_seq_around_event_frame(self, df, event_idx):
        if event_idx >= 4:
            start_idx = event_idx - randint(4, self.seq_length / 7.5)
            if start_idx > 0:
                end_idx = start_idx + self.seq_length
                if end_idx <= len(df):
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
                elif end_idx > len(df):
                    end_idx = len(df)
                    start_idx = end_idx - self.seq_length
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
            elif start_idx <= 4:
                start_idx = event_idx
                end_idx = start_idx + self.seq_length
                input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                output = df.iloc[start_idx:end_idx]['FO']
                if end_idx <= len(df):
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
                elif end_idx > len(df):
                    end_idx = len(df)
                    start_idx = end_idx - self.seq_length
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']

        if self.convolution:
            output = signal.convolve(output, self.window, mode='same')
        #  Standardising the input
        input = self.scaler.fit_transform(input)
        
        assert input.shape[0] == output.shape[0] == self.seq_length
        return torch.tensor(input), torch.tensor(output)

    def read_file(self, f):
        df = pd.read_csv(open(f, "r"))
        fname = os.path.basename(f)
        if fname[0:2] == 'RT':
            df = df.drop(['ID',
                          # 'class',
                          #'RTOE_X', 'RTOE_Y', 'RTOE_Z', 'V_RTOE_X', 'V_RTOE_Y', 'V_RTOE_Z',
                          #'RHLX_X', 'RHLX_Y', 'RHLX_Z', 'V_RHLX_X', 'V_RHLX_Y', 'V_RHLX_Z',
                          #'RHEE_X', 'RHEE_Y', 'RHEE_Z', 'V_RHEE_X', 'V_RHEE_Y', 'V_RHEE_Z',
                          'RPMT5_X', 'RPMT5_Y', 'RPMT5_Z', 'V_RPMT5_X', 'V_RPMT5_Y', 'V_RPMT5_Z'
                          ], axis=1)
        elif fname[0:2] == 'LT':
            df = df.drop(['ID',
                          # 'class',
                          #'LTOE_X', 'LTOE_Y', 'LTOE_Z', 'V_LTOE_X', 'V_LTOE_Y', 'V_LTOE_Z',
                          #'LHLX_X', 'LHLX_Y', 'LHLX_Z', 'V_LHLX_X', 'V_LHLX_Y', 'V_LHLX_Z',
                          #'LHEE_X', 'LHEE_Y', 'LHEE_Z', 'V_LHEE_X', 'V_LHEE_Y', 'V_LHEE_Z',
                          'LPMT5_X', 'LPMT5_Y', 'LPMT5_Z', 'V_LPMT5_X', 'V_LPMT5_Y', 'V_LPMT5_Z',
                          ], axis=1)
        return df, fname

# %% [markdown]
# # Model

# %%
class Network(nn.Module):
    # TO DO
    def __init__(self, config,hidden_size,num_layers,drop_out):
        super(Network, self).__init__()

        # Model construct Configuration
        self.batch_size  = config.batch_size
        self.num_layers  = num_layers
        self.hidden_size = hidden_size
        self.device      = config.device

        self.lstm = nn.LSTM(config.input_size, hidden_size, num_layers, dropout=drop_out, batch_first=True,
                            bidirectional=True)
        self.linear = nn.Linear(hidden_size * 2, config.output_size, bias=True)
        torch.nn.init.xavier_uniform_(self.linear.weight)

    def forward(self, x):
        hidden, cell = self.init_hidden()
        out, _ = self.lstm(x, (hidden, cell))
        logits = self.linear(out)

        return logits[:, :, -1]

    def init_hidden(self):
        weight = next((self.parameters())).data
        hidden, cell = (weight.new(self.num_layers * 2, self.batch_size, self.hidden_size).zero_().to(self.device),
                        weight.new(self.num_layers * 2, self.batch_size, self.hidden_size).zero_().to(self.device))
        return hidden, cell

# %% [markdown]
# # Early Stop

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""

    # def __init__(self, patience: str,, delta: str, Name: str, verbose=False):
    def __init__(self, config, patience: str, delta: str, Name: str, verbose=False, ):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path_dir = config.isdirectory_result
        self.type_ICTO = config.type_ICTO
        self.noofmarkers = config.noofmarkers
        self.combination = config.combination
        self.name = Name

    def __call__(self, val_loss, TPR_CP, TNR_CP, model, config,name):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

            ROC = pd.DataFrame({'TPR_MF': pd.Series(TPR_CP[0]), 'TNR_MF': pd.Series(TNR_CP[0]),
                                'TPR_FF': pd.Series(TPR_CP[1]), 'TNR_FF': pd.Series(TNR_CP[1]),
                                'TPR_HS': pd.Series(TPR_CP[2]), 'TNR_HS': pd.Series(TNR_CP[2])})
            isExist_csv = os.path.exists(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/")
            if not isExist_csv:
              os.makedirs(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/")
            # csv file save
            ROC.to_csv(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/{name}-ROC.csv",index=False)

        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}\n')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0
            ROC = pd.DataFrame({'TPR_MF': pd.Series(TPR_CP[0]), 'TNR_MF': pd.Series(TNR_CP[0]),
                                'TPR_FF': pd.Series(TPR_CP[1]), 'TNR_FF': pd.Series(TNR_CP[1]),
                                'TPR_HS': pd.Series(TPR_CP[2]), 'TNR_HS': pd.Series(TNR_CP[2])})

            ROC.to_csv(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/{name}-ROC.csv", mode='a', header=False, index=False)

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        filepath = f"{self.path_dir}/{self.type_ICTO}/{self.noofmarkers}/{self.combination}/v1/models/CheckPoint/"
        isExist = os.path.exists(filepath)
        if not isExist:
            os.makedirs(filepath)
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model\n')
            torch.save(model.state_dict(), os.path.join(filepath, f"{self.name}-FOcheckpoint.pt"), _use_new_zipfile_serialization=False)

        self.val_loss_min = val_loss

# %% [markdown]
# # Training and Validation

# %%
 class Trainer:

    def __init__(self, hidden_size, num_layers, drop_out, lr, epochs, config):

        # System configuration
        self.validation_split = config.validation_split
        self.log_interval = config.log_interval
        self.isdirectory = config.isdirectory
        self.device = config.device
        self.seed = config.seed

        # Model Construction
        self.input_size = config.input_size
        self.batch_size = config.batch_size
        self.seq_length = config.seq_length
        self.samples_per_event = config.samples_per_event
        self.lr = lr

        self.model = Network(config, hidden_size, num_layers, drop_out).to(self.device)
        self.model = self.model.to(self.device)
        print(self.model)

        # Optimizer and Loss
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.BCEWithLogitsLoss(pos_weight=config.weight_factor).to(self.device)

        # Initialise the early_stopping object
        self.name = f"TO-{hidden_size}-HS-{num_layers}-NL-{lr}-LR-{drop_out}-DO"
        self.early_stopping = EarlyStopping(config, patience=model_config.patience, verbose=True,
                                            delta=model_config.delta, Name=self.name)
        print(self.name)

        # DataLoader
        dataset = Split_data(self.isdirectory, epochs, torch.manual_seed(self.seed))
        self.train_idx, self.val_idx = dataset.splitset(self.validation_split)
        self.train_loader = defaultdict(list)
        self.val_loader = defaultdict(list)

        # Tensorboard
        self.globaliter = 0
        train_log_dir = f"{config.isdirectory_result}/logs/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/train/" + self.name
        val_log_dir = f"{config.isdirectory_result}/logs/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/val/" + self.name
        self.train_summary_writer = SummaryWriter(train_log_dir)
        self.val_summary_writer = SummaryWriter(val_log_dir)

    def train(self, epoch):

        self.model.train()
        TPR_internal_final = defaultdict(list)
        TNR_internal_final = defaultdict(list)
        loss_final = defaultdict(list)
        start_train = time.time()
        subdir_idx = 0
        with self.train_summary_writer:
            for root, subdir, files in os.walk(self.isdirectory):
                if "desktop.ini" in files: files.remove('desktop.ini')
                if len(files) > 0:
                    train_loader = DataLoader(
                        CoolDataset(root, self.input_size, self.seq_length, self.samples_per_event,
                                    self.train_idx[subdir_idx][epoch], 'train'), batch_size=self.batch_size,
                        drop_last=True, shuffle=False)
                    for batch_idx, (data, target) in enumerate(train_loader):
                        self.optimizer.zero_grad()
                        data, target = data.to(self.device), target.to(self.device)
                        predictions = self.model(data.float()).to(self.device)
                        loss = self.criterion(predictions.float(), target.float())
                        loss.backward()

                        self.optimizer.step()
                        pred = torch.sigmoid(predictions.detach())
                        correct_indx_positive = pred[target > 0.5]  # Should have batch_size * 1's
                        correct_indx_negative = pred[target <= 0.5]  # Should have (batch_size*seq_length-batch_size) * 0'

                        TPR_internal = len(correct_indx_positive[correct_indx_positive > 0.5]) / len(
                            correct_indx_positive)
                        TNR_internal = len(correct_indx_negative[correct_indx_negative <= 0.5]) / len(
                            correct_indx_negative)
                        TPR_internal = TPR_internal * 100
                        TNR_internal = TNR_internal * 100

                        TPR_internal_final[subdir_idx].append(TPR_internal)
                        TNR_internal_final[subdir_idx].append(TNR_internal)
                        loss_final[subdir_idx].append(loss.item())

                        self.globaliter += 1

                        if batch_idx % self.log_interval == 0:
                            self.train_summary_writer.add_scalar('Loss', loss.item(), self.globaliter)
                    subdir_idx += 1

            return loss_final, TPR_internal_final, TNR_internal_final, (time.time() - start_train)

    def val(self, epoch):
        self.model.eval()
        TPR_internal_final_val = defaultdict(list)
        TNR_internal_final_val = defaultdict(list)
        val_loss_final = defaultdict(list)
        start_time_val = time.time()
        subdir_idx_val = 0

        with self.val_summary_writer:
            with torch.no_grad():
                for root, subdir, files in os.walk(self.isdirectory):
                    if "desktop.ini" in files: files.remove('desktop.ini')
                    if len(files) > 0:
                        val_loader = DataLoader(
                            CoolDataset(root, self.input_size, self.seq_length, self.samples_per_event,
                                        self.val_idx[subdir_idx_val][epoch], 'val'), batch_size=self.batch_size,
                            drop_last=True, shuffle=False)
                        for batch_idx, (data, target) in enumerate(val_loader):
                            data, target = data.to(self.device), target.to(self.device)
                            predictions = self.model(data.float())
                            val_loss = self.criterion(predictions.float(), target.float())
                            pred = torch.sigmoid(predictions.detach())

                            correct_indx_positive = pred[target > 0.5]  # Should have batch_size * 1's
                            correct_indx_negative = pred[
                                target <= 0.5]  # Should have (batch_size*seq_length-batch_size) * 0'
                            TPR_internal_val = len(correct_indx_positive[correct_indx_positive > 0.5]) / len(
                                correct_indx_positive)
                            TNR_internal_val = len(correct_indx_negative[correct_indx_negative <= 0.5]) / len(
                                correct_indx_negative)
                            TPR_internal_val = TPR_internal_val * 100
                            TNR_internal_val = TNR_internal_val * 100

                            TPR_internal_final_val[subdir_idx_val].append(TPR_internal_val)
                            TNR_internal_final_val[subdir_idx_val].append(TNR_internal_val)
                            val_loss_final[subdir_idx_val].append(val_loss.item())

                        self.val_summary_writer.add_scalar('val_loss', val_loss.item(), self.globaliter)
                        subdir_idx_val += 1
                return val_loss_final, TPR_internal_final_val, TNR_internal_final_val, (
                                    time.time() - start_time_val), self.name

# %% [markdown]
# # Hyperparmeter Setting

# %%
def main(hparam, model_config):
    for lr in hparam['lr']:
        for hidden_size in hparam['hidden_size']:
            for num_layers in hparam['num_layers']:
                for drop_out in hparam['drop_out']:
                    for epochs in hparam['epochs']:
                        trainer = Trainer(hidden_size, num_layers, drop_out, lr, epochs, model_config)
                        TPR = dict()
                        TNR = dict()
                        for epoch in range(epochs):
                            loss_train, TPR_train, TNR_train, train_time = trainer.train(epoch)
                            print('\nEpoch: {}\n'
                                  'Loss_MF: {:.6f}\tTPR_MF: {:.2f}\tTNR_MF: {:.2f}\n'
                                  'Loss_FF: {:.6f}\tTPR_FF: {:.2f}\tTNR_FF: {:.2f}\n'
                                  'Loss_HS: {:.6f}\tTPR_HS: {:.2f}\tTNR_HS: {:.2f}\n'
                                  'LossALL: {:.6f}\tTPRALL: {:.2f}\tTNRALL: {:.2f}\n''Time: {:.2f} '.format(epoch, np.mean(loss_train[0]), np.median(TPR_train[0]),np.median(TNR_train[0]),
                                                                                                           np.mean(loss_train[1]), np.median(TPR_train[1]), np.median(TNR_train[1]),
                                                                                                           np.mean(loss_train[2]), np.median(TPR_train[2]),np.median(TNR_train[2]),
                                                                                                           np.mean(loss_train[0]+loss_train[1]+loss_train[2]),np.median(TPR_train[0]+TPR_train[1]+TPR_train[2]),np.median(TNR_train[0]+TNR_train[1]+TNR_train[2]),
                                                                                                           train_time))

                            val_loss, TPR[epoch], TNR[epoch], val_time, name = trainer.val(epoch)
                            print('\nEpoch:{}\n'
                                  'ValLoss_MF: {:.6f}\tTPR_MF: {:.2f}\tTNR_MF: {:.2f}\n'
                                  'ValLoss_FF: {:.6f}\tTPR_FF: {:.2f}\tTNR_FF: {:.2f}\n'
                                  'ValLoss_HS: {:.6f}\tTPR_HS: {:.2f}\tTNR_HS: {:.2f}\n'
                                  'ValLossALL: {:.6f}\tTPRALL: {:.2f}\tTNRALL: {:.2f}\n''Time: {:.2f} '.format(epoch, np.mean(val_loss[0]), np.median(TPR[epoch][0]),np.median(TNR[epoch][0]),
                                                                                                           np.mean(val_loss[1]), np.median(TPR[epoch][1]), np.median(TNR[epoch][1]),
                                                                                                           np.mean(val_loss[2]), np.median(TPR[epoch][2]),np.median(TNR[epoch][2]),
                                                                                                           np.mean(val_loss[0]+val_loss[1]+val_loss[2]), np.median(TPR[epoch][0]+TPR[epoch][1]+TPR[epoch][2]),np.median(TNR[epoch][0]+TNR[epoch][1]+TNR[epoch][2]),
                                                                                                           val_time))
                            trainer.early_stopping(np.mean(val_loss[0]+val_loss[1]+val_loss[2]), TPR[epoch], TNR[epoch], trainer.model, model_config,name)
                            if trainer.early_stopping.early_stop:
                                print("Early stopping")
                                break

# %% [markdown]
# # Main

# %%
 class Config:

    def __init__(self, **kwargs):
        for key, value in kwargs.items():
            setattr(self, key, value)

if __name__ == '__main__':

    if torch.cuda.is_available():
        device = torch.device("cuda")
        print("Running on the GPU")
    else:
        device = torch.device("cpu")
        print("Running on the CPU")

    model_config = Config(
        device=device,
        # Early Stop
        patience=20,
        delta=0.01,
        log_interval=100,
        # Dataset Configuration
        validation_split=[0.075, 0.25, 0.065],
        seed=253,
        samples_per_event=1,
        output_size=1,
        # Weight factor
        weight_factor=torch.tensor(11),
        # Directory
        isdirectory        = r"/content/drive/MyDrive/Deep_learning/Deep Learning/Data/iteration3/Train",
        isdirectory_result = r"/content/drive/MyDrive/Deep_learning/Deep Learning/Results/LSTM",
        type_ICTO          = r"TO",
        noofmarkers        = r"3markers",
        combination        = r"HLXTOE5HEE",
        # Model Consturction
        input_size=18,
        batch_size=64,
        seq_length=150,
    )

    hparam = {
        'hidden_size': [256,512,1024],
        'num_layers': [2,5,10],
        'drop_out': [0.3],
        'lr': [0.001],
        'epochs': [150],
    }

    main(hparam, model_config)
# Out:
# Streaming output truncated to the last 5000 lines.
# Time: 3.73
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.209295	TPR_MF: 95.09	TNR_MF: 95.56
# Loss_FF: 0.313490	TPR_FF: 93.58	TNR_FF: 94.85
# Loss_HS: 0.216108	TPR_HS: 95.92	TNR_HS: 95.22
# LossALL: 0.247174	TPRALL: 94.82	TNRALL: 95.26
# Time: 59.77
#
# Epoch:11
# ValLoss_MF: 0.206035	TPR_MF: 92.90	TNR_MF: 96.83
# ValLoss_FF: 0.296820	TPR_FF: 89.34	TNR_FF: 96.25
# ValLoss_HS: 0.158931	TPR_HS: 96.70	TNR_HS: 96.89
# ValLossALL: 0.220596	TPRALL: 92.90	TNRALL: 96.83
# Time: 3.47
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.200748	TPR_MF: 96.42	TNR_MF: 95.42
# Loss_FF: 0.324759	TPR_FF: 91.92	TNR_FF: 94.43
# Loss_HS: 0.191485	TPR_HS: 95.96	TNR_HS: 96.40
# LossALL: 0.240370	TPRALL: 95.86	TNRALL: 95.79
# Time: 59.07
#
# Epoch:12
# ValLoss_MF: 0.193903	TPR_MF: 94.15	TNR_MF: 96.45
# ValLoss_FF: 0.345059	TPR_FF: 86.28	TNR_FF: 95.70
# ValLoss_HS: 0.231200	TPR_HS: 93.36	TNR_HS: 96.40
# ValLossALL: 0.256721	TPRALL: 93.36	TNRALL: 96.40
# Time: 3.79
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.198386	TPR_MF: 95.35	TNR_MF: 95.85
# Loss_FF: 0.328195	TPR_FF: 91.85	TNR_FF: 95.10
# Loss_HS: 0.188097	TPR_HS: 96.24	TNR_HS: 96.74
# LossALL: 0.238611	TPRALL: 94.96	TNRALL: 95.93
# Time: 60.20
#
# Epoch:13
# ValLoss_MF: 0.213044	TPR_MF: 94.55	TNR_MF: 96.50
# ValLoss_FF: 0.281354	TPR_FF: 88.59	TNR_FF: 95.97
# ValLoss_HS: 0.171203	TPR_HS: 96.02	TNR_HS: 96.73
# ValLossALL: 0.221867	TPRALL: 94.55	TNRALL: 96.50
# Time: 3.70
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.203950	TPR_MF: 95.01	TNR_MF: 95.89
# Loss_FF: 0.313462	TPR_FF: 95.28	TNR_FF: 94.66
# Loss_HS: 0.185466	TPR_HS: 96.07	TNR_HS: 96.57
# LossALL: 0.235154	TPRALL: 95.51	TNRALL: 95.89
# Time: 60.15
#
# Epoch:14
# ValLoss_MF: 0.165421	TPR_MF: 95.93	TNR_MF: 96.45
# ValLoss_FF: 0.349490	TPR_FF: 85.84	TNR_FF: 95.62
# ValLoss_HS: 0.171175	TPR_HS: 96.96	TNR_HS: 96.29
# ValLossALL: 0.228695	TPRALL: 95.93	TNRALL: 96.29
# Time: 3.83
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 15
# Loss_MF: 0.193779	TPR_MF: 95.41	TNR_MF: 95.96
# Loss_FF: 0.318901	TPR_FF: 89.66	TNR_FF: 95.09
# Loss_HS: 0.184974	TPR_HS: 96.51	TNR_HS: 96.62
# LossALL: 0.233954	TPRALL: 95.37	TNRALL: 95.91
# Time: 60.17
#
# Epoch:15
# ValLoss_MF: 0.241541	TPR_MF: 90.00	TNR_MF: 96.18
# ValLoss_FF: 0.234682	TPR_FF: 92.35	TNR_FF: 95.99
# ValLoss_HS: 0.147634	TPR_HS: 98.69	TNR_HS: 96.44
# ValLossALL: 0.207952	TPRALL: 92.35	TNRALL: 96.18
# Time: 3.66
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 16
# Loss_MF: 0.190677	TPR_MF: 95.77	TNR_MF: 96.16
# Loss_FF: 0.295408	TPR_FF: 93.94	TNR_FF: 95.19
# Loss_HS: 0.181140	TPR_HS: 96.34	TNR_HS: 96.82
# LossALL: 0.222852	TPRALL: 95.33	TNRALL: 96.15
# Time: 60.09
#
# Epoch:16
# ValLoss_MF: 0.183076	TPR_MF: 95.46	TNR_MF: 96.28
# ValLoss_FF: 0.322751	TPR_FF: 90.00	TNR_FF: 95.41
# ValLoss_HS: 0.150014	TPR_HS: 98.17	TNR_HS: 96.44
# ValLossALL: 0.218614	TPRALL: 95.46	TNRALL: 96.28
# Time: 3.60
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 17
# Loss_MF: 0.193262	TPR_MF: 95.42	TNR_MF: 95.68
# Loss_FF: 0.321314	TPR_FF: 92.50	TNR_FF: 95.09
# Loss_HS: 0.191571	TPR_HS: 96.03	TNR_HS: 96.49
# LossALL: 0.237067	TPRALL: 95.31	TNRALL: 95.87
# Time: 59.81
#
# Epoch:17
# ValLoss_MF: 0.211839	TPR_MF: 93.57	TNR_MF: 96.19
# ValLoss_FF: 0.254575	TPR_FF: 87.95	TNR_FF: 95.81
# ValLoss_HS: 0.162032	TPR_HS: 97.16	TNR_HS: 96.46
# ValLossALL: 0.209482	TPRALL: 93.57	TNRALL: 96.19
# Time: 3.64
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 18
# Loss_MF: 0.198745	TPR_MF: 95.52	TNR_MF: 95.77
# Loss_FF: 0.282499	TPR_FF: 94.73	TNR_FF: 95.42
# Loss_HS: 0.178838	TPR_HS: 96.68	TNR_HS: 96.77
# LossALL: 0.220055	TPRALL: 95.42	TNRALL: 95.90
# Time: 60.10
#
# Epoch:18
# ValLoss_MF: 0.166979	TPR_MF: 97.58	TNR_MF: 96.11
# ValLoss_FF: 0.377248	TPR_FF: 86.97	TNR_FF: 95.15
# ValLoss_HS: 0.213063	TPR_HS: 95.64	TNR_HS: 96.53
# ValLossALL: 0.252430	TPRALL: 95.64	TNRALL: 96.11
# Time: 3.58
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.190256	TPR_MF: 96.01	TNR_MF: 96.01
# Loss_FF: 0.274562	TPR_FF: 95.40	TNR_FF: 95.48
# Loss_HS: 0.173568	TPR_HS: 95.64	TNR_HS: 96.91
# LossALL: 0.212912	TPRALL: 95.73	TNRALL: 96.24
# Time: 59.69
#
# Epoch:19
# ValLoss_MF: 0.167965	TPR_MF: 94.67	TNR_MF: 96.79
# ValLoss_FF: 0.286962	TPR_FF: 88.10	TNR_FF: 96.06
# ValLoss_HS: 0.175715	TPR_HS: 96.06	TNR_HS: 97.00
# ValLossALL: 0.210214	TPRALL: 94.67	TNRALL: 96.79
# Time: 3.63
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.196385	TPR_MF: 96.23	TNR_MF: 95.29
# Loss_FF: 0.301718	TPR_FF: 93.58	TNR_FF: 95.28
# Loss_HS: 0.185761	TPR_HS: 96.36	TNR_HS: 96.65
# LossALL: 0.229027	TPRALL: 95.77	TNRALL: 95.87
# Time: 59.18
#
# Epoch:20
# ValLoss_MF: 0.204281	TPR_MF: 92.38	TNR_MF: 96.54
# ValLoss_FF: 0.301163	TPR_FF: 88.36	TNR_FF: 95.82
# ValLoss_HS: 0.135436	TPR_HS: 99.63	TNR_HS: 96.78
# ValLossALL: 0.213627	TPRALL: 92.38	TNRALL: 96.54
# Time: 3.65
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.193628	TPR_MF: 96.02	TNR_MF: 95.96
# Loss_FF: 0.277607	TPR_FF: 93.88	TNR_FF: 95.59
# Loss_HS: 0.200589	TPR_HS: 95.54	TNR_HS: 96.47
# LossALL: 0.225321	TPRALL: 94.85	TNRALL: 95.66
# Time: 59.23
#
# Epoch:21
# ValLoss_MF: 0.208970	TPR_MF: 92.81	TNR_MF: 96.33
# ValLoss_FF: 0.381070	TPR_FF: 84.82	TNR_FF: 96.40
# ValLoss_HS: 0.179760	TPR_HS: 94.82	TNR_HS: 96.98
# ValLossALL: 0.256600	TPRALL: 92.81	TNRALL: 96.40
# Time: 3.65
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.198370	TPR_MF: 95.12	TNR_MF: 96.06
# Loss_FF: 0.313469	TPR_FF: 92.67	TNR_FF: 95.31
# Loss_HS: 0.177803	TPR_HS: 95.82	TNR_HS: 96.76
# LossALL: 0.230747	TPRALL: 95.12	TNRALL: 96.32
# Time: 59.32
#
# Epoch:22
# ValLoss_MF: 0.163940	TPR_MF: 96.55	TNR_MF: 96.64
# ValLoss_FF: 0.222721	TPR_FF: 92.64	TNR_FF: 95.95
# ValLoss_HS: 0.228679	TPR_HS: 93.42	TNR_HS: 96.75
# ValLossALL: 0.205114	TPRALL: 93.42	TNRALL: 96.64
# Time: 3.79
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.191077	TPR_MF: 95.99	TNR_MF: 95.92
# Loss_FF: 0.228994	TPR_FF: 94.49	TNR_FF: 95.98
# Loss_HS: 0.178282	TPR_HS: 95.82	TNR_HS: 96.79
# LossALL: 0.199107	TPRALL: 95.68	TNRALL: 96.21
# Time: 59.83
#
# Epoch:23
# ValLoss_MF: 0.160397	TPR_MF: 97.57	TNR_MF: 96.35
# ValLoss_FF: 0.624636	TPR_FF: 78.97	TNR_FF: 95.08
# ValLoss_HS: 0.173106	TPR_HS: 96.04	TNR_HS: 96.51
# ValLossALL: 0.319380	TPRALL: 96.04	TNRALL: 96.35
# Time: 3.74
# EarlyStopping counter: 20 out of 20
#
# Early stopping
# Network(
#   (lstm): LSTM(18, 512, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear): Linear(in_features=1024, out_features=1, bias=True)
# )
# TO-512-HS-2-NL-0.001-LR-0.3-DO
#
# Epoch: 0
# Loss_MF: 0.680119	TPR_MF: 89.74	TNR_MF: 80.58
# Loss_FF: 0.470659	TPR_FF: 89.44	TNR_FF: 90.24
# Loss_HS: 0.228103	TPR_HS: 94.35	TNR_HS: 95.84
# LossALL: 0.441403	TPRALL: 92.65	TNRALL: 92.54
# Time: 44.94
#
# Epoch:0
# ValLoss_MF: 0.236133	TPR_MF: 88.32	TNR_MF: 96.09
# ValLoss_FF: 0.433078	TPR_FF: 80.11	TNR_FF: 95.34
# ValLoss_HS: 0.191233	TPR_HS: 94.60	TNR_HS: 96.12
# ValLossALL: 0.286814	TPRALL: 88.32	TNRALL: 96.09
# Time: 3.53
# Validation loss decreased (inf --> 0.286814).  Saving model
#
#
# Epoch: 1
# Loss_MF: 0.224702	TPR_MF: 93.89	TNR_MF: 95.52
# Loss_FF: 0.379724	TPR_FF: 88.46	TNR_FF: 93.89
# Loss_HS: 0.211439	TPR_HS: 93.40	TNR_HS: 96.29
# LossALL: 0.273613	TPRALL: 93.33	TNRALL: 95.25
# Time: 44.51
#
# Epoch:1
# ValLoss_MF: 0.248880	TPR_MF: 89.91	TNR_MF: 96.48
# ValLoss_FF: 0.317029	TPR_FF: 86.02	TNR_FF: 95.84
# ValLoss_HS: 0.161086	TPR_HS: 96.27	TNR_HS: 96.89
# ValLossALL: 0.242332	TPRALL: 89.91	TNRALL: 96.48
# Time: 3.56
# Validation loss decreased (0.286814 --> 0.242332).  Saving model
#
#
# Epoch: 2
# Loss_MF: 0.218348	TPR_MF: 94.04	TNR_MF: 95.84
# Loss_FF: 0.318769	TPR_FF: 92.05	TNR_FF: 94.06
# Loss_HS: 0.195235	TPR_HS: 95.85	TNR_HS: 96.67
# LossALL: 0.244697	TPRALL: 94.06	TNRALL: 95.80
# Time: 44.78
#
# Epoch:2
# ValLoss_MF: 0.171853	TPR_MF: 93.93	TNR_MF: 96.99
# ValLoss_FF: 0.331713	TPR_FF: 85.28	TNR_FF: 96.51
# ValLoss_HS: 0.165555	TPR_HS: 93.89	TNR_HS: 96.96
# ValLossALL: 0.223041	TPRALL: 93.89	TNRALL: 96.96
# Time: 3.49
# Validation loss decreased (0.242332 --> 0.223041).  Saving model
#
#
# Epoch: 3
# Loss_MF: 0.210822	TPR_MF: 95.70	TNR_MF: 95.16
# Loss_FF: 0.296757	TPR_FF: 94.51	TNR_FF: 94.59
# Loss_HS: 0.185217	TPR_HS: 95.38	TNR_HS: 96.58
# LossALL: 0.230822	TPRALL: 94.91	TNRALL: 95.66
# Time: 44.87
#
# Epoch:3
# ValLoss_MF: 0.257244	TPR_MF: 86.87	TNR_MF: 97.07
# ValLoss_FF: 0.305872	TPR_FF: 85.46	TNR_FF: 96.48
# ValLoss_HS: 0.150358	TPR_HS: 93.64	TNR_HS: 97.57
# ValLossALL: 0.237825	TPRALL: 86.87	TNRALL: 97.07
# Time: 3.44
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 4
# Loss_MF: 0.261294	TPR_MF: 95.12	TNR_MF: 95.39
# Loss_FF: 0.318329	TPR_FF: 91.67	TNR_FF: 94.26
# Loss_HS: 0.193769	TPR_HS: 95.60	TNR_HS: 96.82
# LossALL: 0.255149	TPRALL: 95.03	TNRALL: 95.44
# Time: 44.68
#
# Epoch:4
# ValLoss_MF: 0.231205	TPR_MF: 89.78	TNR_MF: 96.89
# ValLoss_FF: 0.327632	TPR_FF: 84.84	TNR_FF: 96.45
# ValLoss_HS: 0.222823	TPR_HS: 90.65	TNR_HS: 97.23
# ValLossALL: 0.260553	TPRALL: 89.78	TNRALL: 96.89
# Time: 3.39
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 5
# Loss_MF: 0.207508	TPR_MF: 93.67	TNR_MF: 96.20
# Loss_FF: 0.343333	TPR_FF: 90.79	TNR_FF: 93.89
# Loss_HS: 0.186623	TPR_HS: 95.54	TNR_HS: 96.80
# LossALL: 0.246959	TPRALL: 93.93	TNRALL: 96.12
# Time: 44.64
#
# Epoch:5
# ValLoss_MF: 0.168459	TPR_MF: 94.08	TNR_MF: 97.04
# ValLoss_FF: 0.207872	TPR_FF: 91.14	TNR_FF: 96.78
# ValLoss_HS: 0.183741	TPR_HS: 93.84	TNR_HS: 97.09
# ValLossALL: 0.186691	TPRALL: 93.84	TNRALL: 97.04
# Time: 3.45
# Validation loss decreased (0.223041 --> 0.186691).  Saving model
#
#
# Epoch: 6
# Loss_MF: 0.209220	TPR_MF: 94.63	TNR_MF: 95.88
# Loss_FF: 0.317183	TPR_FF: 93.41	TNR_FF: 94.07
# Loss_HS: 0.188780	TPR_HS: 96.87	TNR_HS: 96.34
# LossALL: 0.239168	TPRALL: 95.05	TNRALL: 95.65
# Time: 44.95
#
# Epoch:6
# ValLoss_MF: 0.214066	TPR_MF: 92.54	TNR_MF: 96.11
# ValLoss_FF: 0.311909	TPR_FF: 85.30	TNR_FF: 95.45
# ValLoss_HS: 0.143706	TPR_HS: 99.09	TNR_HS: 96.50
# ValLossALL: 0.223227	TPRALL: 92.54	TNRALL: 96.11
# Time: 3.55
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 7
# Loss_MF: 0.201943	TPR_MF: 94.13	TNR_MF: 96.19
# Loss_FF: 0.313062	TPR_FF: 90.21	TNR_FF: 94.20
# Loss_HS: 0.181086	TPR_HS: 96.71	TNR_HS: 96.46
# LossALL: 0.231798	TPRALL: 94.91	TNRALL: 95.94
# Time: 45.09
#
# Epoch:7
# ValLoss_MF: 0.174907	TPR_MF: 95.33	TNR_MF: 96.74
# ValLoss_FF: 0.192386	TPR_FF: 93.30	TNR_FF: 96.63
# ValLoss_HS: 0.192462	TPR_HS: 95.33	TNR_HS: 96.76
# ValLossALL: 0.186585	TPRALL: 95.33	TNRALL: 96.74
# Time: 3.55
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 8
# Loss_MF: 0.206970	TPR_MF: 95.39	TNR_MF: 96.02
# Loss_FF: 0.300446	TPR_FF: 90.89	TNR_FF: 94.53
# Loss_HS: 0.194940	TPR_HS: 95.82	TNR_HS: 96.06
# LossALL: 0.234180	TPRALL: 94.08	TNRALL: 95.67
# Time: 45.23
#
# Epoch:8
# ValLoss_MF: 0.180356	TPR_MF: 96.46	TNR_MF: 95.96
# ValLoss_FF: 0.217418	TPR_FF: 94.98	TNR_FF: 95.63
# ValLoss_HS: 0.166676	TPR_HS: 97.45	TNR_HS: 96.07
# ValLossALL: 0.188150	TPRALL: 96.46	TNRALL: 95.96
# Time: 3.48
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 9
# Loss_MF: 0.193408	TPR_MF: 95.10	TNR_MF: 95.90
# Loss_FF: 0.292683	TPR_FF: 91.46	TNR_FF: 94.88
# Loss_HS: 0.175882	TPR_HS: 96.20	TNR_HS: 96.46
# LossALL: 0.220852	TPRALL: 95.41	TNRALL: 95.92
# Time: 45.05
#
# Epoch:9
# ValLoss_MF: 0.273781	TPR_MF: 87.70	TNR_MF: 96.37
# ValLoss_FF: 0.254069	TPR_FF: 91.36	TNR_FF: 96.63
# ValLoss_HS: 0.162402	TPR_HS: 95.77	TNR_HS: 96.83
# ValLossALL: 0.230084	TPRALL: 91.36	TNRALL: 96.63
# Time: 3.52
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 10
# Loss_MF: 0.191286	TPR_MF: 94.82	TNR_MF: 95.84
# Loss_FF: 0.254271	TPR_FF: 91.51	TNR_FF: 95.17
# Loss_HS: 0.188158	TPR_HS: 95.68	TNR_HS: 96.52
# LossALL: 0.211116	TPRALL: 94.82	TNRALL: 95.83
# Time: 44.39
#
# Epoch:10
# ValLoss_MF: 0.161790	TPR_MF: 97.44	TNR_MF: 96.03
# ValLoss_FF: 0.224066	TPR_FF: 93.97	TNR_FF: 95.46
# ValLoss_HS: 0.155794	TPR_HS: 97.50	TNR_HS: 96.23
# ValLossALL: 0.180550	TPRALL: 97.44	TNRALL: 96.03
# Time: 3.33
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.188886	TPR_MF: 95.81	TNR_MF: 95.92
# Loss_FF: 0.271274	TPR_FF: 93.20	TNR_FF: 94.82
# Loss_HS: 0.175481	TPR_HS: 95.74	TNR_HS: 96.96
# LossALL: 0.212545	TPRALL: 95.56	TNRALL: 95.98
# Time: 44.16
#
# Epoch:11
# ValLoss_MF: 0.175880	TPR_MF: 95.60	TNR_MF: 96.26
# ValLoss_FF: 0.318320	TPR_FF: 86.86	TNR_FF: 96.06
# ValLoss_HS: 0.150266	TPR_HS: 96.67	TNR_HS: 96.88
# ValLossALL: 0.214822	TPRALL: 95.60	TNRALL: 96.26
# Time: 3.34
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.186964	TPR_MF: 95.53	TNR_MF: 96.07
# Loss_FF: 0.263522	TPR_FF: 94.15	TNR_FF: 94.92
# Loss_HS: 0.164828	TPR_HS: 95.72	TNR_HS: 97.04
# LossALL: 0.205025	TPRALL: 95.62	TNRALL: 96.07
# Time: 44.48
#
# Epoch:12
# ValLoss_MF: 0.164478	TPR_MF: 96.64	TNR_MF: 96.23
# ValLoss_FF: 0.315886	TPR_FF: 87.70	TNR_FF: 94.98
# ValLoss_HS: 0.345836	TPR_HS: 90.53	TNR_HS: 96.07
# ValLossALL: 0.275400	TPRALL: 90.53	TNRALL: 96.07
# Time: 3.45
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.185260	TPR_MF: 95.84	TNR_MF: 96.07
# Loss_FF: 0.259928	TPR_FF: 95.96	TNR_FF: 94.53
# Loss_HS: 0.167817	TPR_HS: 96.14	TNR_HS: 96.72
# LossALL: 0.204758	TPRALL: 96.00	TNRALL: 96.02
# Time: 44.22
#
# Epoch:13
# ValLoss_MF: 0.180526	TPR_MF: 93.83	TNR_MF: 96.56
# ValLoss_FF: 0.256425	TPR_FF: 88.26	TNR_FF: 95.71
# ValLoss_HS: 0.143613	TPR_HS: 97.89	TNR_HS: 96.88
# ValLossALL: 0.193522	TPRALL: 93.83	TNRALL: 96.56
# Time: 3.49
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.185767	TPR_MF: 95.77	TNR_MF: 96.15
# Loss_FF: 0.252438	TPR_FF: 94.52	TNR_FF: 95.08
# Loss_HS: 0.165174	TPR_HS: 96.01	TNR_HS: 96.67
# LossALL: 0.201021	TPRALL: 95.66	TNRALL: 96.16
# Time: 44.02
#
# Epoch:14
# ValLoss_MF: 0.172530	TPR_MF: 95.46	TNR_MF: 96.49
# ValLoss_FF: 0.202074	TPR_FF: 94.56	TNR_FF: 95.67
# ValLoss_HS: 0.148628	TPR_HS: 96.63	TNR_HS: 96.80
# ValLossALL: 0.174411	TPRALL: 95.46	TNRALL: 96.49
# Time: 3.47
# Validation loss decreased (0.186691 --> 0.174411).  Saving model
#
#
# Epoch: 15
# Loss_MF: 0.183884	TPR_MF: 95.68	TNR_MF: 96.19
# Loss_FF: 0.249590	TPR_FF: 93.69	TNR_FF: 95.36
# Loss_HS: 0.159491	TPR_HS: 95.61	TNR_HS: 96.93
# LossALL: 0.197719	TPRALL: 95.58	TNRALL: 96.32
# Time: 44.00
#
# Epoch:15
# ValLoss_MF: 0.185337	TPR_MF: 93.28	TNR_MF: 96.51
# ValLoss_FF: 0.289161	TPR_FF: 86.78	TNR_FF: 95.80
# ValLoss_HS: 0.300304	TPR_HS: 92.23	TNR_HS: 96.86
# ValLossALL: 0.258267	TPRALL: 92.23	TNRALL: 96.51
# Time: 3.48
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 16
# Loss_MF: 0.192192	TPR_MF: 96.24	TNR_MF: 95.52
# Loss_FF: 0.236340	TPR_FF: 95.46	TNR_FF: 95.38
# Loss_HS: 0.167364	TPR_HS: 96.82	TNR_HS: 96.69
# LossALL: 0.198264	TPRALL: 96.23	TNRALL: 95.95
# Time: 43.95
#
# Epoch:16
# ValLoss_MF: 0.168154	TPR_MF: 94.57	TNR_MF: 97.14
# ValLoss_FF: 0.292781	TPR_FF: 83.95	TNR_FF: 95.95
# ValLoss_HS: 0.130358	TPR_HS: 97.37	TNR_HS: 97.34
# ValLossALL: 0.197098	TPRALL: 94.57	TNRALL: 97.14
# Time: 3.46
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 17
# Loss_MF: 0.182916	TPR_MF: 95.08	TNR_MF: 96.18
# Loss_FF: 0.239878	TPR_FF: 96.63	TNR_FF: 95.29
# Loss_HS: 0.169722	TPR_HS: 96.07	TNR_HS: 96.68
# LossALL: 0.197533	TPRALL: 95.81	TNRALL: 96.39
# Time: 44.38
#
# Epoch:17
# ValLoss_MF: 0.164370	TPR_MF: 95.43	TNR_MF: 96.44
# ValLoss_FF: 0.174231	TPR_FF: 96.06	TNR_FF: 96.10
# ValLoss_HS: 0.148629	TPR_HS: 97.74	TNR_HS: 96.52
# ValLossALL: 0.162410	TPRALL: 96.06	TNRALL: 96.44
# Time: 3.37
# Validation loss decreased (0.174411 --> 0.162410).  Saving model
#
#
# Epoch: 18
# Loss_MF: 0.174155	TPR_MF: 96.06	TNR_MF: 96.27
# Loss_FF: 0.243081	TPR_FF: 94.01	TNR_FF: 94.95
# Loss_HS: 0.168811	TPR_HS: 96.79	TNR_HS: 96.60
# LossALL: 0.196105	TPRALL: 96.43	TNRALL: 96.11
# Time: 44.61
#
# Epoch:18
# ValLoss_MF: 0.169869	TPR_MF: 98.03	TNR_MF: 95.57
# ValLoss_FF: 0.243616	TPR_FF: 92.73	TNR_FF: 94.99
# ValLoss_HS: 0.171462	TPR_HS: 96.51	TNR_HS: 96.10
# ValLossALL: 0.194982	TPRALL: 96.51	TNRALL: 95.57
# Time: 3.43
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.176707	TPR_MF: 96.20	TNR_MF: 96.09
# Loss_FF: 0.233402	TPR_FF: 94.58	TNR_FF: 95.02
# Loss_HS: 0.176315	TPR_HS: 96.89	TNR_HS: 96.85
# LossALL: 0.196233	TPRALL: 96.31	TNRALL: 96.00
# Time: 45.54
#
# Epoch:19
# ValLoss_MF: 0.168458	TPR_MF: 95.26	TNR_MF: 96.46
# ValLoss_FF: 0.225438	TPR_FF: 93.58	TNR_FF: 95.75
# ValLoss_HS: 0.143272	TPR_HS: 97.42	TNR_HS: 96.84
# ValLossALL: 0.179056	TPRALL: 95.26	TNRALL: 96.46
# Time: 3.53
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.170731	TPR_MF: 95.82	TNR_MF: 96.42
# Loss_FF: 0.238110	TPR_FF: 94.85	TNR_FF: 95.75
# Loss_HS: 0.171019	TPR_HS: 95.55	TNR_HS: 96.60
# LossALL: 0.194213	TPRALL: 95.75	TNRALL: 96.39
# Time: 45.29
#
# Epoch:20
# ValLoss_MF: 0.182103	TPR_MF: 96.83	TNR_MF: 95.72
# ValLoss_FF: 0.296043	TPR_FF: 91.54	TNR_FF: 94.29
# ValLoss_HS: 0.152157	TPR_HS: 97.96	TNR_HS: 96.36
# ValLossALL: 0.210101	TPRALL: 96.83	TNRALL: 95.72
# Time: 3.78
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.172947	TPR_MF: 96.33	TNR_MF: 96.09
# Loss_FF: 0.240595	TPR_FF: 94.06	TNR_FF: 95.38
# Loss_HS: 0.160567	TPR_HS: 96.14	TNR_HS: 96.92
# LossALL: 0.191869	TPRALL: 96.23	TNRALL: 96.35
# Time: 46.56
#
# Epoch:21
# ValLoss_MF: 0.184660	TPR_MF: 94.93	TNR_MF: 95.99
# ValLoss_FF: 0.251553	TPR_FF: 90.60	TNR_FF: 94.60
# ValLoss_HS: 0.150892	TPR_HS: 96.98	TNR_HS: 96.79
# ValLossALL: 0.195702	TPRALL: 94.93	TNRALL: 95.99
# Time: 3.53
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.173942	TPR_MF: 96.44	TNR_MF: 96.27
# Loss_FF: 0.227759	TPR_FF: 95.74	TNR_FF: 94.97
# Loss_HS: 0.157540	TPR_HS: 96.88	TNR_HS: 96.74
# LossALL: 0.186335	TPRALL: 96.49	TNRALL: 96.29
# Time: 46.14
#
# Epoch:22
# ValLoss_MF: 0.170621	TPR_MF: 95.52	TNR_MF: 95.92
# ValLoss_FF: 0.233123	TPR_FF: 94.41	TNR_FF: 94.97
# ValLoss_HS: 0.129770	TPR_HS: 98.08	TNR_HS: 96.81
# ValLossALL: 0.177838	TPRALL: 95.52	TNRALL: 95.92
# Time: 3.55
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.174046	TPR_MF: 95.67	TNR_MF: 96.19
# Loss_FF: 0.228251	TPR_FF: 94.34	TNR_FF: 95.19
# Loss_HS: 0.168506	TPR_HS: 96.31	TNR_HS: 96.59
# LossALL: 0.190817	TPRALL: 95.33	TNRALL: 96.27
# Time: 46.09
#
# Epoch:23
# ValLoss_MF: 0.202844	TPR_MF: 89.90	TNR_MF: 96.50
# ValLoss_FF: 0.287982	TPR_FF: 90.31	TNR_FF: 95.69
# ValLoss_HS: 0.125859	TPR_HS: 96.02	TNR_HS: 97.55
# ValLossALL: 0.205562	TPRALL: 90.31	TNRALL: 96.50
# Time: 3.53
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 24
# Loss_MF: 0.170142	TPR_MF: 96.11	TNR_MF: 96.21
# Loss_FF: 0.223641	TPR_FF: 95.01	TNR_FF: 95.15
# Loss_HS: 0.169657	TPR_HS: 96.08	TNR_HS: 96.57
# LossALL: 0.188157	TPRALL: 96.06	TNRALL: 96.22
# Time: 46.02
#
# Epoch:24
# ValLoss_MF: 0.203373	TPR_MF: 94.45	TNR_MF: 95.84
# ValLoss_FF: 0.269321	TPR_FF: 91.47	TNR_FF: 94.77
# ValLoss_HS: 0.155452	TPR_HS: 96.69	TNR_HS: 96.70
# ValLossALL: 0.209382	TPRALL: 94.45	TNRALL: 95.84
# Time: 3.50
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 25
# Loss_MF: 0.173330	TPR_MF: 96.59	TNR_MF: 95.96
# Loss_FF: 0.239268	TPR_FF: 95.16	TNR_FF: 95.48
# Loss_HS: 0.166632	TPR_HS: 96.21	TNR_HS: 96.80
# LossALL: 0.193746	TPRALL: 95.96	TNRALL: 95.94
# Time: 46.30
#
# Epoch:25
# ValLoss_MF: 0.196215	TPR_MF: 95.80	TNR_MF: 95.42
# ValLoss_FF: 0.247211	TPR_FF: 91.98	TNR_FF: 95.55
# ValLoss_HS: 0.140086	TPR_HS: 97.79	TNR_HS: 97.04
# ValLossALL: 0.194504	TPRALL: 95.80	TNRALL: 95.55
# Time: 3.61
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 26
# Loss_MF: 0.174881	TPR_MF: 96.91	TNR_MF: 95.89
# Loss_FF: 0.230577	TPR_FF: 93.83	TNR_FF: 95.35
# Loss_HS: 0.176594	TPR_HS: 95.84	TNR_HS: 96.97
# LossALL: 0.194084	TPRALL: 95.46	TNRALL: 96.13
# Time: 46.06
#
# Epoch:26
# ValLoss_MF: 0.173106	TPR_MF: 95.55	TNR_MF: 96.10
# ValLoss_FF: 0.269592	TPR_FF: 87.43	TNR_FF: 95.38
# ValLoss_HS: 0.148809	TPR_HS: 98.01	TNR_HS: 96.52
# ValLossALL: 0.197169	TPRALL: 95.55	TNRALL: 96.10
# Time: 3.45
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 27
# Loss_MF: 0.178471	TPR_MF: 95.80	TNR_MF: 95.91
# Loss_FF: 0.211842	TPR_FF: 95.87	TNR_FF: 95.65
# Loss_HS: 0.167715	TPR_HS: 96.26	TNR_HS: 96.76
# LossALL: 0.185945	TPRALL: 96.04	TNRALL: 96.24
# Time: 45.68
#
# Epoch:27
# ValLoss_MF: 0.143202	TPR_MF: 97.85	TNR_MF: 96.35
# ValLoss_FF: 0.224643	TPR_FF: 94.30	TNR_FF: 95.42
# ValLoss_HS: 0.159415	TPR_HS: 97.17	TNR_HS: 96.27
# ValLossALL: 0.175753	TPRALL: 97.17	TNRALL: 96.27
# Time: 3.50
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 28
# Loss_MF: 0.174754	TPR_MF: 96.20	TNR_MF: 96.16
# Loss_FF: 0.217111	TPR_FF: 94.43	TNR_FF: 94.89
# Loss_HS: 0.164429	TPR_HS: 95.71	TNR_HS: 96.80
# LossALL: 0.185656	TPRALL: 95.81	TNRALL: 96.23
# Time: 45.63
#
# Epoch:28
# ValLoss_MF: 0.161242	TPR_MF: 97.63	TNR_MF: 95.74
# ValLoss_FF: 0.208021	TPR_FF: 92.35	TNR_FF: 95.49
# ValLoss_HS: 0.225234	TPR_HS: 94.45	TNR_HS: 96.17
# ValLossALL: 0.198166	TPRALL: 94.45	TNRALL: 95.74
# Time: 3.60
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 29
# Loss_MF: 0.174462	TPR_MF: 95.99	TNR_MF: 96.21
# Loss_FF: 0.224833	TPR_FF: 93.57	TNR_FF: 95.03
# Loss_HS: 0.166879	TPR_HS: 96.64	TNR_HS: 96.79
# LossALL: 0.188858	TPRALL: 96.37	TNRALL: 96.26
# Time: 46.54
#
# Epoch:29
# ValLoss_MF: 0.160419	TPR_MF: 98.71	TNR_MF: 95.83
# ValLoss_FF: 0.203850	TPR_FF: 93.99	TNR_FF: 95.56
# ValLoss_HS: 0.155877	TPR_HS: 96.30	TNR_HS: 96.54
# ValLossALL: 0.173382	TPRALL: 96.30	TNRALL: 95.83
# Time: 3.54
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 30
# Loss_MF: 0.171301	TPR_MF: 96.32	TNR_MF: 96.27
# Loss_FF: 0.218246	TPR_FF: 95.70	TNR_FF: 95.56
# Loss_HS: 0.173205	TPR_HS: 95.66	TNR_HS: 96.67
# LossALL: 0.187948	TPRALL: 95.72	TNRALL: 96.25
# Time: 46.00
#
# Epoch:30
# ValLoss_MF: 0.197921	TPR_MF: 92.19	TNR_MF: 96.18
# ValLoss_FF: 0.225363	TPR_FF: 90.94	TNR_FF: 95.42
# ValLoss_HS: 0.157512	TPR_HS: 94.70	TNR_HS: 96.64
# ValLossALL: 0.193599	TPRALL: 92.19	TNRALL: 96.18
# Time: 3.59
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 31
# Loss_MF: 0.174824	TPR_MF: 96.87	TNR_MF: 95.97
# Loss_FF: 0.223576	TPR_FF: 96.20	TNR_FF: 95.60
# Loss_HS: 0.168261	TPR_HS: 95.69	TNR_HS: 97.11
# LossALL: 0.189327	TPRALL: 96.16	TNRALL: 96.23
# Time: 46.59
#
# Epoch:31
# ValLoss_MF: 0.208538	TPR_MF: 93.92	TNR_MF: 96.12
# ValLoss_FF: 0.236899	TPR_FF: 91.62	TNR_FF: 95.03
# ValLoss_HS: 0.163154	TPR_HS: 97.01	TNR_HS: 96.29
# ValLossALL: 0.202864	TPRALL: 93.92	TNRALL: 96.12
# Time: 3.62
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 32
# Loss_MF: 0.174045	TPR_MF: 96.33	TNR_MF: 96.04
# Loss_FF: 0.226865	TPR_FF: 94.84	TNR_FF: 94.79
# Loss_HS: 0.166093	TPR_HS: 96.15	TNR_HS: 96.80
# LossALL: 0.188982	TPRALL: 96.09	TNRALL: 96.19
# Time: 46.71
#
# Epoch:32
# ValLoss_MF: 0.196968	TPR_MF: 92.99	TNR_MF: 96.55
# ValLoss_FF: 0.253089	TPR_FF: 92.43	TNR_FF: 95.47
# ValLoss_HS: 0.145289	TPR_HS: 97.57	TNR_HS: 96.75
# ValLossALL: 0.198449	TPRALL: 92.99	TNRALL: 96.55
# Time: 3.49
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 33
# Loss_MF: 0.177133	TPR_MF: 95.83	TNR_MF: 96.18
# Loss_FF: 0.228835	TPR_FF: 95.69	TNR_FF: 95.50
# Loss_HS: 0.173326	TPR_HS: 95.83	TNR_HS: 96.71
# LossALL: 0.193672	TPRALL: 95.69	TNRALL: 96.14
# Time: 46.22
#
# Epoch:33
# ValLoss_MF: 0.191570	TPR_MF: 94.33	TNR_MF: 96.10
# ValLoss_FF: 0.232916	TPR_FF: 91.37	TNR_FF: 94.79
# ValLoss_HS: 0.144169	TPR_HS: 97.63	TNR_HS: 96.48
# ValLossALL: 0.189552	TPRALL: 94.33	TNRALL: 96.10
# Time: 3.48
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 34
# Loss_MF: 0.174784	TPR_MF: 96.02	TNR_MF: 96.36
# Loss_FF: 0.208178	TPR_FF: 95.27	TNR_FF: 95.36
# Loss_HS: 0.154801	TPR_HS: 96.48	TNR_HS: 97.05
# LossALL: 0.179029	TPRALL: 96.24	TNRALL: 96.33
# Time: 45.46
#
# Epoch:34
# ValLoss_MF: 0.168642	TPR_MF: 95.60	TNR_MF: 96.03
# ValLoss_FF: 0.264527	TPR_FF: 94.25	TNR_FF: 94.38
# ValLoss_HS: 0.134901	TPR_HS: 98.57	TNR_HS: 96.76
# ValLossALL: 0.189357	TPRALL: 95.60	TNRALL: 96.03
# Time: 3.58
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 35
# Loss_MF: 0.169439	TPR_MF: 95.51	TNR_MF: 96.15
# Loss_FF: 0.205731	TPR_FF: 96.05	TNR_FF: 95.42
# Loss_HS: 0.169461	TPR_HS: 96.09	TNR_HS: 96.87
# LossALL: 0.181786	TPRALL: 95.88	TNRALL: 96.23
# Time: 45.54
#
# Epoch:35
# ValLoss_MF: 0.157894	TPR_MF: 98.28	TNR_MF: 95.97
# ValLoss_FF: 0.213575	TPR_FF: 95.69	TNR_FF: 95.03
# ValLoss_HS: 0.167939	TPR_HS: 96.10	TNR_HS: 96.39
# ValLossALL: 0.179803	TPRALL: 96.10	TNRALL: 95.97
# Time: 3.54
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 36
# Loss_MF: 0.167536	TPR_MF: 97.05	TNR_MF: 96.59
# Loss_FF: 0.219122	TPR_FF: 96.62	TNR_FF: 95.17
# Loss_HS: 0.161509	TPR_HS: 95.89	TNR_HS: 96.89
# LossALL: 0.183219	TPRALL: 96.53	TNRALL: 96.56
# Time: 45.46
#
# Epoch:36
# ValLoss_MF: 0.181008	TPR_MF: 93.81	TNR_MF: 96.57
# ValLoss_FF: 0.200950	TPR_FF: 93.14	TNR_FF: 96.39
# ValLoss_HS: 0.244967	TPR_HS: 93.48	TNR_HS: 96.83
# ValLossALL: 0.208975	TPRALL: 93.48	TNRALL: 96.57
# Time: 3.49
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 37
# Loss_MF: 0.168077	TPR_MF: 96.36	TNR_MF: 96.19
# Loss_FF: 0.208056	TPR_FF: 94.99	TNR_FF: 95.01
# Loss_HS: 0.159226	TPR_HS: 96.08	TNR_HS: 96.80
# LossALL: 0.178483	TPRALL: 95.98	TNRALL: 96.37
# Time: 45.54
#
# Epoch:37
# ValLoss_MF: 0.178372	TPR_MF: 96.96	TNR_MF: 95.22
# ValLoss_FF: 0.196581	TPR_FF: 96.70	TNR_FF: 94.83
# ValLoss_HS: 0.167442	TPR_HS: 94.67	TNR_HS: 97.05
# ValLossALL: 0.180798	TPRALL: 96.70	TNRALL: 95.22
# Time: 3.50
# EarlyStopping counter: 20 out of 20
#
# Early stopping
# Network(
#   (lstm): LSTM(18, 512, num_layers=5, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear): Linear(in_features=1024, out_features=1, bias=True)
# )
# TO-512-HS-5-NL-0.001-LR-0.3-DO
#
# Epoch: 0
# Loss_MF: 0.616544	TPR_MF: 89.26	TNR_MF: 91.67
# Loss_FF: 0.404374	TPR_FF: 91.88	TNR_FF: 91.54
# Loss_HS: 0.429426	TPR_HS: 81.29	TNR_HS: 96.97
# LossALL: 0.474197	TPRALL: 85.40	TNRALL: 95.10
# Time: 57.08
#
# Epoch:0
# ValLoss_MF: 0.346094	TPR_MF: 84.16	TNR_MF: 97.62
# ValLoss_FF: 0.508834	TPR_FF: 69.68	TNR_FF: 96.89
# ValLoss_HS: 0.368094	TPR_HS: 81.69	TNR_HS: 97.46
# ValLossALL: 0.407674	TPRALL: 81.69	TNRALL: 97.46
# Time: 3.90
# Validation loss decreased (inf --> 0.407674).  Saving model
#
#
# Epoch: 1
# Loss_MF: 0.442695	TPR_MF: 82.80	TNR_MF: 96.21
# Loss_FF: 0.471802	TPR_FF: 80.18	TNR_FF: 95.50
# Loss_HS: 0.385114	TPR_HS: 82.31	TNR_HS: 96.90
# LossALL: 0.431862	TPRALL: 81.86	TNRALL: 96.27
# Time: 57.74
#
# Epoch:1
# ValLoss_MF: 0.399894	TPR_MF: 81.71	TNR_MF: 96.11
# ValLoss_FF: 0.543503	TPR_FF: 72.94	TNR_FF: 95.49
# ValLoss_HS: 0.402020	TPR_HS: 82.88	TNR_HS: 96.30
# ValLossALL: 0.448472	TPRALL: 81.71	TNRALL: 96.11
# Time: 3.82
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 2
# Loss_MF: 0.346741	TPR_MF: 85.43	TNR_MF: 96.27
# Loss_FF: 0.308432	TPR_FF: 92.23	TNR_FF: 95.02
# Loss_HS: 0.209710	TPR_HS: 95.15	TNR_HS: 96.15
# LossALL: 0.284385	TPRALL: 91.45	TNRALL: 95.97
# Time: 57.44
#
# Epoch:2
# ValLoss_MF: 0.241924	TPR_MF: 90.94	TNR_MF: 96.52
# ValLoss_FF: 0.326694	TPR_FF: 87.28	TNR_FF: 96.03
# ValLoss_HS: 0.174923	TPR_HS: 94.32	TNR_HS: 96.67
# ValLossALL: 0.247847	TPRALL: 90.94	TNRALL: 96.52
# Time: 3.82
# Validation loss decreased (0.407674 --> 0.247847).  Saving model
#
#
# Epoch: 3
# Loss_MF: 0.202082	TPR_MF: 95.01	TNR_MF: 95.58
# Loss_FF: 0.328341	TPR_FF: 88.73	TNR_FF: 94.64
# Loss_HS: 0.202951	TPR_HS: 95.34	TNR_HS: 96.67
# LossALL: 0.245340	TPRALL: 94.68	TNRALL: 95.58
# Time: 57.29
#
# Epoch:3
# ValLoss_MF: 0.265279	TPR_MF: 88.05	TNR_MF: 96.43
# ValLoss_FF: 0.381000	TPR_FF: 83.33	TNR_FF: 96.00
# ValLoss_HS: 0.150006	TPR_HS: 95.93	TNR_HS: 97.02
# ValLossALL: 0.265428	TPRALL: 88.05	TNRALL: 96.43
# Time: 3.86
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 4
# Loss_MF: 0.201543	TPR_MF: 95.70	TNR_MF: 95.92
# Loss_FF: 0.334983	TPR_FF: 92.64	TNR_FF: 94.78
# Loss_HS: 0.201380	TPR_HS: 95.64	TNR_HS: 96.32
# LossALL: 0.247779	TPRALL: 95.33	TNRALL: 95.38
# Time: 57.42
#
# Epoch:4
# ValLoss_MF: 0.228676	TPR_MF: 89.53	TNR_MF: 97.14
# ValLoss_FF: 0.280146	TPR_FF: 86.17	TNR_FF: 96.86
# ValLoss_HS: 0.206083	TPR_HS: 94.57	TNR_HS: 97.16
# ValLossALL: 0.238302	TPRALL: 89.53	TNRALL: 97.14
# Time: 3.72
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 5
# Loss_MF: 0.210417	TPR_MF: 95.49	TNR_MF: 95.66
# Loss_FF: 0.305009	TPR_FF: 91.42	TNR_FF: 95.15
# Loss_HS: 0.189972	TPR_HS: 95.67	TNR_HS: 96.13
# LossALL: 0.235724	TPRALL: 95.20	TNRALL: 95.77
# Time: 56.52
#
# Epoch:5
# ValLoss_MF: 0.164836	TPR_MF: 95.83	TNR_MF: 96.86
# ValLoss_FF: 0.281151	TPR_FF: 89.77	TNR_FF: 96.45
# ValLoss_HS: 0.216864	TPR_HS: 93.08	TNR_HS: 96.78
# ValLossALL: 0.220951	TPRALL: 93.08	TNRALL: 96.78
# Time: 3.88
# Validation loss decreased (0.247847 --> 0.220951).  Saving model
#
#
# Epoch: 6
# Loss_MF: 0.196290	TPR_MF: 95.63	TNR_MF: 95.53
# Loss_FF: 0.318937	TPR_FF: 92.10	TNR_FF: 95.54
# Loss_HS: 0.189899	TPR_HS: 95.14	TNR_HS: 96.62
# LossALL: 0.235689	TPRALL: 95.03	TNRALL: 95.91
# Time: 56.88
#
# Epoch:6
# ValLoss_MF: 0.192982	TPR_MF: 95.10	TNR_MF: 95.89
# ValLoss_FF: 0.320052	TPR_FF: 87.50	TNR_FF: 95.88
# ValLoss_HS: 0.138526	TPR_HS: 98.90	TNR_HS: 96.59
# ValLossALL: 0.217187	TPRALL: 95.10	TNRALL: 95.89
# Time: 3.73
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 7
# Loss_MF: 0.189970	TPR_MF: 95.30	TNR_MF: 95.93
# Loss_FF: 0.296313	TPR_FF: 94.63	TNR_FF: 94.43
# Loss_HS: 0.174724	TPR_HS: 96.10	TNR_HS: 96.96
# LossALL: 0.221264	TPRALL: 95.19	TNRALL: 95.99
# Time: 56.76
#
# Epoch:7
# ValLoss_MF: 0.194572	TPR_MF: 93.96	TNR_MF: 96.61
# ValLoss_FF: 0.375614	TPR_FF: 84.92	TNR_FF: 96.37
# ValLoss_HS: 0.160572	TPR_HS: 96.35	TNR_HS: 96.81
# ValLossALL: 0.243586	TPRALL: 93.96	TNRALL: 96.61
# Time: 3.92
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 8
# Loss_MF: 0.195945	TPR_MF: 95.86	TNR_MF: 95.60
# Loss_FF: 0.306241	TPR_FF: 93.44	TNR_FF: 95.20
# Loss_HS: 0.192633	TPR_HS: 95.65	TNR_HS: 96.61
# LossALL: 0.232995	TPRALL: 94.55	TNRALL: 95.71
# Time: 57.60
#
# Epoch:8
# ValLoss_MF: 0.215707	TPR_MF: 91.68	TNR_MF: 96.40
# ValLoss_FF: 0.264874	TPR_FF: 90.85	TNR_FF: 96.25
# ValLoss_HS: 0.165903	TPR_HS: 95.17	TNR_HS: 96.99
# ValLossALL: 0.215495	TPRALL: 91.68	TNRALL: 96.40
# Time: 3.77
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 9
# Loss_MF: 0.198151	TPR_MF: 96.34	TNR_MF: 96.05
# Loss_FF: 0.286185	TPR_FF: 96.08	TNR_FF: 95.42
# Loss_HS: 0.188091	TPR_HS: 95.19	TNR_HS: 96.75
# LossALL: 0.224998	TPRALL: 95.76	TNRALL: 96.33
# Time: 57.12
#
# Epoch:9
# ValLoss_MF: 0.194694	TPR_MF: 92.98	TNR_MF: 97.38
# ValLoss_FF: 0.232182	TPR_FF: 91.06	TNR_FF: 96.80
# ValLoss_HS: 0.193079	TPR_HS: 94.16	TNR_HS: 97.12
# ValLossALL: 0.206652	TPRALL: 92.98	TNRALL: 97.12
# Time: 3.79
# Validation loss decreased (0.220951 --> 0.206652).  Saving model
#
#
# Epoch: 10
# Loss_MF: 0.187887	TPR_MF: 95.86	TNR_MF: 95.99
# Loss_FF: 0.305427	TPR_FF: 93.68	TNR_FF: 95.46
# Loss_HS: 0.170728	TPR_HS: 96.03	TNR_HS: 96.92
# LossALL: 0.222363	TPRALL: 95.71	TNRALL: 96.11
# Time: 57.17
#
# Epoch:10
# ValLoss_MF: 0.223074	TPR_MF: 91.13	TNR_MF: 96.69
# ValLoss_FF: 0.226700	TPR_FF: 91.04	TNR_FF: 96.95
# ValLoss_HS: 0.140961	TPR_HS: 97.06	TNR_HS: 97.26
# ValLossALL: 0.196912	TPRALL: 91.13	TNRALL: 96.95
# Time: 3.86
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.186032	TPR_MF: 95.91	TNR_MF: 95.87
# Loss_FF: 0.294376	TPR_FF: 91.60	TNR_FF: 94.54
# Loss_HS: 0.189022	TPR_HS: 95.41	TNR_HS: 96.69
# LossALL: 0.223261	TPRALL: 95.45	TNRALL: 96.05
# Time: 57.47
#
# Epoch:11
# ValLoss_MF: 0.189610	TPR_MF: 91.11	TNR_MF: 97.34
# ValLoss_FF: 0.297421	TPR_FF: 84.68	TNR_FF: 96.59
# ValLoss_HS: 0.170053	TPR_HS: 93.19	TNR_HS: 97.52
# ValLossALL: 0.219028	TPRALL: 91.11	TNRALL: 97.34
# Time: 3.54
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.196406	TPR_MF: 95.93	TNR_MF: 95.89
# Loss_FF: 0.269672	TPR_FF: 93.05	TNR_FF: 95.46
# Loss_HS: 0.180073	TPR_HS: 95.45	TNR_HS: 96.67
# LossALL: 0.215825	TPRALL: 95.65	TNRALL: 96.06
# Time: 56.05
#
# Epoch:12
# ValLoss_MF: 0.179020	TPR_MF: 94.75	TNR_MF: 96.63
# ValLoss_FF: 0.371141	TPR_FF: 86.46	TNR_FF: 95.97
# ValLoss_HS: 0.137039	TPR_HS: 99.09	TNR_HS: 96.85
# ValLossALL: 0.229067	TPRALL: 94.75	TNRALL: 96.63
# Time: 3.78
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.185122	TPR_MF: 95.95	TNR_MF: 96.07
# Loss_FF: 0.302804	TPR_FF: 91.15	TNR_FF: 95.23
# Loss_HS: 0.176692	TPR_HS: 95.80	TNR_HS: 97.06
# LossALL: 0.222099	TPRALL: 95.69	TNRALL: 96.19
# Time: 56.19
#
# Epoch:13
# ValLoss_MF: 0.205399	TPR_MF: 91.68	TNR_MF: 97.02
# ValLoss_FF: 0.234219	TPR_FF: 89.91	TNR_FF: 96.44
# ValLoss_HS: 0.166344	TPR_HS: 94.91	TNR_HS: 97.24
# ValLossALL: 0.201987	TPRALL: 91.68	TNRALL: 97.02
# Time: 3.72
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.189200	TPR_MF: 96.08	TNR_MF: 95.95
# Loss_FF: 0.288738	TPR_FF: 92.88	TNR_FF: 95.92
# Loss_HS: 0.176201	TPR_HS: 95.99	TNR_HS: 96.84
# LossALL: 0.217537	TPRALL: 95.86	TNRALL: 96.43
# Time: 57.91
#
# Epoch:14
# ValLoss_MF: 0.190043	TPR_MF: 92.31	TNR_MF: 97.09
# ValLoss_FF: 0.263150	TPR_FF: 87.37	TNR_FF: 95.98
# ValLoss_HS: 0.159199	TPR_HS: 94.92	TNR_HS: 97.46
# ValLossALL: 0.204131	TPRALL: 92.31	TNRALL: 97.09
# Time: 3.64
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 15
# Loss_MF: 0.189373	TPR_MF: 96.05	TNR_MF: 96.27
# Loss_FF: 0.463372	TPR_FF: 87.31	TNR_FF: 94.67
# Loss_HS: 0.682348	TPR_HS: 71.20	TNR_HS: 98.55
# LossALL: 0.465526	TPRALL: 90.60	TNRALL: 95.79
# Time: 57.48
#
# Epoch:15
# ValLoss_MF: 0.889567	TPR_MF: 3.60	TNR_MF: 99.70
# ValLoss_FF: 0.905016	TPR_FF: 11.67	TNR_FF: 99.00
# ValLoss_HS: 0.868600	TPR_HS: 10.45	TNR_HS: 99.26
# ValLossALL: 0.887727	TPRALL: 10.45	TNRALL: 99.26
# Time: 3.73
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 16
# Loss_MF: 0.869438	TPR_MF: 10.19	TNR_MF: 98.74
# Loss_FF: 0.550623	TPR_FF: 83.92	TNR_FF: 94.57
# Loss_HS: 0.230745	TPR_HS: 96.61	TNR_HS: 95.94
# LossALL: 0.524207	TPRALL: 88.95	TNRALL: 96.29
# Time: 56.92
#
# Epoch:16
# ValLoss_MF: 0.184423	TPR_MF: 96.32	TNR_MF: 96.36
# ValLoss_FF: 0.321760	TPR_FF: 89.30	TNR_FF: 95.67
# ValLoss_HS: 0.155078	TPR_HS: 98.36	TNR_HS: 96.43
# ValLossALL: 0.220420	TPRALL: 96.32	TNRALL: 96.36
# Time: 3.83
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 17
# Loss_MF: 0.214533	TPR_MF: 95.50	TNR_MF: 95.35
# Loss_FF: 0.332122	TPR_FF: 91.11	TNR_FF: 93.92
# Loss_HS: 0.241097	TPR_HS: 96.80	TNR_HS: 95.01
# LossALL: 0.265087	TPRALL: 95.31	TNRALL: 94.97
# Time: 56.71
#
# Epoch:17
# ValLoss_MF: 0.179647	TPR_MF: 96.90	TNR_MF: 95.69
# ValLoss_FF: 0.322045	TPR_FF: 90.96	TNR_FF: 95.16
# ValLoss_HS: 0.175976	TPR_HS: 97.23	TNR_HS: 95.79
# ValLossALL: 0.225889	TPRALL: 96.90	TNRALL: 95.69
# Time: 3.81
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 18
# Loss_MF: 0.204909	TPR_MF: 94.61	TNR_MF: 95.19
# Loss_FF: 0.318175	TPR_FF: 92.20	TNR_FF: 95.04
# Loss_HS: 0.176977	TPR_HS: 95.89	TNR_HS: 96.68
# LossALL: 0.233945	TPRALL: 95.42	TNRALL: 96.09
# Time: 56.06
#
# Epoch:18
# ValLoss_MF: 0.260610	TPR_MF: 90.02	TNR_MF: 96.32
# ValLoss_FF: 0.314100	TPR_FF: 87.18	TNR_FF: 95.59
# ValLoss_HS: 0.254452	TPR_HS: 92.38	TNR_HS: 96.68
# ValLossALL: 0.276387	TPRALL: 90.02	TNRALL: 96.32
# Time: 3.85
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.195552	TPR_MF: 96.24	TNR_MF: 95.84
# Loss_FF: 0.282138	TPR_FF: 91.60	TNR_FF: 95.18
# Loss_HS: 0.190414	TPR_HS: 95.90	TNR_HS: 96.55
# LossALL: 0.223705	TPRALL: 95.42	TNRALL: 96.18
# Time: 56.49
#
# Epoch:19
# ValLoss_MF: 0.172933	TPR_MF: 95.02	TNR_MF: 96.98
# ValLoss_FF: 0.452601	TPR_FF: 82.64	TNR_FF: 96.12
# ValLoss_HS: 0.167116	TPR_HS: 94.72	TNR_HS: 96.94
# ValLossALL: 0.264217	TPRALL: 94.72	TNRALL: 96.94
# Time: 3.73
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.193479	TPR_MF: 95.72	TNR_MF: 96.33
# Loss_FF: 0.331111	TPR_FF: 90.87	TNR_FF: 95.62
# Loss_HS: 0.194053	TPR_HS: 95.83	TNR_HS: 96.41
# LossALL: 0.240480	TPRALL: 95.47	TNRALL: 95.94
# Time: 57.08
#
# Epoch:20
# ValLoss_MF: 0.219197	TPR_MF: 92.70	TNR_MF: 95.96
# ValLoss_FF: 0.248130	TPR_FF: 90.18	TNR_FF: 95.57
# ValLoss_HS: 0.169498	TPR_HS: 96.83	TNR_HS: 96.39
# ValLossALL: 0.212275	TPRALL: 92.70	TNRALL: 95.96
# Time: 3.62
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.195839	TPR_MF: 95.90	TNR_MF: 95.96
# Loss_FF: 0.273338	TPR_FF: 95.91	TNR_FF: 96.13
# Loss_HS: 0.181818	TPR_HS: 96.97	TNR_HS: 96.54
# LossALL: 0.217141	TPRALL: 96.15	TNRALL: 96.15
# Time: 57.13
#
# Epoch:21
# ValLoss_MF: 0.223668	TPR_MF: 92.56	TNR_MF: 96.57
# ValLoss_FF: 0.326815	TPR_FF: 87.66	TNR_FF: 95.96
# ValLoss_HS: 0.168975	TPR_HS: 95.06	TNR_HS: 96.93
# ValLossALL: 0.239819	TPRALL: 92.56	TNRALL: 96.57
# Time: 3.72
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.187259	TPR_MF: 94.93	TNR_MF: 96.31
# Loss_FF: 0.270245	TPR_FF: 94.94	TNR_FF: 95.47
# Loss_HS: 0.173104	TPR_HS: 96.02	TNR_HS: 96.80
# LossALL: 0.209647	TPRALL: 95.45	TNRALL: 96.49
# Time: 58.10
#
# Epoch:22
# ValLoss_MF: 0.206081	TPR_MF: 94.17	TNR_MF: 96.42
# ValLoss_FF: 0.324083	TPR_FF: 87.26	TNR_FF: 95.87
# ValLoss_HS: 0.143338	TPR_HS: 97.19	TNR_HS: 96.92
# ValLossALL: 0.224501	TPRALL: 94.17	TNRALL: 96.42
# Time: 3.67
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.195710	TPR_MF: 95.88	TNR_MF: 95.53
# Loss_FF: 0.251457	TPR_FF: 92.31	TNR_FF: 96.00
# Loss_HS: 0.175982	TPR_HS: 95.40	TNR_HS: 96.71
# LossALL: 0.207804	TPRALL: 95.30	TNRALL: 96.24
# Time: 57.28
#
# Epoch:23
# ValLoss_MF: 0.167350	TPR_MF: 96.77	TNR_MF: 96.20
# ValLoss_FF: 0.486722	TPR_FF: 84.24	TNR_FF: 95.36
# ValLoss_HS: 0.146412	TPR_HS: 96.56	TNR_HS: 96.79
# ValLossALL: 0.266828	TPRALL: 96.56	TNRALL: 96.20
# Time: 3.88
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 24
# Loss_MF: 0.188045	TPR_MF: 96.46	TNR_MF: 95.70
# Loss_FF: 0.281813	TPR_FF: 91.76	TNR_FF: 95.75
# Loss_HS: 0.172647	TPR_HS: 96.23	TNR_HS: 96.80
# LossALL: 0.214383	TPRALL: 95.79	TNRALL: 96.12
# Time: 57.29
#
# Epoch:24
# ValLoss_MF: 0.193649	TPR_MF: 93.39	TNR_MF: 96.95
# ValLoss_FF: 0.216283	TPR_FF: 90.97	TNR_FF: 96.64
# ValLoss_HS: 0.160174	TPR_HS: 94.40	TNR_HS: 97.15
# ValLossALL: 0.190035	TPRALL: 93.39	TNRALL: 96.95
# Time: 3.71
# Validation loss decreased (0.206652 --> 0.190035).  Saving model
#
#
# Epoch: 25
# Loss_MF: 0.188036	TPR_MF: 96.34	TNR_MF: 95.95
# Loss_FF: 0.279555	TPR_FF: 92.66	TNR_FF: 95.07
# Loss_HS: 0.180030	TPR_HS: 95.28	TNR_HS: 96.39
# LossALL: 0.216110	TPRALL: 95.35	TNRALL: 96.15
# Time: 56.97
#
# Epoch:25
# ValLoss_MF: 0.187865	TPR_MF: 94.46	TNR_MF: 96.62
# ValLoss_FF: 0.280277	TPR_FF: 89.28	TNR_FF: 96.31
# ValLoss_HS: 0.161139	TPR_HS: 97.50	TNR_HS: 96.42
# ValLossALL: 0.209760	TPRALL: 94.46	TNRALL: 96.42
# Time: 3.68
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 26
# Loss_MF: 0.186797	TPR_MF: 95.32	TNR_MF: 96.17
# Loss_FF: 0.267801	TPR_FF: 92.75	TNR_FF: 95.48
# Loss_HS: 0.173778	TPR_HS: 95.55	TNR_HS: 97.06
# LossALL: 0.209651	TPRALL: 95.18	TNRALL: 96.43
# Time: 56.40
#
# Epoch:26
# ValLoss_MF: 0.224216	TPR_MF: 90.26	TNR_MF: 96.87
# ValLoss_FF: 0.318743	TPR_FF: 87.98	TNR_FF: 96.34
# ValLoss_HS: 0.136908	TPR_HS: 96.73	TNR_HS: 97.29
# ValLossALL: 0.226622	TPRALL: 90.26	TNRALL: 96.87
# Time: 3.63
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 27
# Loss_MF: 0.182247	TPR_MF: 96.08	TNR_MF: 96.11
# Loss_FF: 0.279306	TPR_FF: 93.12	TNR_FF: 95.33
# Loss_HS: 0.207193	TPR_HS: 93.27	TNR_HS: 96.25
# LossALL: 0.225084	TPRALL: 95.00	TNRALL: 96.07
# Time: 55.80
#
# Epoch:27
# ValLoss_MF: 0.180226	TPR_MF: 96.71	TNR_MF: 96.10
# ValLoss_FF: 0.380263	TPR_FF: 85.38	TNR_FF: 95.61
# ValLoss_HS: 0.156423	TPR_HS: 97.57	TNR_HS: 96.58
# ValLossALL: 0.238971	TPRALL: 96.71	TNRALL: 96.10
# Time: 3.74
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 28
# Loss_MF: 0.198674	TPR_MF: 95.36	TNR_MF: 95.90
# Loss_FF: 0.308175	TPR_FF: 90.82	TNR_FF: 95.23
# Loss_HS: 0.208130	TPR_HS: 95.80	TNR_HS: 96.74
# LossALL: 0.240138	TPRALL: 94.84	TNRALL: 96.00
# Time: 56.69
#
# Epoch:28
# ValLoss_MF: 0.229469	TPR_MF: 93.44	TNR_MF: 95.96
# ValLoss_FF: 0.329865	TPR_FF: 86.71	TNR_FF: 96.03
# ValLoss_HS: 0.202370	TPR_HS: 95.52	TNR_HS: 96.43
# ValLossALL: 0.253902	TPRALL: 93.44	TNRALL: 96.03
# Time: 3.73
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 29
# Loss_MF: 0.211468	TPR_MF: 94.39	TNR_MF: 96.12
# Loss_FF: 0.308390	TPR_FF: 93.47	TNR_FF: 94.65
# Loss_HS: 0.194042	TPR_HS: 95.62	TNR_HS: 96.75
# LossALL: 0.238148	TPRALL: 94.55	TNRALL: 95.92
# Time: 57.32
#
# Epoch:29
# ValLoss_MF: 0.175114	TPR_MF: 95.51	TNR_MF: 96.38
# ValLoss_FF: 0.314988	TPR_FF: 85.38	TNR_FF: 96.21
# ValLoss_HS: 0.164189	TPR_HS: 96.18	TNR_HS: 96.61
# ValLossALL: 0.218097	TPRALL: 95.51	TNRALL: 96.38
# Time: 3.73
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 30
# Loss_MF: 0.184387	TPR_MF: 96.14	TNR_MF: 95.95
# Loss_FF: 0.257838	TPR_FF: 94.33	TNR_FF: 95.12
# Loss_HS: 0.175858	TPR_HS: 94.79	TNR_HS: 96.99
# LossALL: 0.206737	TPRALL: 95.31	TNRALL: 96.05
# Time: 56.67
#
# Epoch:30
# ValLoss_MF: 0.212863	TPR_MF: 92.69	TNR_MF: 96.43
# ValLoss_FF: 0.514075	TPR_FF: 80.56	TNR_FF: 95.91
# ValLoss_HS: 0.160240	TPR_HS: 95.92	TNR_HS: 96.78
# ValLossALL: 0.295726	TPRALL: 92.69	TNRALL: 96.43
# Time: 3.85
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 31
# Loss_MF: 0.188315	TPR_MF: 95.34	TNR_MF: 95.98
# Loss_FF: 0.270179	TPR_FF: 95.23	TNR_FF: 95.76
# Loss_HS: 0.182813	TPR_HS: 96.15	TNR_HS: 96.50
# LossALL: 0.214696	TPRALL: 95.68	TNRALL: 96.04
# Time: 56.91
#
# Epoch:31
# ValLoss_MF: 0.178347	TPR_MF: 92.86	TNR_MF: 97.00
# ValLoss_FF: 0.371061	TPR_FF: 81.87	TNR_FF: 96.62
# ValLoss_HS: 0.145246	TPR_HS: 97.89	TNR_HS: 97.18
# ValLossALL: 0.231551	TPRALL: 92.86	TNRALL: 97.00
# Time: 3.89
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 32
# Loss_MF: 0.192601	TPR_MF: 94.94	TNR_MF: 96.14
# Loss_FF: 0.283760	TPR_FF: 93.43	TNR_FF: 94.66
# Loss_HS: 0.183524	TPR_HS: 94.22	TNR_HS: 96.84
# LossALL: 0.220146	TPRALL: 94.16	TNRALL: 96.14
# Time: 56.33
#
# Epoch:32
# ValLoss_MF: 0.181707	TPR_MF: 94.30	TNR_MF: 96.38
# ValLoss_FF: 0.365958	TPR_FF: 85.43	TNR_FF: 95.76
# ValLoss_HS: 0.157148	TPR_HS: 96.94	TNR_HS: 96.52
# ValLossALL: 0.234938	TPRALL: 94.30	TNRALL: 96.38
# Time: 3.72
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 33
# Loss_MF: 0.186065	TPR_MF: 96.56	TNR_MF: 95.92
# Loss_FF: 0.293445	TPR_FF: 91.08	TNR_FF: 94.98
# Loss_HS: 0.172592	TPR_HS: 95.93	TNR_HS: 96.84
# LossALL: 0.217724	TPRALL: 95.66	TNRALL: 96.07
# Time: 56.31
#
# Epoch:33
# ValLoss_MF: 0.206426	TPR_MF: 92.49	TNR_MF: 96.88
# ValLoss_FF: 0.275161	TPR_FF: 89.29	TNR_FF: 96.64
# ValLoss_HS: 0.191018	TPR_HS: 94.32	TNR_HS: 97.00
# ValLossALL: 0.224202	TPRALL: 92.49	TNRALL: 96.88
# Time: 3.78
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 34
# Loss_MF: 0.180008	TPR_MF: 96.28	TNR_MF: 96.32
# Loss_FF: 0.307467	TPR_FF: 90.41	TNR_FF: 95.39
# Loss_HS: 0.175575	TPR_HS: 96.36	TNR_HS: 96.92
# LossALL: 0.222600	TPRALL: 95.54	TNRALL: 96.43
# Time: 56.51
#
# Epoch:34
# ValLoss_MF: 0.240366	TPR_MF: 92.46	TNR_MF: 96.41
# ValLoss_FF: 0.184868	TPR_FF: 94.81	TNR_FF: 96.42
# ValLoss_HS: 0.146716	TPR_HS: 97.38	TNR_HS: 97.13
# ValLossALL: 0.190650	TPRALL: 94.81	TNRALL: 96.42
# Time: 3.87
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 35
# Loss_MF: 0.180547	TPR_MF: 95.42	TNR_MF: 96.50
# Loss_FF: 0.296092	TPR_FF: 92.54	TNR_FF: 95.13
# Loss_HS: 0.176429	TPR_HS: 96.51	TNR_HS: 96.58
# LossALL: 0.218267	TPRALL: 95.42	TNRALL: 96.32
# Time: 58.25
#
# Epoch:35
# ValLoss_MF: 0.223218	TPR_MF: 89.65	TNR_MF: 96.58
# ValLoss_FF: 0.184958	TPR_FF: 93.72	TNR_FF: 96.41
# ValLoss_HS: 0.185340	TPR_HS: 93.09	TNR_HS: 96.92
# ValLossALL: 0.197839	TPRALL: 93.09	TNRALL: 96.58
# Time: 3.65
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 36
# Loss_MF: 0.186126	TPR_MF: 96.06	TNR_MF: 96.14
# Loss_FF: 0.258111	TPR_FF: 95.19	TNR_FF: 95.88
# Loss_HS: 0.173663	TPR_HS: 97.06	TNR_HS: 96.47
# LossALL: 0.206522	TPRALL: 95.79	TNRALL: 96.10
# Time: 56.68
#
# Epoch:36
# ValLoss_MF: 0.207645	TPR_MF: 92.88	TNR_MF: 96.80
# ValLoss_FF: 0.291713	TPR_FF: 89.31	TNR_FF: 96.13
# ValLoss_HS: 0.150796	TPR_HS: 96.95	TNR_HS: 96.97
# ValLossALL: 0.216718	TPRALL: 92.88	TNRALL: 96.80
# Time: 3.69
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 37
# Loss_MF: 0.181890	TPR_MF: 96.74	TNR_MF: 95.75
# Loss_FF: 0.269877	TPR_FF: 92.12	TNR_FF: 95.99
# Loss_HS: 0.174774	TPR_HS: 95.33	TNR_HS: 96.87
# LossALL: 0.209802	TPRALL: 95.32	TNRALL: 96.23
# Time: 56.58
#
# Epoch:37
# ValLoss_MF: 0.214374	TPR_MF: 91.28	TNR_MF: 96.58
# ValLoss_FF: 0.256976	TPR_FF: 88.29	TNR_FF: 96.61
# ValLoss_HS: 0.155949	TPR_HS: 95.73	TNR_HS: 97.14
# ValLossALL: 0.209100	TPRALL: 91.28	TNRALL: 96.61
# Time: 3.87
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 38
# Loss_MF: 0.181336	TPR_MF: 95.68	TNR_MF: 96.27
# Loss_FF: 0.260334	TPR_FF: 93.04	TNR_FF: 96.08
# Loss_HS: 0.175246	TPR_HS: 96.95	TNR_HS: 96.45
# LossALL: 0.206507	TPRALL: 95.71	TNRALL: 96.26
# Time: 57.20
#
# Epoch:38
# ValLoss_MF: 0.175287	TPR_MF: 93.32	TNR_MF: 97.46
# ValLoss_FF: 0.319237	TPR_FF: 83.49	TNR_FF: 96.47
# ValLoss_HS: 0.135321	TPR_HS: 97.18	TNR_HS: 97.57
# ValLossALL: 0.209948	TPRALL: 93.32	TNRALL: 97.46
# Time: 3.76
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 39
# Loss_MF: 0.188022	TPR_MF: 95.74	TNR_MF: 96.26
# Loss_FF: 0.251863	TPR_FF: 92.65	TNR_FF: 95.68
# Loss_HS: 0.164715	TPR_HS: 95.95	TNR_HS: 97.03
# LossALL: 0.201609	TPRALL: 95.54	TNRALL: 96.18
# Time: 55.70
#
# Epoch:39
# ValLoss_MF: 0.173595	TPR_MF: 94.63	TNR_MF: 96.47
# ValLoss_FF: 0.294655	TPR_FF: 90.46	TNR_FF: 95.62
# ValLoss_HS: 0.160966	TPR_HS: 95.32	TNR_HS: 97.01
# ValLossALL: 0.209739	TPRALL: 94.63	TNRALL: 96.47
# Time: 3.87
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 40
# Loss_MF: 0.175737	TPR_MF: 95.93	TNR_MF: 96.25
# Loss_FF: 0.233028	TPR_FF: 93.38	TNR_FF: 95.85
# Loss_HS: 0.162169	TPR_HS: 96.29	TNR_HS: 96.92
# LossALL: 0.190629	TPRALL: 95.20	TNRALL: 96.27
# Time: 55.89
#
# Epoch:40
# ValLoss_MF: 0.153235	TPR_MF: 95.56	TNR_MF: 96.92
# ValLoss_FF: 0.342017	TPR_FF: 85.69	TNR_FF: 95.57
# ValLoss_HS: 0.265974	TPR_HS: 92.29	TNR_HS: 96.97
# ValLossALL: 0.253742	TPRALL: 92.29	TNRALL: 96.92
# Time: 3.83
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 41
# Loss_MF: 0.177146	TPR_MF: 96.68	TNR_MF: 96.52
# Loss_FF: 0.301841	TPR_FF: 92.28	TNR_FF: 95.53
# Loss_HS: 0.180446	TPR_HS: 96.22	TNR_HS: 96.69
# LossALL: 0.220730	TPRALL: 96.08	TNRALL: 96.31
# Time: 56.91
#
# Epoch:41
# ValLoss_MF: 0.178276	TPR_MF: 93.89	TNR_MF: 96.94
# ValLoss_FF: 0.237089	TPR_FF: 89.46	TNR_FF: 96.49
# ValLoss_HS: 0.161215	TPR_HS: 95.51	TNR_HS: 97.01
# ValLossALL: 0.192193	TPRALL: 93.89	TNRALL: 96.94
# Time: 3.76
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 42
# Loss_MF: 0.182480	TPR_MF: 96.80	TNR_MF: 96.17
# Loss_FF: 0.270100	TPR_FF: 94.27	TNR_FF: 95.53
# Loss_HS: 0.174842	TPR_HS: 95.81	TNR_HS: 97.00
# LossALL: 0.209521	TPRALL: 95.89	TNRALL: 96.17
# Time: 57.80
#
# Epoch:42
# ValLoss_MF: 0.238567	TPR_MF: 91.40	TNR_MF: 96.11
# ValLoss_FF: 0.268648	TPR_FF: 89.20	TNR_FF: 96.34
# ValLoss_HS: 0.184400	TPR_HS: 94.20	TNR_HS: 96.88
# ValLossALL: 0.230538	TPRALL: 91.40	TNRALL: 96.34
# Time: 3.73
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 43
# Loss_MF: 0.179218	TPR_MF: 96.15	TNR_MF: 96.24
# Loss_FF: 0.257382	TPR_FF: 94.93	TNR_FF: 95.84
# Loss_HS: 0.168368	TPR_HS: 95.61	TNR_HS: 97.14
# LossALL: 0.201887	TPRALL: 95.96	TNRALL: 96.35
# Time: 57.25
#
# Epoch:43
# ValLoss_MF: 0.178218	TPR_MF: 94.84	TNR_MF: 96.46
# ValLoss_FF: 0.219239	TPR_FF: 92.57	TNR_FF: 96.36
# ValLoss_HS: 0.134667	TPR_HS: 97.80	TNR_HS: 97.28
# ValLossALL: 0.177375	TPRALL: 94.84	TNRALL: 96.46
# Time: 3.76
# Validation loss decreased (0.190035 --> 0.177375).  Saving model
#
#
# Epoch: 44
# Loss_MF: 0.175915	TPR_MF: 97.07	TNR_MF: 96.13
# Loss_FF: 0.250798	TPR_FF: 94.12	TNR_FF: 95.34
# Loss_HS: 0.170557	TPR_HS: 95.97	TNR_HS: 96.79
# LossALL: 0.199926	TPRALL: 95.88	TNRALL: 96.30
# Time: 57.23
#
# Epoch:44
# ValLoss_MF: 0.221254	TPR_MF: 92.38	TNR_MF: 96.72
# ValLoss_FF: 0.229202	TPR_FF: 93.00	TNR_FF: 96.51
# ValLoss_HS: 0.172691	TPR_HS: 94.07	TNR_HS: 97.24
# ValLossALL: 0.207716	TPRALL: 93.00	TNRALL: 96.72
# Time: 3.87
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 45
# Loss_MF: 0.181301	TPR_MF: 95.91	TNR_MF: 96.20
# Loss_FF: 0.252543	TPR_FF: 93.75	TNR_FF: 95.80
# Loss_HS: 0.166625	TPR_HS: 96.51	TNR_HS: 96.95
# LossALL: 0.200627	TPRALL: 96.18	TNRALL: 96.52
# Time: 56.91
#
# Epoch:45
# ValLoss_MF: 0.167558	TPR_MF: 95.55	TNR_MF: 96.61
# ValLoss_FF: 0.228356	TPR_FF: 92.36	TNR_FF: 96.26
# ValLoss_HS: 0.159219	TPR_HS: 95.48	TNR_HS: 96.77
# ValLossALL: 0.185044	TPRALL: 95.48	TNRALL: 96.61
# Time: 3.83
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 46
# Loss_MF: 0.172594	TPR_MF: 96.52	TNR_MF: 96.33
# Loss_FF: 0.255275	TPR_FF: 90.62	TNR_FF: 95.54
# Loss_HS: 0.218696	TPR_HS: 94.56	TNR_HS: 96.43
# LossALL: 0.218224	TPRALL: 94.82	TNRALL: 96.31
# Time: 57.02
#
# Epoch:46
# ValLoss_MF: 0.364134	TPR_MF: 90.29	TNR_MF: 91.61
# ValLoss_FF: 0.482449	TPR_FF: 81.94	TNR_FF: 91.57
# ValLoss_HS: 0.276765	TPR_HS: 96.07	TNR_HS: 90.92
# ValLossALL: 0.374449	TPRALL: 90.29	TNRALL: 91.57
# Time: 3.73
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 47
# Loss_MF: 0.378738	TPR_MF: 95.04	TNR_MF: 94.00
# Loss_FF: 0.343498	TPR_FF: 92.48	TNR_FF: 93.57
# Loss_HS: 0.188825	TPR_HS: 95.63	TNR_HS: 96.21
# LossALL: 0.296240	TPRALL: 95.12	TNRALL: 94.69
# Time: 56.72
#
# Epoch:47
# ValLoss_MF: 0.164377	TPR_MF: 95.12	TNR_MF: 97.02
# ValLoss_FF: 0.452045	TPR_FF: 79.58	TNR_FF: 96.10
# ValLoss_HS: 0.129909	TPR_HS: 97.98	TNR_HS: 97.33
# ValLossALL: 0.248777	TPRALL: 95.12	TNRALL: 97.02
# Time: 3.66
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 48
# Loss_MF: 0.195543	TPR_MF: 94.69	TNR_MF: 96.15
# Loss_FF: 0.302401	TPR_FF: 90.94	TNR_FF: 95.61
# Loss_HS: 0.193926	TPR_HS: 97.29	TNR_HS: 96.53
# LossALL: 0.232023	TPRALL: 94.41	TNRALL: 95.84
# Time: 56.81
#
# Epoch:48
# ValLoss_MF: 0.172580	TPR_MF: 95.33	TNR_MF: 96.68
# ValLoss_FF: 0.279820	TPR_FF: 87.46	TNR_FF: 96.15
# ValLoss_HS: 0.185633	TPR_HS: 94.99	TNR_HS: 96.74
# ValLossALL: 0.212678	TPRALL: 94.99	TNRALL: 96.68
# Time: 3.61
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 49
# Loss_MF: 0.190052	TPR_MF: 94.66	TNR_MF: 96.52
# Loss_FF: 0.290217	TPR_FF: 87.78	TNR_FF: 95.05
# Loss_HS: 0.184878	TPR_HS: 95.81	TNR_HS: 96.74
# LossALL: 0.221512	TPRALL: 94.67	TNRALL: 96.29
# Time: 57.80
#
# Epoch:49
# ValLoss_MF: 0.270974	TPR_MF: 88.24	TNR_MF: 96.11
# ValLoss_FF: 0.269525	TPR_FF: 87.68	TNR_FF: 96.12
# ValLoss_HS: 0.140289	TPR_HS: 98.32	TNR_HS: 96.77
# ValLossALL: 0.226929	TPRALL: 88.24	TNRALL: 96.12
# Time: 3.57
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 50
# Loss_MF: 0.184839	TPR_MF: 95.62	TNR_MF: 96.32
# Loss_FF: 0.277621	TPR_FF: 93.44	TNR_FF: 95.64
# Loss_HS: 0.177792	TPR_HS: 95.47	TNR_HS: 96.88
# LossALL: 0.213848	TPRALL: 95.28	TNRALL: 96.30
# Time: 57.10
#
# Epoch:50
# ValLoss_MF: 0.173295	TPR_MF: 95.28	TNR_MF: 96.81
# ValLoss_FF: 0.301616	TPR_FF: 86.81	TNR_FF: 96.21
# ValLoss_HS: 0.184339	TPR_HS: 92.46	TNR_HS: 96.96
# ValLossALL: 0.219750	TPRALL: 92.46	TNRALL: 96.81
# Time: 3.70
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 51
# ...
# ValLossALL: 0.581106	TPRALL: 75.59	TNRALL: 87.59
# Time: 4.69
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 41
# Loss_MF: 0.577490	TPR_MF: 74.31	TNR_MF: 87.20
# Loss_FF: 0.589514	TPR_FF: 76.87	TNR_FF: 86.81
# Loss_HS: 0.567394	TPR_HS: 75.90	TNR_HS: 86.71
# LossALL: 0.577944	TPRALL: 76.36	TNRALL: 86.81
# Time: 110.95
#
# Epoch:41
# ValLoss_MF: 0.532310	TPR_MF: 80.19	TNR_MF: 87.26
# ValLoss_FF: 0.682320	TPR_FF: 72.58	TNR_FF: 87.26
# ValLoss_HS: 0.533402	TPR_HS: 76.38	TNR_HS: 87.25
# ValLossALL: 0.582677	TPRALL: 76.38	TNRALL: 87.26
# Time: 4.53
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 42
# Loss_MF: 0.563288	TPR_MF: 78.99	TNR_MF: 86.68
# Loss_FF: 0.603523	TPR_FF: 73.06	TNR_FF: 87.32
# Loss_HS: 0.559735	TPR_HS: 76.67	TNR_HS: 86.81
# LossALL: 0.575689	TPRALL: 76.12	TNRALL: 86.76
# Time: 110.61
#
# Epoch:42
# ValLoss_MF: 0.515293	TPR_MF: 77.15	TNR_MF: 86.47
# ValLoss_FF: 0.583898	TPR_FF: 73.12	TNR_FF: 87.14
# ValLoss_HS: 0.544457	TPR_HS: 75.74	TNR_HS: 87.00
# ValLossALL: 0.547883	TPRALL: 75.74	TNRALL: 87.00
# Time: 4.58
# Validation loss decreased (0.573190 --> 0.547883).  Saving model
#
#
# Epoch: 43
# Loss_MF: 0.574203	TPR_MF: 77.36	TNR_MF: 86.35
# Loss_FF: 0.610122	TPR_FF: 74.44	TNR_FF: 85.80
# Loss_HS: 0.561245	TPR_HS: 75.77	TNR_HS: 86.72
# LossALL: 0.581905	TPRALL: 75.95	TNRALL: 86.57
# Time: 110.31
#
# Epoch:43
# ValLoss_MF: 0.604336	TPR_MF: 69.12	TNR_MF: 86.82
# ValLoss_FF: 0.535978	TPR_FF: 78.45	TNR_FF: 87.58
# ValLoss_HS: 0.583305	TPR_HS: 73.78	TNR_HS: 87.22
# ValLossALL: 0.574540	TPRALL: 73.78	TNRALL: 87.22
# Time: 4.54
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 44
# Loss_MF: 0.566102	TPR_MF: 76.15	TNR_MF: 86.38
# Loss_FF: 0.601666	TPR_FF: 72.97	TNR_FF: 85.66
# Loss_HS: 0.557465	TPR_HS: 77.35	TNR_HS: 86.07
# LossALL: 0.574739	TPRALL: 75.56	TNRALL: 86.07
# Time: 112.07
#
# Epoch:44
# ValLoss_MF: 0.565808	TPR_MF: 77.13	TNR_MF: 87.56
# ValLoss_FF: 0.520651	TPR_FF: 78.78	TNR_FF: 87.68
# ValLoss_HS: 0.562944	TPR_HS: 71.35	TNR_HS: 87.22
# ValLossALL: 0.549801	TPRALL: 77.13	TNRALL: 87.56
# Time: 4.42
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 45
# Loss_MF: 0.556800	TPR_MF: 74.78	TNR_MF: 87.12
# Loss_FF: 0.621503	TPR_FF: 70.59	TNR_FF: 86.79
# Loss_HS: 0.558890	TPR_HS: 75.81	TNR_HS: 86.66
# LossALL: 0.580016	TPRALL: 74.69	TNRALL: 86.83
# Time: 108.71
#
# Epoch:45
# ValLoss_MF: 0.641110	TPR_MF: 68.57	TNR_MF: 86.90
# ValLoss_FF: 0.577802	TPR_FF: 77.26	TNR_FF: 86.67
# ValLoss_HS: 0.599796	TPR_HS: 74.63	TNR_HS: 86.77
# ValLossALL: 0.606236	TPRALL: 74.63	TNRALL: 86.77
# Time: 4.62
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 46
# Loss_MF: 0.559209	TPR_MF: 76.36	TNR_MF: 86.72
# Loss_FF: 0.598449	TPR_FF: 74.13	TNR_FF: 86.20
# Loss_HS: 0.568451	TPR_HS: 76.65	TNR_HS: 86.10
# LossALL: 0.576218	TPRALL: 74.90	TNRALL: 86.45
# Time: 109.23
#
# Epoch:46
# ValLoss_MF: 0.514623	TPR_MF: 83.54	TNR_MF: 87.20
# ValLoss_FF: 0.668768	TPR_FF: 70.94	TNR_FF: 86.83
# ValLoss_HS: 0.599126	TPR_HS: 71.99	TNR_HS: 86.01
# ValLossALL: 0.594172	TPRALL: 71.99	TNRALL: 86.83
# Time: 4.58
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 47
# Loss_MF: 0.567203	TPR_MF: 77.33	TNR_MF: 86.00
# Loss_FF: 0.633756	TPR_FF: 70.66	TNR_FF: 85.71
# Loss_HS: 0.559562	TPR_HS: 77.38	TNR_HS: 86.78
# LossALL: 0.587080	TPRALL: 77.06	TNRALL: 85.99
# Time: 110.56
#
# Epoch:47
# ValLoss_MF: 0.576446	TPR_MF: 75.18	TNR_MF: 87.48
# ValLoss_FF: 0.532224	TPR_FF: 79.00	TNR_FF: 87.74
# ValLoss_HS: 0.503079	TPR_HS: 79.92	TNR_HS: 87.31
# ValLossALL: 0.537250	TPRALL: 79.00	TNRALL: 87.48
# Time: 4.67
# Validation loss decreased (0.547883 --> 0.537250).  Saving model
#
#
# Epoch: 48
# Loss_MF: 0.552193	TPR_MF: 77.02	TNR_MF: 87.22
# Loss_FF: 0.602186	TPR_FF: 74.32	TNR_FF: 86.78
# Loss_HS: 0.562370	TPR_HS: 76.57	TNR_HS: 87.05
# LossALL: 0.572854	TPRALL: 76.57	TNRALL: 86.91
# Time: 110.90
#
# Epoch:48
# ValLoss_MF: 0.644518	TPR_MF: 69.93	TNR_MF: 86.53
# ValLoss_FF: 0.623438	TPR_FF: 70.16	TNR_FF: 86.68
# ValLoss_HS: 0.548475	TPR_HS: 76.08	TNR_HS: 87.05
# ValLossALL: 0.605477	TPRALL: 70.16	TNRALL: 86.68
# Time: 4.65
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 49
# Loss_MF: 0.558243	TPR_MF: 75.45	TNR_MF: 86.92
# Loss_FF: 0.586099	TPR_FF: 77.88	TNR_FF: 86.93
# Loss_HS: 0.561446	TPR_HS: 75.40	TNR_HS: 86.20
# LossALL: 0.568867	TPRALL: 76.49	TNRALL: 86.79
# Time: 110.52
#
# Epoch:49
# ValLoss_MF: 0.595561	TPR_MF: 70.98	TNR_MF: 86.62
# ValLoss_FF: 0.627273	TPR_FF: 72.17	TNR_FF: 86.90
# ValLoss_HS: 0.607622	TPR_HS: 67.75	TNR_HS: 87.10
# ValLossALL: 0.610152	TPRALL: 70.98	TNRALL: 86.90
# Time: 4.61
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 50
# Loss_MF: 0.569915	TPR_MF: 74.25	TNR_MF: 86.85
# Loss_FF: 0.617985	TPR_FF: 72.50	TNR_FF: 86.57
# Loss_HS: 0.563043	TPR_HS: 75.62	TNR_HS: 86.80
# LossALL: 0.584068	TPRALL: 74.22	TNRALL: 86.76
# Time: 109.53
#
# Epoch:50
# ValLoss_MF: 0.554431	TPR_MF: 73.18	TNR_MF: 88.02
# ValLoss_FF: 0.529898	TPR_FF: 74.33	TNR_FF: 87.96
# ValLoss_HS: 0.560084	TPR_HS: 72.31	TNR_HS: 87.21
# ValLossALL: 0.548138	TPRALL: 73.18	TNRALL: 87.96
# Time: 4.68
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 51
# Loss_MF: 0.567665	TPR_MF: 75.57	TNR_MF: 86.65
# Loss_FF: 0.585147	TPR_FF: 74.62	TNR_FF: 87.57
# Loss_HS: 0.563437	TPR_HS: 76.62	TNR_HS: 86.97
# LossALL: 0.572177	TPRALL: 75.38	TNRALL: 86.94
# Time: 109.33
#
# Epoch:51
# ValLoss_MF: 0.581428	TPR_MF: 64.68	TNR_MF: 87.43
# ValLoss_FF: 0.628851	TPR_FF: 67.62	TNR_FF: 87.10
# ValLoss_HS: 0.515001	TPR_HS: 77.30	TNR_HS: 87.47
# ValLossALL: 0.575093	TPRALL: 67.62	TNRALL: 87.43
# Time: 4.62
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 52
# Loss_MF: 0.584040	TPR_MF: 75.86	TNR_MF: 85.59
# Loss_FF: 0.603001	TPR_FF: 75.93	TNR_FF: 86.26
# Loss_HS: 0.554007	TPR_HS: 80.73	TNR_HS: 85.27
# LossALL: 0.579586	TPRALL: 76.79	TNRALL: 85.62
# Time: 108.95
#
# Epoch:52
# ValLoss_MF: 0.520174	TPR_MF: 81.21	TNR_MF: 87.35
# ValLoss_FF: 0.604276	TPR_FF: 72.97	TNR_FF: 87.21
# ValLoss_HS: 0.606076	TPR_HS: 71.38	TNR_HS: 86.78
# ValLossALL: 0.576842	TPRALL: 72.97	TNRALL: 87.21
# Time: 4.71
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 53
# Loss_MF: 0.560419	TPR_MF: 76.12	TNR_MF: 86.92
# Loss_FF: 0.640725	TPR_FF: 68.03	TNR_FF: 86.78
# Loss_HS: 0.567963	TPR_HS: 74.71	TNR_HS: 87.00
# LossALL: 0.590439	TPRALL: 74.39	TNRALL: 86.92
# Time: 110.90
#
# Epoch:53
# ValLoss_MF: 0.560138	TPR_MF: 77.51	TNR_MF: 85.74
# ValLoss_FF: 0.560493	TPR_FF: 79.32	TNR_FF: 86.11
# ValLoss_HS: 0.578504	TPR_HS: 79.86	TNR_HS: 86.19
# ValLossALL: 0.566378	TPRALL: 79.32	TNRALL: 86.11
# Time: 4.57
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 54
# Loss_MF: 0.569025	TPR_MF: 77.82	TNR_MF: 85.56
# Loss_FF: 0.603238	TPR_FF: 75.52	TNR_FF: 86.28
# Loss_HS: 0.572684	TPR_HS: 74.87	TNR_HS: 85.96
# LossALL: 0.582239	TPRALL: 75.52	TNRALL: 85.99
# Time: 109.57
#
# Epoch:54
# ValLoss_MF: 0.475266	TPR_MF: 80.92	TNR_MF: 87.12
# ValLoss_FF: 0.627308	TPR_FF: 72.24	TNR_FF: 86.88
# ValLoss_HS: 0.478411	TPR_HS: 84.47	TNR_HS: 87.52
# ValLossALL: 0.526995	TPRALL: 80.92	TNRALL: 87.12
# Time: 4.66
# Validation loss decreased (0.537250 --> 0.526995).  Saving model
#
#
# Epoch: 55
# Loss_MF: 0.558641	TPR_MF: 75.56	TNR_MF: 86.76
# Loss_FF: 0.587993	TPR_FF: 73.25	TNR_FF: 86.51
# Loss_HS: 0.553358	TPR_HS: 77.72	TNR_HS: 86.21
# LossALL: 0.566719	TPRALL: 77.10	TNRALL: 86.57
# Time: 111.59
#
# Epoch:55
# ValLoss_MF: 0.647160	TPR_MF: 64.21	TNR_MF: 88.69
# ValLoss_FF: 0.689081	TPR_FF: 67.06	TNR_FF: 89.07
# ValLoss_HS: 0.493842	TPR_HS: 78.25	TNR_HS: 89.35
# ValLossALL: 0.610028	TPRALL: 67.06	TNRALL: 89.07
# Time: 4.59
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 56
# Loss_MF: 0.561847	TPR_MF: 76.21	TNR_MF: 87.42
# Loss_FF: 0.608051	TPR_FF: 75.32	TNR_FF: 86.42
# Loss_HS: 0.564933	TPR_HS: 73.62	TNR_HS: 86.38
# LossALL: 0.579010	TPRALL: 75.09	TNRALL: 86.64
# Time: 109.24
#
# Epoch:56
# ValLoss_MF: 0.538616	TPR_MF: 80.89	TNR_MF: 84.57
# ValLoss_FF: 0.568568	TPR_FF: 77.15	TNR_FF: 85.59
# ValLoss_HS: 0.579059	TPR_HS: 76.58	TNR_HS: 86.35
# ValLossALL: 0.562081	TPRALL: 77.15	TNRALL: 85.59
# Time: 4.71
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 57
# Loss_MF: 0.569938	TPR_MF: 75.06	TNR_MF: 86.44
# Loss_FF: 0.604615	TPR_FF: 72.01	TNR_FF: 86.25
# Loss_HS: 0.563124	TPR_HS: 77.35	TNR_HS: 85.70
# LossALL: 0.579466	TPRALL: 75.95	TNRALL: 86.25
# Time: 109.74
#
# Epoch:57
# ValLoss_MF: 0.589459	TPR_MF: 76.27	TNR_MF: 85.02
# ValLoss_FF: 0.587551	TPR_FF: 78.67	TNR_FF: 85.42
# ValLoss_HS: 0.526181	TPR_HS: 80.86	TNR_HS: 84.49
# ValLossALL: 0.567730	TPRALL: 78.67	TNRALL: 85.02
# Time: 4.54
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 58
# Loss_MF: 0.563344	TPR_MF: 78.60	TNR_MF: 85.72
# Loss_FF: 0.617159	TPR_FF: 75.17	TNR_FF: 85.76
# Loss_HS: 0.567520	TPR_HS: 75.42	TNR_HS: 86.35
# LossALL: 0.583549	TPRALL: 77.02	TNRALL: 86.09
# Time: 109.52
#
# Epoch:58
# ValLoss_MF: 0.591920	TPR_MF: 76.87	TNR_MF: 85.37
# ValLoss_FF: 0.645383	TPR_FF: 70.43	TNR_FF: 85.06
# ValLoss_HS: 0.563261	TPR_HS: 77.03	TNR_HS: 86.00
# ValLossALL: 0.600188	TPRALL: 76.87	TNRALL: 85.37
# Time: 4.59
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 59
# Loss_MF: 0.571533	TPR_MF: 74.35	TNR_MF: 86.49
# Loss_FF: 0.617669	TPR_FF: 75.82	TNR_FF: 85.76
# Loss_HS: 0.557527	TPR_HS: 78.52	TNR_HS: 85.94
# LossALL: 0.582395	TPRALL: 77.38	TNRALL: 86.06
# Time: 109.36
#
# Epoch:59
# ValLoss_MF: 0.590590	TPR_MF: 73.35	TNR_MF: 87.52
# ValLoss_FF: 0.558524	TPR_FF: 73.73	TNR_FF: 87.19
# ValLoss_HS: 0.521828	TPR_HS: 77.70	TNR_HS: 87.18
# ValLossALL: 0.556981	TPRALL: 73.73	TNRALL: 87.19
# Time: 4.59
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 60
# Loss_MF: 0.561979	TPR_MF: 74.69	TNR_MF: 87.08
# Loss_FF: 0.601070	TPR_FF: 75.04	TNR_FF: 86.79
# Loss_HS: 0.570170	TPR_HS: 76.21	TNR_HS: 85.82
# LossALL: 0.578219	TPRALL: 75.20	TNRALL: 86.47
# Time: 110.93
#
# Epoch:60
# ValLoss_MF: 0.603617	TPR_MF: 76.28	TNR_MF: 86.77
# ValLoss_FF: 0.564784	TPR_FF: 76.18	TNR_FF: 86.77
# ValLoss_HS: 0.525338	TPR_HS: 78.32	TNR_HS: 86.66
# ValLossALL: 0.564580	TPRALL: 76.28	TNRALL: 86.77
# Time: 4.57
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 61
# Loss_MF: 0.567042	TPR_MF: 74.26	TNR_MF: 85.72
# Loss_FF: 0.598599	TPR_FF: 70.93	TNR_FF: 86.27
# Loss_HS: 0.558663	TPR_HS: 75.85	TNR_HS: 86.91
# LossALL: 0.574912	TPRALL: 74.05	TNRALL: 86.30
# Time: 109.23
#
# Epoch:61
# ValLoss_MF: 0.526206	TPR_MF: 79.92	TNR_MF: 85.36
# ValLoss_FF: 0.604905	TPR_FF: 76.44	TNR_FF: 85.44
# ValLoss_HS: 0.548145	TPR_HS: 82.62	TNR_HS: 85.71
# ValLossALL: 0.559752	TPRALL: 79.92	TNRALL: 85.44
# Time: 4.73
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 62
# Loss_MF: 0.560732	TPR_MF: 76.37	TNR_MF: 86.98
# Loss_FF: 0.602654	TPR_FF: 73.65	TNR_FF: 87.08
# Loss_HS: 0.559722	TPR_HS: 76.60	TNR_HS: 86.97
# LossALL: 0.574905	TPRALL: 76.23	TNRALL: 87.04
# Time: 109.89
#
# Epoch:62
# ValLoss_MF: 0.592368	TPR_MF: 73.09	TNR_MF: 85.75
# ValLoss_FF: 0.564543	TPR_FF: 76.67	TNR_FF: 86.01
# ValLoss_HS: 0.543737	TPR_HS: 77.94	TNR_HS: 86.06
# ValLossALL: 0.566883	TPRALL: 76.67	TNRALL: 86.01
# Time: 4.58
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 63
# Loss_MF: 0.553990	TPR_MF: 76.79	TNR_MF: 86.58
# Loss_FF: 0.604665	TPR_FF: 76.76	TNR_FF: 86.76
# Loss_HS: 0.552240	TPR_HS: 77.29	TNR_HS: 86.53
# LossALL: 0.570590	TPRALL: 76.79	TNRALL: 86.59
# Time: 110.91
#
# Epoch:63
# ValLoss_MF: 0.562513	TPR_MF: 74.82	TNR_MF: 87.96
# ValLoss_FF: 0.601784	TPR_FF: 71.40	TNR_FF: 87.58
# ValLoss_HS: 0.575257	TPR_HS: 71.43	TNR_HS: 87.68
# ValLossALL: 0.579851	TPRALL: 71.43	TNRALL: 87.68
# Time: 4.48
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 64
# Loss_MF: 0.555937	TPR_MF: 77.08	TNR_MF: 86.60
# Loss_FF: 0.589258	TPR_FF: 72.59	TNR_FF: 86.88
# Loss_HS: 0.563882	TPR_HS: 75.38	TNR_HS: 86.16
# LossALL: 0.570127	TPRALL: 75.38	TNRALL: 86.58
# Time: 111.86
#
# Epoch:64
# ValLoss_MF: 0.595983	TPR_MF: 78.85	TNR_MF: 84.42
# ValLoss_FF: 0.678291	TPR_FF: 72.13	TNR_FF: 84.30
# ValLoss_HS: 0.636570	TPR_HS: 71.91	TNR_HS: 84.20
# ValLossALL: 0.636948	TPRALL: 72.13	TNRALL: 84.30
# Time: 4.70
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 65
# Loss_MF: 0.566335	TPR_MF: 75.78	TNR_MF: 86.77
# Loss_FF: 0.597964	TPR_FF: 75.00	TNR_FF: 86.68
# Loss_HS: 0.568722	TPR_HS: 77.42	TNR_HS: 85.88
# LossALL: 0.578185	TPRALL: 76.27	TNRALL: 86.53
# Time: 110.30
#
# Epoch:65
# ValLoss_MF: 0.572013	TPR_MF: 74.96	TNR_MF: 85.58
# ValLoss_FF: 0.566173	TPR_FF: 77.66	TNR_FF: 86.08
# ValLoss_HS: 0.576614	TPR_HS: 73.64	TNR_HS: 86.04
# ValLossALL: 0.571600	TPRALL: 74.96	TNRALL: 86.04
# Time: 4.56
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 66
# Loss_MF: 0.572472	TPR_MF: 73.79	TNR_MF: 85.94
# Loss_FF: 0.613875	TPR_FF: 75.09	TNR_FF: 85.50
# Loss_HS: 0.556665	TPR_HS: 77.31	TNR_HS: 86.30
# LossALL: 0.581030	TPRALL: 75.49	TNRALL: 86.12
# Time: 109.48
#
# Epoch:66
# ValLoss_MF: 0.568730	TPR_MF: 75.42	TNR_MF: 86.40
# ValLoss_FF: 0.634627	TPR_FF: 72.96	TNR_FF: 86.70
# ValLoss_HS: 0.573364	TPR_HS: 73.74	TNR_HS: 86.25
# ValLossALL: 0.592240	TPRALL: 73.74	TNRALL: 86.40
# Time: 4.65
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 67
# Loss_MF: 0.563978	TPR_MF: 74.83	TNR_MF: 86.84
# Loss_FF: 0.595742	TPR_FF: 76.61	TNR_FF: 86.69
# Loss_HS: 0.555652	TPR_HS: 77.26	TNR_HS: 86.25
# LossALL: 0.571940	TPRALL: 76.38	TNRALL: 86.63
# Time: 109.95
#
# Epoch:67
# ValLoss_MF: 0.555685	TPR_MF: 82.01	TNR_MF: 86.27
# ValLoss_FF: 0.644949	TPR_FF: 70.81	TNR_FF: 85.99
# ValLoss_HS: 0.528389	TPR_HS: 78.57	TNR_HS: 86.13
# ValLossALL: 0.576341	TPRALL: 78.57	TNRALL: 86.13
# Time: 4.65
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 68
# Loss_MF: 0.561652	TPR_MF: 75.70	TNR_MF: 86.91
# Loss_FF: 0.607877	TPR_FF: 70.23	TNR_FF: 86.65
# Loss_HS: 0.568773	TPR_HS: 74.24	TNR_HS: 86.77
# LossALL: 0.579932	TPRALL: 74.44	TNRALL: 86.77
# Time: 111.67
#
# Epoch:68
# ValLoss_MF: 0.611651	TPR_MF: 72.50	TNR_MF: 88.13
# ValLoss_FF: 0.564059	TPR_FF: 78.07	TNR_FF: 88.63
# ValLoss_HS: 0.512876	TPR_HS: 78.42	TNR_HS: 88.54
# ValLossALL: 0.562862	TPRALL: 78.07	TNRALL: 88.54
# Time: 4.62
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 69
# Loss_MF: 0.568329	TPR_MF: 74.18	TNR_MF: 87.08
# Loss_FF: 0.599461	TPR_FF: 75.48	TNR_FF: 86.87
# Loss_HS: 0.564739	TPR_HS: 75.82	TNR_HS: 86.29
# LossALL: 0.577369	TPRALL: 75.37	TNRALL: 86.79
# Time: 112.50
#
# Epoch:69
# ValLoss_MF: 0.525746	TPR_MF: 78.24	TNR_MF: 85.56
# ValLoss_FF: 0.569774	TPR_FF: 76.66	TNR_FF: 86.07
# ValLoss_HS: 0.509142	TPR_HS: 83.11	TNR_HS: 86.00
# ValLossALL: 0.534887	TPRALL: 78.24	TNRALL: 86.00
# Time: 4.52
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 70
# Loss_MF: 0.559606	TPR_MF: 76.61	TNR_MF: 86.80
# Loss_FF: 0.578992	TPR_FF: 77.50	TNR_FF: 86.74
# Loss_HS: 0.564204	TPR_HS: 75.09	TNR_HS: 86.83
# LossALL: 0.568021	TPRALL: 75.92	TNRALL: 86.78
# Time: 109.81
#
# Epoch:70
# ValLoss_MF: 0.599194	TPR_MF: 69.37	TNR_MF: 86.61
# ValLoss_FF: 0.599505	TPR_FF: 76.17	TNR_FF: 87.26
# ValLoss_HS: 0.540525	TPR_HS: 75.50	TNR_HS: 86.82
# ValLossALL: 0.579741	TPRALL: 75.50	TNRALL: 86.82
# Time: 4.71
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 71
# Loss_MF: 0.565622	TPR_MF: 75.18	TNR_MF: 86.36
# Loss_FF: 0.615976	TPR_FF: 73.16	TNR_FF: 86.49
# Loss_HS: 0.562214	TPR_HS: 76.28	TNR_HS: 86.29
# LossALL: 0.581840	TPRALL: 75.60	TNRALL: 86.39
# Time: 109.78
#
# Epoch:71
# ValLoss_MF: 0.557492	TPR_MF: 79.60	TNR_MF: 85.97
# ValLoss_FF: 0.569700	TPR_FF: 76.95	TNR_FF: 85.77
# ValLoss_HS: 0.558343	TPR_HS: 78.05	TNR_HS: 85.62
# ValLossALL: 0.561845	TPRALL: 78.05	TNRALL: 85.77
# Time: 4.62
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 72
# Loss_MF: 0.555942	TPR_MF: 76.09	TNR_MF: 86.30
# Loss_FF: 0.600009	TPR_FF: 72.71	TNR_FF: 86.65
# Loss_HS: 0.552683	TPR_HS: 75.96	TNR_HS: 87.03
# LossALL: 0.569416	TPRALL: 75.56	TNRALL: 86.84
# Time: 112.34
#
# Epoch:72
# ValLoss_MF: 0.574145	TPR_MF: 76.85	TNR_MF: 87.21
# ValLoss_FF: 0.583636	TPR_FF: 73.43	TNR_FF: 87.12
# ValLoss_HS: 0.604643	TPR_HS: 72.28	TNR_HS: 86.81
# ValLossALL: 0.587475	TPRALL: 73.43	TNRALL: 87.12
# Time: 4.49
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 73
# Loss_MF: 0.562381	TPR_MF: 75.14	TNR_MF: 87.07
# Loss_FF: 0.617551	TPR_FF: 73.04	TNR_FF: 86.54
# Loss_HS: 0.575193	TPR_HS: 75.14	TNR_HS: 85.84
# LossALL: 0.585751	TPRALL: 75.09	TNRALL: 86.58
# Time: 111.17
#
# Epoch:73
# ValLoss_MF: 0.566925	TPR_MF: 72.66	TNR_MF: 89.57
# ValLoss_FF: 0.569917	TPR_FF: 68.83	TNR_FF: 89.25
# ValLoss_HS: 0.560529	TPR_HS: 66.42	TNR_HS: 89.34
# ValLossALL: 0.565790	TPRALL: 68.83	TNRALL: 89.34
# Time: 4.44
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 74
# Loss_MF: 0.557286	TPR_MF: 76.89	TNR_MF: 86.89
# Loss_FF: 0.590643	TPR_FF: 73.25	TNR_FF: 86.46
# Loss_HS: 0.556474	TPR_HS: 76.70	TNR_HS: 86.33
# LossALL: 0.568319	TPRALL: 76.46	TNRALL: 86.46
# Time: 110.73
#
# Epoch:74
# ValLoss_MF: 0.642230	TPR_MF: 71.86	TNR_MF: 87.14
# ValLoss_FF: 0.584237	TPR_FF: 75.18	TNR_FF: 87.42
# ValLoss_HS: 0.577711	TPR_HS: 70.68	TNR_HS: 86.83
# ValLossALL: 0.601393	TPRALL: 71.86	TNRALL: 87.14
# Time: 4.55
# EarlyStopping counter: 20 out of 20
#
# Early stopping
