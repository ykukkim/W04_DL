# %% [markdown]
# # Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  # %cd /content/drive/MyDrive/Deep_learning/Deep\ Learning
# Out:
# /content/drive/MyDrive/Deep_learning/Deep Learning

# %% [markdown]
# # Libraries

# %%
#Importing Libraries and Packages
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, IterableDataset
from torch.utils.tensorboard import SummaryWriter

# calculate train time, writing train data to files etc.
import os
import logging
import pandas as pd
import numpy as np
import time
from collections import defaultdict
from sklearn.preprocessing import MinMaxScaler
from pathlib import Path
from random import randint
from scipy import signal

import pdb

# %% [markdown]
# # Dataset

# %%
# Data split
class Split_data:

    def __init__(self, dir_path: str, frequency: str, random_seed: str):

        self.directory = dir_path
        self.random_seed = random_seed
        self.frequency = frequency

    def splitset(self, split_ratio, shuffle_dataset=True):
        train_idx = defaultdict(list)
        val_idx = defaultdict(list)
        indices_idx = 0
        ratio_idx = 0
        for root, subdir, files in os.walk(self.directory):
            if "desktop.ini" in files: files.remove('desktop.ini')
            dataset_size = len(files)
            if dataset_size > 0:
                indices = list(range(dataset_size - 1))
                split = int(np.floor(split_ratio[ratio_idx] * len(files)))
                for i in range(self.frequency):
                    if shuffle_dataset:
                        np.random.shuffle(indices)
                    train_idx[indices_idx].append(indices[split:])
                    val_idx[indices_idx].append(indices[:split])
                ratio_idx += 1
                indices_idx += 1

        return train_idx, val_idx

class CoolDataset(IterableDataset):

    def __init__(self, dir_path: str, input_size: str, seq_length: str, samples_per_events: str, indices, trainorval: str,
                 convolution=True):

        super().__init__()
        self.files = tuple(Path(dir_path).glob("**/*.csv"))
        self.indices = indices
        self.seq_length = seq_length
        self.input_size = input_size
        self.SAMPLES_PER_EVENT = samples_per_events
        self.window = signal.gaussian(8, std=3)
        self.convolution = convolution
        self.trainorval  = trainorval
        self.scaler = MinMaxScaler(feature_range=(0,1))

        assert seq_length % 2 == 0, "Please pass an even seq length"

    def __iter__(self):

        # Initialise Counter for events and files
        self.file_nr = 0
        self.event_in_file = 0
        self._sample_nr = 0

        return self

    def __next__(self):
        # Reads the current file and looks for event
        df, fname = self.read_file(self.files[self.indices[self.file_nr]])  # could be cached so you dont read it anew every iteration
        if len(df) >= self.seq_length:
            events = df[df["FO"] == 1]
            if df['class'][0] == 3 and self.trainorval == 'train':
                self.SAMPLES_PER_EVENT = 4

            if events.shape[0] > 0:

                if self._sample_nr < self.SAMPLES_PER_EVENT:
                    # just give back the current event again, with different sampling, until we have generated
                    # SAMPLES_PER_EVENT such samples
                    event_frame = events.iloc[self.event_in_file].name
                    input_data, output_data = self.sample_seq_around_event_frame(df, event_frame)
                    self._sample_nr += 1

                elif self._sample_nr == self.SAMPLES_PER_EVENT:

                    self.event_in_file += 1  # work on the next event in this file
                    self._sample_nr = 0  # reset for the next event

                    # check whether we are done with this file
                    # otherwise we return the next event on the beginning of the next iteration
                    if self.event_in_file >= len(events):
                        self.file_nr += 1
                        # If there still are files to run, it resets the variables
                        if self.file_nr < len(self.indices):
                            logging.info("File is complete. Going to new file...")
                            self.event_in_file = 0
                            self._sample_nr = 0
                            return next(self)
                        else:
                            # processed the last file, we are done
                            logging.info("File is complete. All files done. Stopping...")
                            raise StopIteration
                    elif self.event_in_file < len(events):
                        event_frame = events.iloc[self.event_in_file].name
                        input_data, output_data = self.sample_seq_around_event_frame(df, event_frame)
                        self._sample_nr += 1

            else:
                logging.info("No events detected")
                self.file_nr += 1
                self.event_in_file = 0
                self._sample_nr = 0
                return next(self)

        else:
            logging.info("data length is too short")
            self.file_nr += 1
            self.event_in_file = 0
            self._sample_nr = 0
            return next(self)
        return input_data, output_data

    def sample_seq_around_event_frame(self, df, event_idx):
        if event_idx >= 4:
            start_idx = event_idx - randint(4, self.seq_length / 7.5)
            if start_idx > 0:
                end_idx = start_idx + self.seq_length
                if end_idx <= len(df):
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
                elif end_idx > len(df):
                    end_idx = len(df)
                    start_idx = end_idx - self.seq_length
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
            elif start_idx <= 4:
                start_idx = event_idx
                end_idx = start_idx + self.seq_length
                input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                output = df.iloc[start_idx:end_idx]['FO']
                if end_idx <= len(df):
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']
                elif end_idx > len(df):
                    end_idx = len(df)
                    start_idx = end_idx - self.seq_length
                    input = df.iloc[start_idx:end_idx, 1:self.input_size + 1]
                    output = df.iloc[start_idx:end_idx]['FO']

        if self.convolution:
            output = signal.convolve(output, self.window, mode='same')
        #  Standardising the input
        input = self.scaler.fit_transform(input)
        
        assert input.shape[0] == output.shape[0] == self.seq_length
        return torch.tensor(input), torch.tensor(output)

    def read_file(self, f):
        df = pd.read_csv(open(f, "r"))
        fname = os.path.basename(f)
        if fname[0:2] == 'RT':
            df = df.drop(['ID',
                          # 'class',
                          #'RTOE_X', 'RTOE_Y', 'RTOE_Z', 'V_RTOE_X', 'V_RTOE_Y', 'V_RTOE_Z',
                          #'RHLX_X', 'RHLX_Y', 'RHLX_Z', 'V_RHLX_X', 'V_RHLX_Y', 'V_RHLX_Z',
                          #'RHEE_X', 'RHEE_Y', 'RHEE_Z', 'V_RHEE_X', 'V_RHEE_Y', 'V_RHEE_Z',
                          'RPMT5_X', 'RPMT5_Y', 'RPMT5_Z', 'V_RPMT5_X', 'V_RPMT5_Y', 'V_RPMT5_Z'
                          ], axis=1)
        elif fname[0:2] == 'LT':
            df = df.drop(['ID',
                          # 'class',
                          #'LTOE_X', 'LTOE_Y', 'LTOE_Z', 'V_LTOE_X', 'V_LTOE_Y', 'V_LTOE_Z',
                          #'LHLX_X', 'LHLX_Y', 'LHLX_Z', 'V_LHLX_X', 'V_LHLX_Y', 'V_LHLX_Z',
                          #'LHEE_X', 'LHEE_Y', 'LHEE_Z', 'V_LHEE_X', 'V_LHEE_Y', 'V_LHEE_Z',
                          'LPMT5_X', 'LPMT5_Y', 'LPMT5_Z', 'V_LPMT5_X', 'V_LPMT5_Y', 'V_LPMT5_Z',
                          ], axis=1)
        return df, fname

# %% [markdown]
# # Model

# %%
class Network(nn.Module):
    # TO DO
    def __init__(self, config,hidden_size,num_layers,drop_out):
        super(Network, self).__init__()

        # Model construct Configuration
        self.batch_size  = config.batch_size
        self.num_layers  = num_layers
        self.hidden_size = hidden_size
        self.device      = config.device

        self.lstm = nn.LSTM(config.input_size, hidden_size, num_layers, dropout=drop_out, batch_first=True,
                            bidirectional=True)
        self.linear = nn.Linear(hidden_size * 2, config.output_size, bias=True)
        torch.nn.init.xavier_uniform_(self.linear.weight)

    def forward(self, x):
        hidden, cell = self.init_hidden()
        out, _ = self.lstm(x, (hidden, cell))
        logits = self.linear(out)

        return logits[:, :, -1]

    def init_hidden(self):
        weight = next((self.parameters())).data
        hidden, cell = (weight.new(self.num_layers * 2, self.batch_size, self.hidden_size).zero_().to(self.device),
                        weight.new(self.num_layers * 2, self.batch_size, self.hidden_size).zero_().to(self.device))
        return hidden, cell

# %% [markdown]
# # Early Stop

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""

    # def __init__(self, patience: str,, delta: str, Name: str, verbose=False):
    def __init__(self, config, patience: str, delta: str, Name: str, verbose=False, ):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path_dir = config.isdirectory_result
        self.type_ICTO = config.type_ICTO
        self.noofmarkers = config.noofmarkers
        self.combination = config.combination
        self.name = Name

    def __call__(self, val_loss, TPR_CP, TNR_CP, model, config,name):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

            ROC = pd.DataFrame({'TPR_MF': pd.Series(TPR_CP[0]), 'TNR_MF': pd.Series(TNR_CP[0]),
                                'TPR_FF': pd.Series(TPR_CP[1]), 'TNR_FF': pd.Series(TNR_CP[1]),
                                'TPR_HS': pd.Series(TPR_CP[2]), 'TNR_HS': pd.Series(TNR_CP[2])})
            isExist_csv = os.path.exists(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/")
            if not isExist_csv:
              os.makedirs(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/")
            # csv file save
            ROC.to_csv(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/{name}-ROC.csv",index=False)

        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}\n')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0
            ROC = pd.DataFrame({'TPR_MF': pd.Series(TPR_CP[0]), 'TNR_MF': pd.Series(TNR_CP[0]),
                                'TPR_FF': pd.Series(TPR_CP[1]), 'TNR_FF': pd.Series(TNR_CP[1]),
                                'TPR_HS': pd.Series(TPR_CP[2]), 'TNR_HS': pd.Series(TNR_CP[2])})

            ROC.to_csv(f"{config.isdirectory_result}/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/v1/models/csv/{name}-ROC.csv", mode='a', header=False, index=False)

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        filepath = f"{self.path_dir}/{self.type_ICTO}/{self.noofmarkers}/{self.combination}/v1/models/CheckPoint/"
        isExist = os.path.exists(filepath)
        if not isExist:
            os.makedirs(filepath)
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model\n')
            torch.save(model.state_dict(), os.path.join(filepath, f"{self.name}-FOcheckpoint.pt"), _use_new_zipfile_serialization=False)

        self.val_loss_min = val_loss

# %% [markdown]
# # Training and Validation

# %%
 class Trainer:

    def __init__(self, hidden_size, num_layers, drop_out, lr, epochs, config):

        # System configuration
        self.validation_split = config.validation_split
        self.log_interval = config.log_interval
        self.isdirectory = config.isdirectory
        self.device = config.device
        self.seed = config.seed

        # Model Construction
        self.input_size = config.input_size
        self.batch_size = config.batch_size
        self.seq_length = config.seq_length
        self.samples_per_event = config.samples_per_event
        self.lr = lr

        self.model = Network(config, hidden_size, num_layers, drop_out).to(self.device)
        self.model = self.model.to(self.device)
        print(self.model)

        # Optimizer and Loss
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.BCEWithLogitsLoss(pos_weight=config.weight_factor).to(self.device)

        # Initialise the early_stopping object
        self.name = f"TO-{hidden_size}-HS-{num_layers}-NL-{lr}-LR-{drop_out}-DO"
        self.early_stopping = EarlyStopping(config, patience=model_config.patience, verbose=True,
                                            delta=model_config.delta, Name=self.name)
        print(self.name)

        # DataLoader
        dataset = Split_data(self.isdirectory, epochs, torch.manual_seed(self.seed))
        self.train_idx, self.val_idx = dataset.splitset(self.validation_split)
        self.train_loader = defaultdict(list)
        self.val_loader = defaultdict(list)

        # Tensorboard
        self.globaliter = 0
        train_log_dir = f"{config.isdirectory_result}/logs/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/train/" + self.name
        val_log_dir = f"{config.isdirectory_result}/logs/{config.type_ICTO}/{config.noofmarkers}/{config.combination}/val/" + self.name
        self.train_summary_writer = SummaryWriter(train_log_dir)
        self.val_summary_writer = SummaryWriter(val_log_dir)

    def train(self, epoch):

        self.model.train()
        TPR_internal_final = defaultdict(list)
        TNR_internal_final = defaultdict(list)
        loss_final = defaultdict(list)
        start_train = time.time()
        subdir_idx = 0
        with self.train_summary_writer:
            for root, subdir, files in os.walk(self.isdirectory):
                if "desktop.ini" in files: files.remove('desktop.ini')
                if len(files) > 0:
                    train_loader = DataLoader(
                        CoolDataset(root, self.input_size, self.seq_length, self.samples_per_event,
                                    self.train_idx[subdir_idx][epoch], 'train'), batch_size=self.batch_size,
                        drop_last=True, shuffle=False)
                    for batch_idx, (data, target) in enumerate(train_loader):
                        self.optimizer.zero_grad()
                        data, target = data.to(self.device), target.to(self.device)
                        predictions = self.model(data.float()).to(self.device)
                        loss = self.criterion(predictions.float(), target.float())
                        loss.backward()

                        self.optimizer.step()
                        pred = torch.sigmoid(predictions.detach())
                        correct_indx_positive = pred[target > 0.5]  # Should have batch_size * 1's
                        correct_indx_negative = pred[target <= 0.5]  # Should have (batch_size*seq_length-batch_size) * 0'

                        TPR_internal = len(correct_indx_positive[correct_indx_positive > 0.5]) / len(
                            correct_indx_positive)
                        TNR_internal = len(correct_indx_negative[correct_indx_negative <= 0.5]) / len(
                            correct_indx_negative)
                        TPR_internal = TPR_internal * 100
                        TNR_internal = TNR_internal * 100

                        TPR_internal_final[subdir_idx].append(TPR_internal)
                        TNR_internal_final[subdir_idx].append(TNR_internal)
                        loss_final[subdir_idx].append(loss.item())

                        self.globaliter += 1

                        if batch_idx % self.log_interval == 0:
                            self.train_summary_writer.add_scalar('Loss', loss.item(), self.globaliter)
                    subdir_idx += 1

            return loss_final, TPR_internal_final, TNR_internal_final, (time.time() - start_train)

    def val(self, epoch):
        self.model.eval()
        TPR_internal_final_val = defaultdict(list)
        TNR_internal_final_val = defaultdict(list)
        val_loss_final = defaultdict(list)
        start_time_val = time.time()
        subdir_idx_val = 0

        with self.val_summary_writer:
            with torch.no_grad():
                for root, subdir, files in os.walk(self.isdirectory):
                    if "desktop.ini" in files: files.remove('desktop.ini')
                    if len(files) > 0:
                        val_loader = DataLoader(
                            CoolDataset(root, self.input_size, self.seq_length, self.samples_per_event,
                                        self.val_idx[subdir_idx_val][epoch], 'val'), batch_size=self.batch_size,
                            drop_last=True, shuffle=False)
                        for batch_idx, (data, target) in enumerate(val_loader):
                            data, target = data.to(self.device), target.to(self.device)
                            predictions = self.model(data.float())
                            val_loss = self.criterion(predictions.float(), target.float())
                            pred = torch.sigmoid(predictions.detach())

                            correct_indx_positive = pred[target > 0.5]  # Should have batch_size * 1's
                            correct_indx_negative = pred[
                                target <= 0.5]  # Should have (batch_size*seq_length-batch_size) * 0'
                            TPR_internal_val = len(correct_indx_positive[correct_indx_positive > 0.5]) / len(
                                correct_indx_positive)
                            TNR_internal_val = len(correct_indx_negative[correct_indx_negative <= 0.5]) / len(
                                correct_indx_negative)
                            TPR_internal_val = TPR_internal_val * 100
                            TNR_internal_val = TNR_internal_val * 100

                            TPR_internal_final_val[subdir_idx_val].append(TPR_internal_val)
                            TNR_internal_final_val[subdir_idx_val].append(TNR_internal_val)
                            val_loss_final[subdir_idx_val].append(val_loss.item())

                        self.val_summary_writer.add_scalar('val_loss', val_loss.item(), self.globaliter)
                        subdir_idx_val += 1
                return val_loss_final, TPR_internal_final_val, TNR_internal_final_val, (
                                    time.time() - start_time_val), self.name

# %% [markdown]
# # Hyperparmeter Setting

# %%
def main(hparam, model_config):
    for lr in hparam['lr']:
        for hidden_size in hparam['hidden_size']:
            for num_layers in hparam['num_layers']:
                for drop_out in hparam['drop_out']:
                    for epochs in hparam['epochs']:
                        trainer = Trainer(hidden_size, num_layers, drop_out, lr, epochs, model_config)
                        TPR = dict()
                        TNR = dict()
                        for epoch in range(epochs):
                            loss_train, TPR_train, TNR_train, train_time = trainer.train(epoch)
                            print('\nEpoch: {}\n'
                                  'Loss_MF: {:.6f}\tTPR_MF: {:.2f}\tTNR_MF: {:.2f}\n'
                                  'Loss_FF: {:.6f}\tTPR_FF: {:.2f}\tTNR_FF: {:.2f}\n'
                                  'Loss_HS: {:.6f}\tTPR_HS: {:.2f}\tTNR_HS: {:.2f}\n'
                                  'LossALL: {:.6f}\tTPRALL: {:.2f}\tTNRALL: {:.2f}\n''Time: {:.2f} '.format(epoch, np.mean(loss_train[0]), np.median(TPR_train[0]),np.median(TNR_train[0]),
                                                                                                           np.mean(loss_train[1]), np.median(TPR_train[1]), np.median(TNR_train[1]),
                                                                                                           np.mean(loss_train[2]), np.median(TPR_train[2]),np.median(TNR_train[2]),
                                                                                                           np.mean(loss_train[0]+loss_train[1]+loss_train[2]),np.median(TPR_train[0]+TPR_train[1]+TPR_train[2]),np.median(TNR_train[0]+TNR_train[1]+TNR_train[2]),
                                                                                                           train_time))

                            val_loss, TPR[epoch], TNR[epoch], val_time, name = trainer.val(epoch)
                            print('\nEpoch:{}\n'
                                  'ValLoss_MF: {:.6f}\tTPR_MF: {:.2f}\tTNR_MF: {:.2f}\n'
                                  'ValLoss_FF: {:.6f}\tTPR_FF: {:.2f}\tTNR_FF: {:.2f}\n'
                                  'ValLoss_HS: {:.6f}\tTPR_HS: {:.2f}\tTNR_HS: {:.2f}\n'
                                  'ValLossALL: {:.6f}\tTPRALL: {:.2f}\tTNRALL: {:.2f}\n''Time: {:.2f} '.format(epoch, np.mean(val_loss[0]), np.median(TPR[epoch][0]),np.median(TNR[epoch][0]),
                                                                                                           np.mean(val_loss[1]), np.median(TPR[epoch][1]), np.median(TNR[epoch][1]),
                                                                                                           np.mean(val_loss[2]), np.median(TPR[epoch][2]),np.median(TNR[epoch][2]),
                                                                                                           np.mean(val_loss[0]+val_loss[1]+val_loss[2]), np.median(TPR[epoch][0]+TPR[epoch][1]+TPR[epoch][2]),np.median(TNR[epoch][0]+TNR[epoch][1]+TNR[epoch][2]),
                                                                                                           val_time))
                            trainer.early_stopping(np.mean(val_loss[0]+val_loss[1]+val_loss[2]), TPR[epoch], TNR[epoch], trainer.model, model_config,name)
                            if trainer.early_stopping.early_stop:
                                print("Early stopping")
                                break

# %% [markdown]
# # Main

# %%
 class Config:

    def __init__(self, **kwargs):
        for key, value in kwargs.items():
            setattr(self, key, value)

if __name__ == '__main__':

    if torch.cuda.is_available():
        device = torch.device("cuda")
        print("Running on the GPU")
    else:
        device = torch.device("cpu")
        print("Running on the CPU")

    model_config = Config(
        device=device,
        # Early Stop
        patience=20,
        delta=0.01,
        log_interval=100,
        # Dataset Configuration
        validation_split=[0.075, 0.25, 0.065],
        seed=253,
        samples_per_event=1,
        output_size=1,
        # Weight factor
        weight_factor=torch.tensor(11),
        # Directory
        isdirectory        = r"/content/drive/MyDrive/Deep_learning/Deep Learning/Data/iteration3/Train",
        isdirectory_result = r"/content/drive/MyDrive/Deep_learning/Deep Learning/Results/LSTM",
        type_ICTO          = r"TO",
        noofmarkers        = r"3markers",
        combination        = r"HLXTOE5HEE",
        # Model Consturction
        input_size=18,
        batch_size=64,
        seq_length=150,
    )

    hparam = {
        'hidden_size': [256,512,1024],
        'num_layers': [2,5,10],
        'drop_out': [0.3],
        'lr': [0.0001],
        'epochs': [150],
    }

    main(hparam, model_config)
# Out:
# Streaming output truncated to the last 5000 lines.
# Time: 4.25
# Validation loss decreased (0.516310 --> 0.338194).  Saving model
#
#
# Epoch: 2
# Loss_MF: 0.278857	TPR_MF: 95.98	TNR_MF: 92.90
# Loss_FF: 0.385099	TPR_FF: 91.33	TNR_FF: 92.27
# Loss_HS: 0.233517	TPR_HS: 94.40	TNR_HS: 95.85
# LossALL: 0.297750	TPRALL: 94.33	TNRALL: 93.88
# Time: 67.30
#
# Epoch:2
# ValLoss_MF: 0.264106	TPR_MF: 89.83	TNR_MF: 95.52
# ValLoss_FF: 0.261082	TPR_FF: 91.07	TNR_FF: 94.55
# ValLoss_HS: 0.182507	TPR_HS: 97.48	TNR_HS: 95.47
# ValLossALL: 0.235898	TPRALL: 91.07	TNRALL: 95.47
# Time: 4.39
# Validation loss decreased (0.338194 --> 0.235898).  Saving model
#
#
# Epoch: 3
# Loss_MF: 0.228882	TPR_MF: 94.18	TNR_MF: 95.06
# Loss_FF: 0.341486	TPR_FF: 92.21	TNR_FF: 93.80
# Loss_HS: 0.211348	TPR_HS: 96.45	TNR_HS: 95.95
# LossALL: 0.260855	TPRALL: 95.12	TNRALL: 94.86
# Time: 67.58
#
# Epoch:3
# ValLoss_MF: 0.238981	TPR_MF: 92.62	TNR_MF: 95.45
# ValLoss_FF: 0.438367	TPR_FF: 84.55	TNR_FF: 94.80
# ValLoss_HS: 0.192234	TPR_HS: 95.19	TNR_HS: 96.10
# ValLossALL: 0.289860	TPRALL: 92.62	TNRALL: 95.45
# Time: 4.32
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 4
# Loss_MF: 0.224425	TPR_MF: 94.02	TNR_MF: 95.35
# Loss_FF: 0.304739	TPR_FF: 95.41	TNR_FF: 93.93
# Loss_HS: 0.199722	TPR_HS: 96.36	TNR_HS: 96.34
# LossALL: 0.242839	TPRALL: 95.07	TNRALL: 95.19
# Time: 67.16
#
# Epoch:4
# ValLoss_MF: 0.207808	TPR_MF: 94.05	TNR_MF: 96.38
# ValLoss_FF: 0.470063	TPR_FF: 82.52	TNR_FF: 95.35
# ValLoss_HS: 0.191197	TPR_HS: 94.24	TNR_HS: 96.42
# ValLossALL: 0.289689	TPRALL: 94.05	TNRALL: 96.38
# Time: 4.43
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 5
# Loss_MF: 0.214952	TPR_MF: 93.89	TNR_MF: 95.34
# Loss_FF: 0.326376	TPR_FF: 93.47	TNR_FF: 94.35
# Loss_HS: 0.196316	TPR_HS: 95.61	TNR_HS: 96.68
# LossALL: 0.246127	TPRALL: 94.99	TNRALL: 95.27
# Time: 67.65
#
# Epoch:5
# ValLoss_MF: 0.287233	TPR_MF: 88.74	TNR_MF: 96.42
# ValLoss_FF: 0.345747	TPR_FF: 87.10	TNR_FF: 95.91
# ValLoss_HS: 0.198620	TPR_HS: 95.76	TNR_HS: 96.50
# ValLossALL: 0.277200	TPRALL: 88.74	TNRALL: 96.42
# Time: 4.27
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 6
# Loss_MF: 0.211300	TPR_MF: 96.18	TNR_MF: 95.39
# Loss_FF: 0.319243	TPR_FF: 90.71	TNR_FF: 94.77
# Loss_HS: 0.198238	TPR_HS: 95.62	TNR_HS: 96.53
# LossALL: 0.243951	TPRALL: 95.27	TNRALL: 95.49
# Time: 66.54
#
# Epoch:6
# ValLoss_MF: 0.270178	TPR_MF: 91.01	TNR_MF: 96.32
# ValLoss_FF: 0.414449	TPR_FF: 83.60	TNR_FF: 95.83
# ValLoss_HS: 0.162593	TPR_HS: 96.20	TNR_HS: 96.55
# ValLossALL: 0.282407	TPRALL: 91.01	TNRALL: 96.32
# Time: 4.45
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 7
# Loss_MF: 0.202559	TPR_MF: 95.31	TNR_MF: 95.41
# Loss_FF: 0.329394	TPR_FF: 89.82	TNR_FF: 94.58
# Loss_HS: 0.194000	TPR_HS: 96.25	TNR_HS: 96.36
# LossALL: 0.243419	TPRALL: 95.36	TNRALL: 95.31
# Time: 67.07
#
# Epoch:7
# ValLoss_MF: 0.268790	TPR_MF: 87.79	TNR_MF: 96.67
# ValLoss_FF: 0.396973	TPR_FF: 81.75	TNR_FF: 96.38
# ValLoss_HS: 0.217367	TPR_HS: 92.05	TNR_HS: 96.70
# ValLossALL: 0.294377	TPRALL: 87.79	TNRALL: 96.67
# Time: 4.37
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 8
# Loss_MF: 0.209115	TPR_MF: 94.25	TNR_MF: 95.54
# Loss_FF: 0.351661	TPR_FF: 87.99	TNR_FF: 94.66
# Loss_HS: 0.195734	TPR_HS: 97.34	TNR_HS: 95.88
# LossALL: 0.253654	TPRALL: 94.39	TNRALL: 95.25
# Time: 66.71
#
# Epoch:8
# ValLoss_MF: 0.214289	TPR_MF: 89.83	TNR_MF: 97.17
# ValLoss_FF: 0.263306	TPR_FF: 86.65	TNR_FF: 96.68
# ValLoss_HS: 0.157723	TPR_HS: 96.30	TNR_HS: 97.04
# ValLossALL: 0.211773	TPRALL: 89.83	TNRALL: 97.04
# Time: 4.38
# Validation loss decreased (0.235898 --> 0.211773).  Saving model
#
#
# Epoch: 9
# Loss_MF: 0.206629	TPR_MF: 95.12	TNR_MF: 95.42
# Loss_FF: 0.271554	TPR_FF: 95.49	TNR_FF: 94.82
# Loss_HS: 0.190267	TPR_HS: 95.64	TNR_HS: 96.40
# LossALL: 0.222486	TPRALL: 95.47	TNRALL: 95.86
# Time: 67.70
#
# Epoch:9
# ValLoss_MF: 0.250306	TPR_MF: 88.64	TNR_MF: 96.48
# ValLoss_FF: 0.466815	TPR_FF: 82.21	TNR_FF: 95.82
# ValLoss_HS: 0.165377	TPR_HS: 95.52	TNR_HS: 96.77
# ValLossALL: 0.294166	TPRALL: 88.64	TNRALL: 96.48
# Time: 4.31
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 10
# Loss_MF: 0.203386	TPR_MF: 95.52	TNR_MF: 95.43
# Loss_FF: 0.322396	TPR_FF: 93.13	TNR_FF: 94.93
# Loss_HS: 0.192409	TPR_HS: 96.49	TNR_HS: 96.49
# LossALL: 0.239898	TPRALL: 95.72	TNRALL: 95.38
# Time: 67.03
#
# Epoch:10
# ValLoss_MF: 0.197749	TPR_MF: 93.89	TNR_MF: 96.66
# ValLoss_FF: 0.262598	TPR_FF: 89.42	TNR_FF: 96.49
# ValLoss_HS: 0.183456	TPR_HS: 93.52	TNR_HS: 96.82
# ValLossALL: 0.214601	TPRALL: 93.52	TNRALL: 96.66
# Time: 4.25
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.200426	TPR_MF: 94.94	TNR_MF: 96.14
# Loss_FF: 0.332285	TPR_FF: 90.33	TNR_FF: 95.21
# Loss_HS: 0.201144	TPR_HS: 96.27	TNR_HS: 95.73
# LossALL: 0.246437	TPRALL: 94.45	TNRALL: 95.45
# Time: 66.73
#
# Epoch:11
# ValLoss_MF: 0.246379	TPR_MF: 89.87	TNR_MF: 97.10
# ValLoss_FF: 0.225920	TPR_FF: 90.54	TNR_FF: 96.94
# ValLoss_HS: 0.158894	TPR_HS: 95.32	TNR_HS: 97.10
# ValLossALL: 0.210398	TPRALL: 90.54	TNRALL: 97.10
# Time: 4.42
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.207510	TPR_MF: 94.68	TNR_MF: 95.64
# Loss_FF: 0.292834	TPR_FF: 92.35	TNR_FF: 95.39
# Loss_HS: 0.185990	TPR_HS: 96.27	TNR_HS: 96.65
# LossALL: 0.229207	TPRALL: 94.85	TNRALL: 95.93
# Time: 67.94
#
# Epoch:12
# ValLoss_MF: 0.202206	TPR_MF: 92.75	TNR_MF: 96.54
# ValLoss_FF: 0.306776	TPR_FF: 88.43	TNR_FF: 96.34
# ValLoss_HS: 0.147260	TPR_HS: 96.96	TNR_HS: 96.88
# ValLossALL: 0.218747	TPRALL: 92.75	TNRALL: 96.54
# Time: 4.45
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.191477	TPR_MF: 95.30	TNR_MF: 96.10
# Loss_FF: 0.301785	TPR_FF: 94.43	TNR_FF: 95.24
# Loss_HS: 0.192339	TPR_HS: 96.65	TNR_HS: 96.12
# LossALL: 0.230064	TPRALL: 95.59	TNRALL: 95.67
# Time: 67.20
#
# Epoch:13
# ValLoss_MF: 0.210531	TPR_MF: 91.55	TNR_MF: 96.75
# ValLoss_FF: 0.351145	TPR_FF: 86.80	TNR_FF: 95.91
# ValLoss_HS: 0.159946	TPR_HS: 95.90	TNR_HS: 96.98
# ValLossALL: 0.240541	TPRALL: 91.55	TNRALL: 96.75
# Time: 4.55
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.210178	TPR_MF: 95.19	TNR_MF: 95.81
# Loss_FF: 0.306197	TPR_FF: 92.40	TNR_FF: 96.04
# Loss_HS: 0.186457	TPR_HS: 96.30	TNR_HS: 96.56
# LossALL: 0.233811	TPRALL: 95.38	TNRALL: 96.15
# Time: 68.63
#
# Epoch:14
# ValLoss_MF: 0.174950	TPR_MF: 95.03	TNR_MF: 96.98
# ValLoss_FF: 0.263049	TPR_FF: 87.94	TNR_FF: 96.51
# ValLoss_HS: 0.148399	TPR_HS: 97.49	TNR_HS: 97.06
# ValLossALL: 0.195466	TPRALL: 95.03	TNRALL: 96.98
# Time: 4.52
# Validation loss decreased (0.211773 --> 0.195466).  Saving model
#
#
# Epoch: 15
# Loss_MF: 0.197766	TPR_MF: 95.61	TNR_MF: 95.90
# Loss_FF: 0.320472	TPR_FF: 91.74	TNR_FF: 95.65
# Loss_HS: 0.187321	TPR_HS: 96.07	TNR_HS: 96.73
# LossALL: 0.235726	TPRALL: 94.69	TNRALL: 96.19
# Time: 66.89
#
# Epoch:15
# ValLoss_MF: 0.162791	TPR_MF: 97.06	TNR_MF: 96.84
# ValLoss_FF: 0.230355	TPR_FF: 91.21	TNR_FF: 96.24
# ValLoss_HS: 0.155137	TPR_HS: 96.59	TNR_HS: 96.72
# ValLossALL: 0.182761	TPRALL: 96.59	TNRALL: 96.72
# Time: 4.37
# Validation loss decreased (0.195466 --> 0.182761).  Saving model
#
#
# Epoch: 16
# Loss_MF: 0.196809	TPR_MF: 94.39	TNR_MF: 96.12
# Loss_FF: 0.266679	TPR_FF: 94.42	TNR_FF: 95.47
# Loss_HS: 0.183884	TPR_HS: 96.50	TNR_HS: 96.52
# LossALL: 0.216301	TPRALL: 94.51	TNRALL: 96.13
# Time: 66.93
#
# Epoch:16
# ValLoss_MF: 0.193446	TPR_MF: 95.51	TNR_MF: 96.03
# ValLoss_FF: 0.494699	TPR_FF: 81.68	TNR_FF: 95.59
# ValLoss_HS: 0.231330	TPR_HS: 92.71	TNR_HS: 96.25
# ValLossALL: 0.306492	TPRALL: 92.71	TNRALL: 96.03
# Time: 4.32
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 17
# Loss_MF: 0.201815	TPR_MF: 95.96	TNR_MF: 95.50
# Loss_FF: 0.300490	TPR_FF: 92.71	TNR_FF: 95.69
# Loss_HS: 0.190226	TPR_HS: 96.66	TNR_HS: 95.96
# LossALL: 0.231792	TPRALL: 95.80	TNRALL: 95.63
# Time: 67.04
#
# Epoch:17
# ValLoss_MF: 0.192279	TPR_MF: 92.94	TNR_MF: 96.59
# ValLoss_FF: 0.423221	TPR_FF: 80.56	TNR_FF: 95.55
# ValLoss_HS: 0.251235	TPR_HS: 92.59	TNR_HS: 96.55
# ValLossALL: 0.288912	TPRALL: 92.59	TNRALL: 96.55
# Time: 4.36
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 18
# Loss_MF: 0.217275	TPR_MF: 94.28	TNR_MF: 95.85
# Loss_FF: 0.287564	TPR_FF: 92.91	TNR_FF: 95.11
# Loss_HS: 0.191290	TPR_HS: 97.21	TNR_HS: 96.09
# LossALL: 0.232115	TPRALL: 94.79	TNRALL: 95.56
# Time: 67.10
#
# Epoch:18
# ValLoss_MF: 0.182458	TPR_MF: 93.89	TNR_MF: 96.74
# ValLoss_FF: 0.263206	TPR_FF: 89.91	TNR_FF: 96.68
# ValLoss_HS: 0.181617	TPR_HS: 93.08	TNR_HS: 96.88
# ValLossALL: 0.209094	TPRALL: 93.08	TNRALL: 96.74
# Time: 4.51
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.196250	TPR_MF: 95.10	TNR_MF: 95.65
# Loss_FF: 0.282002	TPR_FF: 93.36	TNR_FF: 95.60
# Loss_HS: 0.188648	TPR_HS: 95.63	TNR_HS: 96.40
# LossALL: 0.222669	TPRALL: 95.35	TNRALL: 95.82
# Time: 68.34
#
# Epoch:19
# ValLoss_MF: 0.185995	TPR_MF: 95.10	TNR_MF: 96.87
# ValLoss_FF: 0.401648	TPR_FF: 83.13	TNR_FF: 95.87
# ValLoss_HS: 0.159424	TPR_HS: 96.42	TNR_HS: 96.87
# ValLossALL: 0.249022	TPRALL: 95.10	TNRALL: 96.87
# Time: 4.53
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.199161	TPR_MF: 94.89	TNR_MF: 95.86
# Loss_FF: 0.275724	TPR_FF: 92.41	TNR_FF: 95.29
# Loss_HS: 0.173364	TPR_HS: 97.27	TNR_HS: 95.77
# LossALL: 0.215906	TPRALL: 95.87	TNRALL: 95.69
# Time: 68.25
#
# Epoch:20
# ValLoss_MF: 0.184199	TPR_MF: 92.67	TNR_MF: 97.17
# ValLoss_FF: 0.349919	TPR_FF: 86.38	TNR_FF: 96.52
# ValLoss_HS: 0.254183	TPR_HS: 91.98	TNR_HS: 96.73
# ValLossALL: 0.262767	TPRALL: 91.98	TNRALL: 96.73
# Time: 4.43
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.193686	TPR_MF: 96.11	TNR_MF: 95.64
# Loss_FF: 0.242052	TPR_FF: 93.44	TNR_FF: 95.53
# Loss_HS: 0.178880	TPR_HS: 95.66	TNR_HS: 96.78
# LossALL: 0.205027	TPRALL: 95.60	TNRALL: 95.82
# Time: 67.50
#
# Epoch:21
# ValLoss_MF: 0.198491	TPR_MF: 91.73	TNR_MF: 96.63
# ValLoss_FF: 0.350691	TPR_FF: 85.69	TNR_FF: 96.42
# ValLoss_HS: 0.205934	TPR_HS: 92.50	TNR_HS: 96.69
# ValLossALL: 0.251705	TPRALL: 91.73	TNRALL: 96.63
# Time: 4.33
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.190619	TPR_MF: 96.01	TNR_MF: 95.92
# Loss_FF: 0.311167	TPR_FF: 93.12	TNR_FF: 95.42
# Loss_HS: 0.183821	TPR_HS: 95.39	TNR_HS: 96.83
# LossALL: 0.229944	TPRALL: 95.14	TNRALL: 96.02
# Time: 66.67
#
# Epoch:22
# ValLoss_MF: 0.164648	TPR_MF: 95.62	TNR_MF: 96.98
# ValLoss_FF: 0.298065	TPR_FF: 88.99	TNR_FF: 96.32
# ValLoss_HS: 0.179584	TPR_HS: 95.58	TNR_HS: 96.65
# ValLossALL: 0.214099	TPRALL: 95.58	TNRALL: 96.65
# Time: 4.38
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.187998	TPR_MF: 94.76	TNR_MF: 96.45
# Loss_FF: 0.283647	TPR_FF: 95.28	TNR_FF: 95.55
# Loss_HS: 0.176161	TPR_HS: 96.43	TNR_HS: 96.47
# LossALL: 0.216021	TPRALL: 95.91	TNRALL: 96.29
# Time: 67.84
#
# Epoch:23
# ValLoss_MF: 0.199026	TPR_MF: 92.20	TNR_MF: 96.95
# ValLoss_FF: 0.256157	TPR_FF: 88.55	TNR_FF: 96.46
# ValLoss_HS: 0.219224	TPR_HS: 93.65	TNR_HS: 96.77
# ValLossALL: 0.224802	TPRALL: 92.20	TNRALL: 96.77
# Time: 4.36
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 24
# Loss_MF: 0.193079	TPR_MF: 94.72	TNR_MF: 96.26
# Loss_FF: 0.237763	TPR_FF: 95.04	TNR_FF: 95.50
# Loss_HS: 0.179368	TPR_HS: 96.40	TNR_HS: 96.59
# LossALL: 0.203545	TPRALL: 95.77	TNRALL: 96.35
# Time: 68.08
#
# Epoch:24
# ValLoss_MF: 0.193573	TPR_MF: 91.92	TNR_MF: 97.10
# ValLoss_FF: 0.565531	TPR_FF: 78.99	TNR_FF: 96.16
# ValLoss_HS: 0.149592	TPR_HS: 96.84	TNR_HS: 96.97
# ValLossALL: 0.302899	TPRALL: 91.92	TNRALL: 96.97
# Time: 4.43
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 25
# Loss_MF: 0.184872	TPR_MF: 96.10	TNR_MF: 96.09
# Loss_FF: 0.274069	TPR_FF: 94.99	TNR_FF: 95.10
# Loss_HS: 0.171309	TPR_HS: 96.06	TNR_HS: 96.74
# LossALL: 0.210835	TPRALL: 96.06	TNRALL: 96.02
# Time: 67.06
#
# Epoch:25
# ValLoss_MF: 0.204434	TPR_MF: 92.78	TNR_MF: 96.95
# ValLoss_FF: 0.429671	TPR_FF: 83.15	TNR_FF: 96.26
# ValLoss_HS: 0.224681	TPR_HS: 93.44	TNR_HS: 96.66
# ValLossALL: 0.286262	TPRALL: 92.78	TNRALL: 96.66
# Time: 4.43
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 26
# Loss_MF: 0.186740	TPR_MF: 95.86	TNR_MF: 95.84
# Loss_FF: 0.310224	TPR_FF: 93.54	TNR_FF: 95.40
# Loss_HS: 0.187429	TPR_HS: 96.14	TNR_HS: 96.30
# LossALL: 0.229834	TPRALL: 95.45	TNRALL: 96.05
# Time: 68.12
#
# Epoch:26
# ValLoss_MF: 0.158634	TPR_MF: 96.64	TNR_MF: 96.54
# ValLoss_FF: 0.269715	TPR_FF: 90.57	TNR_FF: 95.87
# ValLoss_HS: 0.212661	TPR_HS: 94.47	TNR_HS: 96.41
# ValLossALL: 0.213670	TPRALL: 94.47	TNRALL: 96.41
# Time: 4.63
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 27
# Loss_MF: 0.189626	TPR_MF: 95.85	TNR_MF: 95.94
# Loss_FF: 0.302038	TPR_FF: 93.95	TNR_FF: 95.11
# Loss_HS: 0.178802	TPR_HS: 96.53	TNR_HS: 96.88
# LossALL: 0.224650	TPRALL: 95.24	TNRALL: 96.00
# Time: 68.54
#
# Epoch:27
# ValLoss_MF: 0.254951	TPR_MF: 89.42	TNR_MF: 96.37
# ValLoss_FF: 0.245774	TPR_FF: 89.82	TNR_FF: 96.80
# ValLoss_HS: 0.166497	TPR_HS: 95.73	TNR_HS: 97.03
# ValLossALL: 0.222407	TPRALL: 89.82	TNRALL: 96.80
# Time: 4.47
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 28
# Loss_MF: 0.190686	TPR_MF: 95.10	TNR_MF: 96.46
# Loss_FF: 0.273379	TPR_FF: 92.90	TNR_FF: 95.37
# Loss_HS: 0.182842	TPR_HS: 96.21	TNR_HS: 96.52
# LossALL: 0.216494	TPRALL: 95.49	TNRALL: 96.06
# Time: 68.32
#
# Epoch:28
# ValLoss_MF: 0.207138	TPR_MF: 90.50	TNR_MF: 97.08
# ValLoss_FF: 0.428477	TPR_FF: 83.01	TNR_FF: 96.33
# ValLoss_HS: 0.154926	TPR_HS: 96.26	TNR_HS: 97.08
# ValLossALL: 0.263514	TPRALL: 90.50	TNRALL: 97.08
# Time: 4.51
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 29
# Loss_MF: 0.191761	TPR_MF: 96.02	TNR_MF: 95.90
# Loss_FF: 0.322375	TPR_FF: 95.86	TNR_FF: 95.81
# Loss_HS: 0.181646	TPR_HS: 95.76	TNR_HS: 96.87
# LossALL: 0.232326	TPRALL: 95.81	TNRALL: 96.28
# Time: 68.90
#
# Epoch:29
# ValLoss_MF: 0.199686	TPR_MF: 92.96	TNR_MF: 96.59
# ValLoss_FF: 0.223725	TPR_FF: 91.10	TNR_FF: 96.40
# ValLoss_HS: 0.142334	TPR_HS: 97.95	TNR_HS: 97.16
# ValLossALL: 0.188582	TPRALL: 92.96	TNRALL: 96.59
# Time: 4.48
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 30
# Loss_MF: 0.196329	TPR_MF: 97.37	TNR_MF: 95.75
# Loss_FF: 0.308932	TPR_FF: 92.98	TNR_FF: 95.54
# Loss_HS: 0.179903	TPR_HS: 96.83	TNR_HS: 96.78
# LossALL: 0.228372	TPRALL: 95.85	TNRALL: 96.22
# Time: 68.70
#
# Epoch:30
# ValLoss_MF: 0.184067	TPR_MF: 94.14	TNR_MF: 96.84
# ValLoss_FF: 0.255314	TPR_FF: 89.90	TNR_FF: 96.11
# ValLoss_HS: 0.178885	TPR_HS: 95.33	TNR_HS: 96.94
# ValLossALL: 0.206088	TPRALL: 94.14	TNRALL: 96.84
# Time: 4.55
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 31
# Loss_MF: 0.190151	TPR_MF: 95.34	TNR_MF: 95.79
# Loss_FF: 0.273294	TPR_FF: 94.83	TNR_FF: 95.91
# Loss_HS: 0.180131	TPR_HS: 96.62	TNR_HS: 96.61
# LossALL: 0.215316	TPRALL: 95.83	TNRALL: 96.18
# Time: 67.35
#
# Epoch:31
# ValLoss_MF: 0.208060	TPR_MF: 95.01	TNR_MF: 96.93
# ValLoss_FF: 0.380445	TPR_FF: 84.74	TNR_FF: 96.04
# ValLoss_HS: 0.143079	TPR_HS: 96.21	TNR_HS: 97.23
# ValLossALL: 0.243861	TPRALL: 95.01	TNRALL: 96.93
# Time: 4.74
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 32
# Loss_MF: 0.181943	TPR_MF: 95.69	TNR_MF: 96.31
# Loss_FF: 0.282133	TPR_FF: 95.12	TNR_FF: 95.64
# Loss_HS: 0.179529	TPR_HS: 95.38	TNR_HS: 96.96
# LossALL: 0.215816	TPRALL: 95.45	TNRALL: 96.49
# Time: 68.52
#
# Epoch:32
# ValLoss_MF: 0.221828	TPR_MF: 91.76	TNR_MF: 96.41
# ValLoss_FF: 0.313818	TPR_FF: 88.02	TNR_FF: 96.02
# ValLoss_HS: 0.164603	TPR_HS: 95.71	TNR_HS: 96.80
# ValLossALL: 0.233416	TPRALL: 91.76	TNRALL: 96.41
# Time: 4.65
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 33
# Loss_MF: 0.188183	TPR_MF: 95.90	TNR_MF: 96.08
# Loss_FF: 0.261739	TPR_FF: 95.08	TNR_FF: 95.78
# Loss_HS: 0.174571	TPR_HS: 96.06	TNR_HS: 96.79
# LossALL: 0.208019	TPRALL: 95.72	TNRALL: 96.29
# Time: 67.49
#
# Epoch:33
# ValLoss_MF: 0.181449	TPR_MF: 93.21	TNR_MF: 96.92
# ValLoss_FF: 0.299373	TPR_FF: 87.04	TNR_FF: 96.53
# ValLoss_HS: 0.153710	TPR_HS: 96.36	TNR_HS: 97.17
# ValLossALL: 0.211511	TPRALL: 93.21	TNRALL: 96.92
# Time: 4.41
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 34
# Loss_MF: 0.185753	TPR_MF: 95.74	TNR_MF: 96.28
# Loss_FF: 0.298313	TPR_FF: 92.82	TNR_FF: 95.57
# Loss_HS: 0.188867	TPR_HS: 96.43	TNR_HS: 96.52
# LossALL: 0.225949	TPRALL: 95.49	TNRALL: 96.08
# Time: 67.08
#
# Epoch:34
# ValLoss_MF: 0.189091	TPR_MF: 93.52	TNR_MF: 96.80
# ValLoss_FF: 0.250482	TPR_FF: 92.72	TNR_FF: 95.96
# ValLoss_HS: 0.159389	TPR_HS: 96.32	TNR_HS: 97.06
# ValLossALL: 0.199654	TPRALL: 93.52	TNRALL: 96.80
# Time: 4.52
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 35
# Loss_MF: 0.192656	TPR_MF: 96.25	TNR_MF: 95.95
# Loss_FF: 0.302738	TPR_FF: 94.62	TNR_FF: 95.76
# Loss_HS: 0.173442	TPR_HS: 95.88	TNR_HS: 96.89
# LossALL: 0.223790	TPRALL: 95.83	TNRALL: 96.40
# Time: 66.73
#
# Epoch:35
# ValLoss_MF: 0.178966	TPR_MF: 93.71	TNR_MF: 96.75
# ValLoss_FF: 0.208625	TPR_FF: 93.25	TNR_FF: 96.15
# ValLoss_HS: 0.283136	TPR_HS: 90.07	TNR_HS: 96.64
# ValLossALL: 0.223576	TPRALL: 93.25	TNRALL: 96.64
# Time: 4.33
# EarlyStopping counter: 20 out of 20
#
# Early stopping
# Network(
#   (lstm): LSTM(18, 512, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear): Linear(in_features=1024, out_features=1, bias=True)
# )
# TO-512-HS-2-NL-0.0001-LR-0.3-DO
#
# Epoch: 0
# Loss_MF: 0.880120	TPR_MF: 0.00	TNR_MF: 100.00
# Loss_FF: 0.677630	TPR_FF: 75.00	TNR_FF: 87.08
# Loss_HS: 0.394097	TPR_HS: 92.38	TNR_HS: 85.16
# LossALL: 0.626584	TPRALL: 79.20	TNRALL: 89.27
# Time: 53.04
#
# Epoch:0
# ValLoss_MF: 0.352436	TPR_MF: 86.60	TNR_MF: 91.84
# ValLoss_FF: 0.390285	TPR_FF: 91.44	TNR_FF: 90.60
# ValLoss_HS: 0.358587	TPR_HS: 93.10	TNR_HS: 91.26
# ValLossALL: 0.367103	TPRALL: 91.44	TNRALL: 91.26
# Time: 4.08
# Validation loss decreased (inf --> 0.367103).  Saving model
#
#
# Epoch: 1
# Loss_MF: 0.283508	TPR_MF: 93.77	TNR_MF: 92.07
# Loss_FF: 0.367965	TPR_FF: 97.44	TNR_FF: 91.92
# Loss_HS: 0.262719	TPR_HS: 99.10	TNR_HS: 93.42
# LossALL: 0.304324	TPRALL: 97.32	TNRALL: 92.55
# Time: 52.79
#
# Epoch:1
# ValLoss_MF: 0.231187	TPR_MF: 96.23	TNR_MF: 94.32
# ValLoss_FF: 0.559632	TPR_FF: 87.27	TNR_FF: 92.86
# ValLoss_HS: 0.212993	TPR_HS: 99.10	TNR_HS: 94.46
# ValLossALL: 0.334604	TPRALL: 96.23	TNRALL: 94.32
# Time: 4.20
# Validation loss decreased (0.367103 --> 0.334604).  Saving model
#
#
# Epoch: 2
# Loss_MF: 0.232668	TPR_MF: 95.48	TNR_MF: 94.43
# Loss_FF: 0.390964	TPR_FF: 91.41	TNR_FF: 93.74
# Loss_HS: 0.217092	TPR_HS: 97.38	TNR_HS: 95.37
# LossALL: 0.280881	TPRALL: 96.13	TNRALL: 94.44
# Time: 52.94
#
# Epoch:2
# ValLoss_MF: 0.232139	TPR_MF: 93.93	TNR_MF: 95.43
# ValLoss_FF: 0.225156	TPR_FF: 94.55	TNR_FF: 95.18
# ValLoss_HS: 0.472874	TPR_HS: 88.20	TNR_HS: 95.11
# ValLossALL: 0.310057	TPRALL: 93.93	TNRALL: 95.18
# Time: 4.18
# Validation loss decreased (0.334604 --> 0.310057).  Saving model
#
#
# Epoch: 3
# Loss_MF: 0.227198	TPR_MF: 93.99	TNR_MF: 95.71
# Loss_FF: 0.324185	TPR_FF: 93.55	TNR_FF: 93.97
# Loss_HS: 0.210481	TPR_HS: 97.45	TNR_HS: 95.56
# LossALL: 0.253299	TPRALL: 94.75	TNRALL: 95.41
# Time: 50.22
#
# Epoch:3
# ValLoss_MF: 0.200896	TPR_MF: 95.56	TNR_MF: 95.42
# ValLoss_FF: 0.425318	TPR_FF: 85.54	TNR_FF: 94.76
# ValLoss_HS: 0.199491	TPR_HS: 96.63	TNR_HS: 95.70
# ValLossALL: 0.275235	TPRALL: 95.56	TNRALL: 95.42
# Time: 3.69
# Validation loss decreased (0.310057 --> 0.275235).  Saving model
#
#
# Epoch: 4
# Loss_MF: 0.212736	TPR_MF: 95.37	TNR_MF: 95.58
# Loss_FF: 0.368467	TPR_FF: 92.04	TNR_FF: 94.60
# Loss_HS: 0.223160	TPR_HS: 95.63	TNR_HS: 95.64
# LossALL: 0.270595	TPRALL: 94.62	TNRALL: 95.40
# Time: 49.00
#
# Epoch:4
# ValLoss_MF: 0.262583	TPR_MF: 91.86	TNR_MF: 96.27
# ValLoss_FF: 0.278434	TPR_FF: 85.51	TNR_FF: 95.91
# ValLoss_HS: 0.270947	TPR_HS: 92.36	TNR_HS: 96.20
# ValLossALL: 0.270655	TPRALL: 91.86	TNRALL: 96.20
# Time: 3.73
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 5
# Loss_MF: 0.213083	TPR_MF: 93.92	TNR_MF: 95.73
# Loss_FF: 0.315413	TPR_FF: 92.90	TNR_FF: 95.12
# Loss_HS: 0.201433	TPR_HS: 96.56	TNR_HS: 96.02
# LossALL: 0.243681	TPRALL: 94.87	TNRALL: 95.71
# Time: 50.18
#
# Epoch:5
# ValLoss_MF: 0.230967	TPR_MF: 90.34	TNR_MF: 96.20
# ValLoss_FF: 0.323932	TPR_FF: 86.36	TNR_FF: 95.92
# ValLoss_HS: 0.150054	TPR_HS: 98.51	TNR_HS: 96.78
# ValLossALL: 0.234984	TPRALL: 90.34	TNRALL: 96.20
# Time: 4.08
# Validation loss decreased (0.275235 --> 0.234984).  Saving model
#
#
# Epoch: 6
# Loss_MF: 0.212577	TPR_MF: 94.81	TNR_MF: 96.08
# Loss_FF: 0.323891	TPR_FF: 90.48	TNR_FF: 95.09
# Loss_HS: 0.212866	TPR_HS: 96.75	TNR_HS: 95.43
# LossALL: 0.251302	TPRALL: 95.03	TNRALL: 95.52
# Time: 48.84
#
# Epoch:6
# ValLoss_MF: 0.228816	TPR_MF: 91.30	TNR_MF: 95.88
# ValLoss_FF: 0.278219	TPR_FF: 88.16	TNR_FF: 95.18
# ValLoss_HS: 0.159659	TPR_HS: 97.27	TNR_HS: 96.34
# ValLossALL: 0.222231	TPRALL: 91.30	TNRALL: 95.88
# Time: 3.85
# Validation loss decreased (0.234984 --> 0.222231).  Saving model
#
#
# Epoch: 7
# Loss_MF: 0.213023	TPR_MF: 93.43	TNR_MF: 95.87
# Loss_FF: 0.326308	TPR_FF: 92.38	TNR_FF: 94.62
# Loss_HS: 0.205065	TPR_HS: 95.94	TNR_HS: 95.75
# LossALL: 0.249403	TPRALL: 94.29	TNRALL: 95.54
# Time: 48.77
#
# Epoch:7
# ValLoss_MF: 0.170164	TPR_MF: 93.81	TNR_MF: 96.92
# ValLoss_FF: 0.241483	TPR_FF: 91.73	TNR_FF: 96.59
# ValLoss_HS: 0.169860	TPR_HS: 94.79	TNR_HS: 96.76
# ValLossALL: 0.193836	TPRALL: 93.81	TNRALL: 96.76
# Time: 3.84
# Validation loss decreased (0.222231 --> 0.193836).  Saving model
#
#
# Epoch: 8
# Loss_MF: 0.204526	TPR_MF: 93.96	TNR_MF: 95.97
# Loss_FF: 0.328822	TPR_FF: 89.73	TNR_FF: 95.08
# Loss_HS: 0.199553	TPR_HS: 95.43	TNR_HS: 96.11
# LossALL: 0.244996	TPRALL: 94.05	TNRALL: 95.82
# Time: 48.85
#
# Epoch:8
# ValLoss_MF: 0.265604	TPR_MF: 86.94	TNR_MF: 96.15
# ValLoss_FF: 0.238897	TPR_FF: 90.07	TNR_FF: 96.09
# ValLoss_HS: 0.219267	TPR_HS: 94.43	TNR_HS: 96.27
# ValLossALL: 0.241256	TPRALL: 90.07	TNRALL: 96.15
# Time: 3.78
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 9
# Loss_MF: 0.203325	TPR_MF: 93.37	TNR_MF: 96.23
# Loss_FF: 0.305961	TPR_FF: 92.03	TNR_FF: 94.94
# Loss_HS: 0.195146	TPR_HS: 96.26	TNR_HS: 96.16
# LossALL: 0.235929	TPRALL: 95.00	TNRALL: 96.05
# Time: 50.06
#
# Epoch:9
# ValLoss_MF: 0.277950	TPR_MF: 88.95	TNR_MF: 96.48
# ValLoss_FF: 0.381469	TPR_FF: 80.98	TNR_FF: 95.99
# ValLoss_HS: 0.165485	TPR_HS: 95.94	TNR_HS: 96.72
# ValLossALL: 0.274968	TPRALL: 88.95	TNRALL: 96.48
# Time: 3.94
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 10
# Loss_MF: 0.206849	TPR_MF: 94.51	TNR_MF: 96.00
# Loss_FF: 0.265229	TPR_FF: 93.32	TNR_FF: 95.44
# Loss_HS: 0.184259	TPR_HS: 96.33	TNR_HS: 96.60
# LossALL: 0.218805	TPRALL: 94.78	TNRALL: 95.92
# Time: 48.58
#
# Epoch:10
# ValLoss_MF: 0.210070	TPR_MF: 90.36	TNR_MF: 96.77
# ValLoss_FF: 0.395185	TPR_FF: 82.91	TNR_FF: 95.75
# ValLoss_HS: 0.138163	TPR_HS: 97.52	TNR_HS: 97.15
# ValLossALL: 0.247806	TPRALL: 90.36	TNRALL: 96.77
# Time: 3.86
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.198109	TPR_MF: 93.88	TNR_MF: 96.31
# Loss_FF: 0.249848	TPR_FF: 92.54	TNR_FF: 95.72
# Loss_HS: 0.185113	TPR_HS: 95.71	TNR_HS: 96.40
# LossALL: 0.210513	TPRALL: 94.51	TNRALL: 96.02
# Time: 50.11
#
# Epoch:11
# ValLoss_MF: 0.187720	TPR_MF: 94.35	TNR_MF: 96.60
# ValLoss_FF: 0.417328	TPR_FF: 78.50	TNR_FF: 95.77
# ValLoss_HS: 0.171113	TPR_HS: 94.34	TNR_HS: 96.98
# ValLossALL: 0.258720	TPRALL: 94.34	TNRALL: 96.60
# Time: 3.94
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.196956	TPR_MF: 95.34	TNR_MF: 96.16
# Loss_FF: 0.288228	TPR_FF: 92.38	TNR_FF: 95.18
# Loss_HS: 0.181915	TPR_HS: 95.91	TNR_HS: 96.55
# LossALL: 0.223097	TPRALL: 95.17	TNRALL: 96.07
# Time: 50.65
#
# Epoch:12
# ValLoss_MF: 0.303143	TPR_MF: 89.31	TNR_MF: 96.71
# ValLoss_FF: 0.311117	TPR_FF: 85.56	TNR_FF: 96.19
# ValLoss_HS: 0.269685	TPR_HS: 93.21	TNR_HS: 96.92
# ValLossALL: 0.294648	TPRALL: 89.31	TNRALL: 96.71
# Time: 3.86
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.203844	TPR_MF: 94.76	TNR_MF: 95.79
# Loss_FF: 0.272177	TPR_FF: 92.97	TNR_FF: 95.05
# Loss_HS: 0.179332	TPR_HS: 96.80	TNR_HS: 96.67
# LossALL: 0.218547	TPRALL: 94.75	TNRALL: 95.65
# Time: 50.28
#
# Epoch:13
# ValLoss_MF: 0.162775	TPR_MF: 96.96	TNR_MF: 96.36
# ValLoss_FF: 0.269932	TPR_FF: 89.01	TNR_FF: 95.69
# ValLoss_HS: 0.190553	TPR_HS: 94.13	TNR_HS: 96.41
# ValLossALL: 0.207753	TPRALL: 94.13	TNRALL: 96.36
# Time: 3.99
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.196593	TPR_MF: 95.38	TNR_MF: 96.01
# Loss_FF: 0.252554	TPR_FF: 94.12	TNR_FF: 95.44
# Loss_HS: 0.177917	TPR_HS: 96.54	TNR_HS: 96.77
# LossALL: 0.208896	TPRALL: 95.49	TNRALL: 95.92
# Time: 50.94
#
# Epoch:14
# ValLoss_MF: 0.182215	TPR_MF: 94.43	TNR_MF: 96.50
# ValLoss_FF: 0.290006	TPR_FF: 89.19	TNR_FF: 95.18
# ValLoss_HS: 0.252426	TPR_HS: 92.70	TNR_HS: 96.43
# ValLossALL: 0.241549	TPRALL: 92.70	TNRALL: 96.43
# Time: 3.98
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 15
# Loss_MF: 0.193240	TPR_MF: 94.98	TNR_MF: 96.09
# Loss_FF: 0.242942	TPR_FF: 94.14	TNR_FF: 95.42
# Loss_HS: 0.172697	TPR_HS: 95.00	TNR_HS: 96.87
# LossALL: 0.202332	TPRALL: 94.98	TNRALL: 96.11
# Time: 51.90
#
# Epoch:15
# ValLoss_MF: 0.192798	TPR_MF: 93.20	TNR_MF: 96.44
# ValLoss_FF: 0.341628	TPR_FF: 82.40	TNR_FF: 95.83
# ValLoss_HS: 0.303820	TPR_HS: 93.30	TNR_HS: 97.00
# ValLossALL: 0.279415	TPRALL: 93.20	TNRALL: 96.44
# Time: 3.96
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 16
# Loss_MF: 0.193732	TPR_MF: 94.52	TNR_MF: 95.95
# Loss_FF: 0.266580	TPR_FF: 92.28	TNR_FF: 95.05
# Loss_HS: 0.183486	TPR_HS: 95.90	TNR_HS: 96.37
# LossALL: 0.215242	TPRALL: 95.38	TNRALL: 96.10
# Time: 51.22
#
# Epoch:16
# ValLoss_MF: 0.164324	TPR_MF: 96.19	TNR_MF: 96.84
# ValLoss_FF: 0.182484	TPR_FF: 94.15	TNR_FF: 96.34
# ValLoss_HS: 0.170610	TPR_HS: 94.69	TNR_HS: 96.79
# ValLossALL: 0.172473	TPRALL: 94.69	TNRALL: 96.79
# Time: 4.02
# Validation loss decreased (0.193836 --> 0.172473).  Saving model
#
#
# Epoch: 17
# Loss_MF: 0.191424	TPR_MF: 95.49	TNR_MF: 96.07
# Loss_FF: 0.243472	TPR_FF: 93.44	TNR_FF: 95.71
# Loss_HS: 0.180214	TPR_HS: 95.48	TNR_HS: 96.71
# LossALL: 0.204597	TPRALL: 95.11	TNRALL: 96.32
# Time: 49.55
#
# Epoch:17
# ValLoss_MF: 0.174290	TPR_MF: 94.22	TNR_MF: 96.95
# ValLoss_FF: 0.478910	TPR_FF: 79.63	TNR_FF: 95.57
# ValLoss_HS: 0.170973	TPR_HS: 94.33	TNR_HS: 96.99
# ValLossALL: 0.274724	TPRALL: 94.22	TNRALL: 96.95
# Time: 3.61
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 18
# Loss_MF: 0.188578	TPR_MF: 95.07	TNR_MF: 96.17
# Loss_FF: 0.260543	TPR_FF: 93.53	TNR_FF: 95.64
# Loss_HS: 0.194493	TPR_HS: 95.13	TNR_HS: 96.70
# LossALL: 0.214784	TPRALL: 94.59	TNRALL: 96.12
# Time: 48.28
#
# Epoch:18
# ValLoss_MF: 0.167619	TPR_MF: 96.85	TNR_MF: 96.37
# ValLoss_FF: 0.340613	TPR_FF: 87.24	TNR_FF: 94.99
# ValLoss_HS: 0.231571	TPR_HS: 93.10	TNR_HS: 96.12
# ValLossALL: 0.246601	TPRALL: 93.10	TNRALL: 96.12
# Time: 4.08
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.177192	TPR_MF: 96.37	TNR_MF: 95.93
# Loss_FF: 0.277877	TPR_FF: 93.26	TNR_FF: 95.24
# Loss_HS: 0.166471	TPR_HS: 96.19	TNR_HS: 97.02
# LossALL: 0.208185	TPRALL: 95.52	TNRALL: 96.26
# Time: 51.07
#
# Epoch:19
# ValLoss_MF: 0.264034	TPR_MF: 90.00	TNR_MF: 96.40
# ValLoss_FF: 0.318261	TPR_FF: 85.79	TNR_FF: 96.18
# ValLoss_HS: 0.221729	TPR_HS: 92.92	TNR_HS: 96.94
# ValLossALL: 0.268008	TPRALL: 90.00	TNRALL: 96.40
# Time: 4.13
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.191289	TPR_MF: 94.49	TNR_MF: 96.50
# Loss_FF: 0.254415	TPR_FF: 95.78	TNR_FF: 95.79
# Loss_HS: 0.184001	TPR_HS: 96.43	TNR_HS: 96.20
# LossALL: 0.209616	TPRALL: 95.52	TNRALL: 96.15
# Time: 50.32
#
# Epoch:20
# ValLoss_MF: 0.172610	TPR_MF: 93.68	TNR_MF: 97.11
# ValLoss_FF: 0.338644	TPR_FF: 82.00	TNR_FF: 96.21
# ValLoss_HS: 0.140855	TPR_HS: 96.53	TNR_HS: 97.47
# ValLossALL: 0.217370	TPRALL: 93.68	TNRALL: 97.11
# Time: 3.81
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.185132	TPR_MF: 95.11	TNR_MF: 96.23
# Loss_FF: 0.252018	TPR_FF: 94.60	TNR_FF: 95.08
# Loss_HS: 0.164172	TPR_HS: 96.17	TNR_HS: 96.94
# LossALL: 0.199619	TPRALL: 95.61	TNRALL: 96.52
# Time: 49.21
#
# Epoch:21
# ValLoss_MF: 0.173552	TPR_MF: 94.38	TNR_MF: 96.63
# ValLoss_FF: 0.332201	TPR_FF: 84.66	TNR_FF: 95.90
# ValLoss_HS: 0.319183	TPR_HS: 90.13	TNR_HS: 96.61
# ValLossALL: 0.274979	TPRALL: 90.13	TNRALL: 96.61
# Time: 3.83
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.181773	TPR_MF: 94.90	TNR_MF: 96.41
# Loss_FF: 0.240586	TPR_FF: 92.49	TNR_FF: 95.37
# Loss_HS: 0.176102	TPR_HS: 95.95	TNR_HS: 96.84
# LossALL: 0.200094	TPRALL: 95.30	TNRALL: 96.40
# Time: 49.80
#
# Epoch:22
# ValLoss_MF: 0.180656	TPR_MF: 94.08	TNR_MF: 96.45
# ValLoss_FF: 0.281320	TPR_FF: 89.71	TNR_FF: 95.25
# ValLoss_HS: 0.154694	TPR_HS: 95.54	TNR_HS: 96.94
# ValLossALL: 0.205557	TPRALL: 94.08	TNRALL: 96.45
# Time: 3.92
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.185440	TPR_MF: 94.98	TNR_MF: 96.19
# Loss_FF: 0.255959	TPR_FF: 92.98	TNR_FF: 95.30
# Loss_HS: 0.176390	TPR_HS: 95.52	TNR_HS: 96.95
# LossALL: 0.205575	TPRALL: 94.85	TNRALL: 96.33
# Time: 48.61
#
# Epoch:23
# ValLoss_MF: 0.198428	TPR_MF: 90.62	TNR_MF: 96.81
# ValLoss_FF: 0.251646	TPR_FF: 90.00	TNR_FF: 95.48
# ValLoss_HS: 0.145291	TPR_HS: 95.36	TNR_HS: 97.40
# ValLossALL: 0.198455	TPRALL: 90.62	TNRALL: 96.81
# Time: 3.59
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 24
# Loss_MF: 0.195850	TPR_MF: 95.49	TNR_MF: 95.55
# Loss_FF: 0.255659	TPR_FF: 92.57	TNR_FF: 95.35
# Loss_HS: 0.171445	TPR_HS: 95.26	TNR_HS: 97.07
# LossALL: 0.206694	TPRALL: 95.09	TNRALL: 96.10
# Time: 49.10
#
# Epoch:24
# ValLoss_MF: 0.150682	TPR_MF: 97.04	TNR_MF: 96.77
# ValLoss_FF: 0.273865	TPR_FF: 87.37	TNR_FF: 95.53
# ValLoss_HS: 0.175287	TPR_HS: 94.53	TNR_HS: 96.87
# ValLossALL: 0.199945	TPRALL: 94.53	TNRALL: 96.77
# Time: 3.75
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 25
# Loss_MF: 0.181912	TPR_MF: 94.87	TNR_MF: 96.16
# Loss_FF: 0.252759	TPR_FF: 92.45	TNR_FF: 95.29
# Loss_HS: 0.172026	TPR_HS: 95.97	TNR_HS: 96.90
# LossALL: 0.202860	TPRALL: 95.25	TNRALL: 96.18
# Time: 49.35
#
# Epoch:25
# ValLoss_MF: 0.149777	TPR_MF: 96.85	TNR_MF: 96.88
# ValLoss_FF: 0.217990	TPR_FF: 89.96	TNR_FF: 96.53
# ValLoss_HS: 0.192076	TPR_HS: 92.92	TNR_HS: 96.47
# ValLossALL: 0.186614	TPRALL: 92.92	TNRALL: 96.53
# Time: 3.83
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 26
# Loss_MF: 0.182100	TPR_MF: 95.99	TNR_MF: 96.26
# Loss_FF: 0.240230	TPR_FF: 93.96	TNR_FF: 95.74
# Loss_HS: 0.175686	TPR_HS: 96.49	TNR_HS: 96.68
# LossALL: 0.199555	TPRALL: 95.91	TNRALL: 96.28
# Time: 48.96
#
# Epoch:26
# ValLoss_MF: 0.167555	TPR_MF: 95.23	TNR_MF: 96.78
# ValLoss_FF: 0.258274	TPR_FF: 91.40	TNR_FF: 94.89
# ValLoss_HS: 0.166443	TPR_HS: 94.46	TNR_HS: 97.06
# ValLossALL: 0.197424	TPRALL: 94.46	TNRALL: 96.78
# Time: 3.73
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 27
# Loss_MF: 0.184548	TPR_MF: 95.59	TNR_MF: 96.04
# Loss_FF: 0.257539	TPR_FF: 90.82	TNR_FF: 94.68
# Loss_HS: 0.173797	TPR_HS: 95.00	TNR_HS: 97.13
# LossALL: 0.205922	TPRALL: 95.07	TNRALL: 96.24
# Time: 48.79
#
# Epoch:27
# ValLoss_MF: 0.170405	TPR_MF: 94.44	TNR_MF: 96.50
# ValLoss_FF: 0.216856	TPR_FF: 92.29	TNR_FF: 95.80
# ValLoss_HS: 0.148734	TPR_HS: 96.70	TNR_HS: 96.81
# ValLossALL: 0.178665	TPRALL: 94.44	TNRALL: 96.50
# Time: 3.85
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 28
# Loss_MF: 0.181276	TPR_MF: 95.58	TNR_MF: 96.23
# Loss_FF: 0.230185	TPR_FF: 95.67	TNR_FF: 95.25
# Loss_HS: 0.167241	TPR_HS: 96.39	TNR_HS: 96.90
# LossALL: 0.192350	TPRALL: 95.73	TNRALL: 96.31
# Time: 49.59
#
# Epoch:28
# ValLoss_MF: 0.197627	TPR_MF: 93.44	TNR_MF: 96.00
# ValLoss_FF: 0.206608	TPR_FF: 94.72	TNR_FF: 95.43
# ValLoss_HS: 0.163019	TPR_HS: 95.96	TNR_HS: 96.65
# ValLossALL: 0.189085	TPRALL: 94.72	TNRALL: 96.00
# Time: 3.70
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 29
# Loss_MF: 0.181662	TPR_MF: 96.28	TNR_MF: 96.11
# Loss_FF: 0.227618	TPR_FF: 95.45	TNR_FF: 95.44
# Loss_HS: 0.171347	TPR_HS: 96.30	TNR_HS: 96.75
# LossALL: 0.193138	TPRALL: 96.28	TNRALL: 96.20
# Time: 49.39
#
# Epoch:29
# ValLoss_MF: 0.175953	TPR_MF: 93.06	TNR_MF: 96.75
# ValLoss_FF: 0.276582	TPR_FF: 89.17	TNR_FF: 95.58
# ValLoss_HS: 0.154394	TPR_HS: 95.52	TNR_HS: 97.36
# ValLossALL: 0.202310	TPRALL: 93.06	TNRALL: 96.75
# Time: 3.81
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 30
# Loss_MF: 0.184445	TPR_MF: 95.62	TNR_MF: 96.24
# Loss_FF: 0.250951	TPR_FF: 92.47	TNR_FF: 94.94
# Loss_HS: 0.167427	TPR_HS: 95.97	TNR_HS: 96.96
# LossALL: 0.201267	TPRALL: 95.34	TNRALL: 96.26
# Time: 48.69
#
# Epoch:30
# ValLoss_MF: 0.148720	TPR_MF: 97.43	TNR_MF: 96.73
# ValLoss_FF: 0.184831	TPR_FF: 97.12	TNR_FF: 95.78
# ValLoss_HS: 0.145422	TPR_HS: 96.51	TNR_HS: 97.07
# ValLossALL: 0.159658	TPRALL: 97.12	TNRALL: 96.73
# Time: 3.86
# Validation loss decreased (0.172473 --> 0.159658).  Saving model
#
#
# Epoch: 31
# Loss_MF: 0.175933	TPR_MF: 95.88	TNR_MF: 96.31
# Loss_FF: 0.217818	TPR_FF: 95.30	TNR_FF: 95.71
# Loss_HS: 0.162237	TPR_HS: 96.24	TNR_HS: 97.05
# LossALL: 0.185433	TPRALL: 96.09	TNRALL: 96.36
# Time: 50.07
#
# Epoch:31
# ValLoss_MF: 0.214063	TPR_MF: 92.41	TNR_MF: 96.81
# ValLoss_FF: 0.320452	TPR_FF: 84.85	TNR_FF: 95.26
# ValLoss_HS: 0.208459	TPR_HS: 92.93	TNR_HS: 96.97
# ValLossALL: 0.247658	TPRALL: 92.41	TNRALL: 96.81
# Time: 4.03
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 32
# Loss_MF: 0.176158	TPR_MF: 95.38	TNR_MF: 96.46
# Loss_FF: 0.212844	TPR_FF: 93.99	TNR_FF: 96.06
# Loss_HS: 0.174790	TPR_HS: 96.65	TNR_HS: 96.57
# LossALL: 0.188384	TPRALL: 95.32	TNRALL: 96.39
# Time: 50.17
#
# Epoch:32
# ValLoss_MF: 0.253450	TPR_MF: 87.78	TNR_MF: 96.20
# ValLoss_FF: 0.301669	TPR_FF: 83.55	TNR_FF: 95.61
# ValLoss_HS: 0.134701	TPR_HS: 97.10	TNR_HS: 97.09
# ValLossALL: 0.229940	TPRALL: 87.78	TNRALL: 96.20
# Time: 3.99
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 33
# Loss_MF: 0.177394	TPR_MF: 95.64	TNR_MF: 96.27
# Loss_FF: 0.228060	TPR_FF: 94.94	TNR_FF: 95.00
# Loss_HS: 0.169752	TPR_HS: 95.35	TNR_HS: 96.87
# LossALL: 0.192165	TPRALL: 95.36	TNRALL: 96.31
# Time: 50.76
#
# Epoch:33
# ValLoss_MF: 0.188744	TPR_MF: 94.80	TNR_MF: 96.13
# ValLoss_FF: 0.217409	TPR_FF: 93.84	TNR_FF: 94.45
# ValLoss_HS: 0.133963	TPR_HS: 98.35	TNR_HS: 96.90
# ValLossALL: 0.180038	TPRALL: 94.80	TNRALL: 96.13
# Time: 4.08
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 34
# Loss_MF: 0.178734	TPR_MF: 95.75	TNR_MF: 96.20
# Loss_FF: 0.221865	TPR_FF: 92.53	TNR_FF: 95.67
# Loss_HS: 0.164767	TPR_HS: 96.21	TNR_HS: 96.89
# LossALL: 0.188370	TPRALL: 95.48	TNRALL: 96.28
# Time: 50.49
#
# Epoch:34
# ValLoss_MF: 0.197740	TPR_MF: 92.75	TNR_MF: 96.60
# ValLoss_FF: 0.246639	TPR_FF: 88.17	TNR_FF: 95.98
# ValLoss_HS: 0.124229	TPR_HS: 96.48	TNR_HS: 97.57
# ValLossALL: 0.189536	TPRALL: 92.75	TNRALL: 96.60
# Time: 4.10
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 35
# Loss_MF: 0.179679	TPR_MF: 95.66	TNR_MF: 96.15
# Loss_FF: 0.221508	TPR_FF: 93.95	TNR_FF: 95.51
# Loss_HS: 0.166364	TPR_HS: 96.44	TNR_HS: 96.66
# LossALL: 0.189108	TPRALL: 95.94	TNRALL: 96.21
# Time: 50.86
#
# Epoch:35
# ValLoss_MF: 0.186697	TPR_MF: 91.36	TNR_MF: 97.10
# ValLoss_FF: 0.227817	TPR_FF: 90.25	TNR_FF: 95.45
# ValLoss_HS: 0.148995	TPR_HS: 95.19	TNR_HS: 97.24
# ValLossALL: 0.187836	TPRALL: 91.36	TNRALL: 97.10
# Time: 3.99
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 36
# Loss_MF: 0.183530	TPR_MF: 94.67	TNR_MF: 96.36
# Loss_FF: 0.229032	TPR_FF: 92.15	TNR_FF: 95.38
# Loss_HS: 0.169673	TPR_HS: 96.10	TNR_HS: 96.81
# LossALL: 0.194012	TPRALL: 94.84	TNRALL: 96.42
# Time: 50.99
#
# Epoch:36
# ValLoss_MF: 0.157641	TPR_MF: 95.77	TNR_MF: 96.81
# ValLoss_FF: 0.215852	TPR_FF: 92.16	TNR_FF: 96.01
# ValLoss_HS: 0.159062	TPR_HS: 95.79	TNR_HS: 97.00
# ValLossALL: 0.177518	TPRALL: 95.77	TNRALL: 96.81
# Time: 3.90
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 37
# Loss_MF: 0.172796	TPR_MF: 95.19	TNR_MF: 96.54
# Loss_FF: 0.210147	TPR_FF: 96.29	TNR_FF: 95.64
# Loss_HS: 0.160577	TPR_HS: 96.11	TNR_HS: 96.68
# LossALL: 0.181097	TPRALL: 95.74	TNRALL: 96.48
# Time: 50.75
#
# Epoch:37
# ValLoss_MF: 0.207288	TPR_MF: 90.41	TNR_MF: 96.44
# ValLoss_FF: 0.324338	TPR_FF: 83.59	TNR_FF: 95.78
# ValLoss_HS: 0.261277	TPR_HS: 92.35	TNR_HS: 97.02
# ValLossALL: 0.264301	TPRALL: 90.41	TNRALL: 96.44
# Time: 4.08
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 38
# Loss_MF: 0.181290	TPR_MF: 93.89	TNR_MF: 96.53
# Loss_FF: 0.222062	TPR_FF: 95.83	TNR_FF: 95.59
# Loss_HS: 0.164435	TPR_HS: 95.68	TNR_HS: 96.93
# LossALL: 0.189244	TPRALL: 95.52	TNRALL: 96.66
# Time: 50.14
#
# Epoch:38
# ValLoss_MF: 0.162667	TPR_MF: 96.01	TNR_MF: 96.88
# ValLoss_FF: 0.219083	TPR_FF: 90.07	TNR_FF: 96.16
# ValLoss_HS: 0.160993	TPR_HS: 95.70	TNR_HS: 96.76
# ValLossALL: 0.180914	TPRALL: 95.70	TNRALL: 96.76
# Time: 4.17
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 39
# Loss_MF: 0.181427	TPR_MF: 95.01	TNR_MF: 96.09
# Loss_FF: 0.216616	TPR_FF: 95.62	TNR_FF: 95.48
# Loss_HS: 0.165215	TPR_HS: 96.46	TNR_HS: 96.85
# LossALL: 0.187555	TPRALL: 95.59	TNRALL: 96.20
# Time: 50.70
#
# Epoch:39
# ValLoss_MF: 0.195973	TPR_MF: 94.48	TNR_MF: 96.63
# ValLoss_FF: 0.209042	TPR_FF: 92.90	TNR_FF: 95.44
# ValLoss_HS: 0.155760	TPR_HS: 96.42	TNR_HS: 96.89
# ValLossALL: 0.186925	TPRALL: 94.48	TNRALL: 96.63
# Time: 4.08
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 40
# Loss_MF: 0.179655	TPR_MF: 96.09	TNR_MF: 96.10
# Loss_FF: 0.209315	TPR_FF: 96.15	TNR_FF: 95.89
# Loss_HS: 0.158356	TPR_HS: 95.64	TNR_HS: 97.30
# LossALL: 0.182121	TPRALL: 96.09	TNRALL: 96.47
# Time: 49.80
#
# Epoch:40
# ValLoss_MF: 0.205349	TPR_MF: 91.96	TNR_MF: 96.93
# ValLoss_FF: 0.286161	TPR_FF: 86.30	TNR_FF: 95.69
# ValLoss_HS: 0.144186	TPR_HS: 95.96	TNR_HS: 96.92
# ValLossALL: 0.211899	TPRALL: 91.96	TNRALL: 96.92
# Time: 4.14
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 41
# Loss_MF: 0.176424	TPR_MF: 95.27	TNR_MF: 96.48
# Loss_FF: 0.205496	TPR_FF: 95.40	TNR_FF: 95.77
# Loss_HS: 0.170971	TPR_HS: 96.08	TNR_HS: 96.81
# LossALL: 0.184346	TPRALL: 95.45	TNRALL: 96.43
# Time: 50.44
#
# Epoch:41
# ValLoss_MF: 0.156086	TPR_MF: 95.27	TNR_MF: 97.01
# ValLoss_FF: 0.253981	TPR_FF: 87.22	TNR_FF: 96.08
# ValLoss_HS: 0.158025	TPR_HS: 96.14	TNR_HS: 97.12
# ValLossALL: 0.189364	TPRALL: 95.27	TNRALL: 97.01
# Time: 3.96
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 42
# Loss_MF: 0.172951	TPR_MF: 95.04	TNR_MF: 96.46
# Loss_FF: 0.215393	TPR_FF: 94.27	TNR_FF: 95.31
# Loss_HS: 0.163160	TPR_HS: 95.86	TNR_HS: 96.99
# LossALL: 0.184079	TPRALL: 95.30	TNRALL: 96.58
# Time: 49.99
#
# Epoch:42
# ValLoss_MF: 0.194434	TPR_MF: 93.39	TNR_MF: 96.38
# ValLoss_FF: 0.213761	TPR_FF: 93.47	TNR_FF: 96.03
# ValLoss_HS: 0.162266	TPR_HS: 95.08	TNR_HS: 96.88
# ValLossALL: 0.190154	TPRALL: 93.47	TNRALL: 96.38
# Time: 3.96
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 43
# Loss_MF: 0.182405	TPR_MF: 94.27	TNR_MF: 96.06
# Loss_FF: 0.218217	TPR_FF: 95.79	TNR_FF: 95.51
# Loss_HS: 0.168895	TPR_HS: 96.55	TNR_HS: 96.77
# LossALL: 0.189867	TPRALL: 95.75	TNRALL: 96.31
# Time: 49.52
#
# Epoch:43
# ValLoss_MF: 0.170405	TPR_MF: 92.94	TNR_MF: 97.25
# ValLoss_FF: 0.255718	TPR_FF: 87.46	TNR_FF: 95.78
# ValLoss_HS: 0.142500	TPR_HS: 95.71	TNR_HS: 97.26
# ValLossALL: 0.189541	TPRALL: 92.94	TNRALL: 97.25
# Time: 4.07
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 44
# Loss_MF: 0.180960	TPR_MF: 94.51	TNR_MF: 96.50
# Loss_FF: 0.218471	TPR_FF: 94.78	TNR_FF: 95.36
# Loss_HS: 0.157101	TPR_HS: 96.17	TNR_HS: 96.93
# LossALL: 0.185209	TPRALL: 95.57	TNRALL: 96.68
# Time: 49.20
#
# Epoch:44
# ValLoss_MF: 0.160269	TPR_MF: 96.81	TNR_MF: 96.58
# ValLoss_FF: 0.209976	TPR_FF: 93.09	TNR_FF: 95.46
# ValLoss_HS: 0.222207	TPR_HS: 92.52	TNR_HS: 96.46
# ValLossALL: 0.197484	TPRALL: 93.09	TNRALL: 96.46
# Time: 3.93
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 45
# Loss_MF: 0.172981	TPR_MF: 95.58	TNR_MF: 96.39
# Loss_FF: 0.205779	TPR_FF: 95.22	TNR_FF: 95.95
# Loss_HS: 0.161467	TPR_HS: 96.37	TNR_HS: 96.94
# LossALL: 0.180130	TPRALL: 95.79	TNRALL: 96.46
# Time: 49.68
#
# Epoch:45
# ValLoss_MF: 0.171700	TPR_MF: 94.52	TNR_MF: 96.93
# ValLoss_FF: 0.207879	TPR_FF: 92.76	TNR_FF: 96.14
# ValLoss_HS: 0.153176	TPR_HS: 96.10	TNR_HS: 96.95
# ValLossALL: 0.177585	TPRALL: 94.52	TNRALL: 96.93
# Time: 4.00
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 46
# Loss_MF: 0.170642	TPR_MF: 96.15	TNR_MF: 96.28
# Loss_FF: 0.218321	TPR_FF: 94.77	TNR_FF: 95.55
# Loss_HS: 0.163820	TPR_HS: 96.39	TNR_HS: 96.93
# LossALL: 0.184397	TPRALL: 95.88	TNRALL: 96.46
# Time: 49.82
#
# Epoch:46
# ValLoss_MF: 0.240529	TPR_MF: 91.97	TNR_MF: 96.27
# ValLoss_FF: 0.200918	TPR_FF: 94.33	TNR_FF: 95.71
# ValLoss_HS: 0.152162	TPR_HS: 96.92	TNR_HS: 96.70
# ValLossALL: 0.197869	TPRALL: 94.33	TNRALL: 96.27
# Time: 3.89
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 47
# Loss_MF: 0.172037	TPR_MF: 96.37	TNR_MF: 96.47
# Loss_FF: 0.209927	TPR_FF: 94.91	TNR_FF: 95.65
# Loss_HS: 0.155352	TPR_HS: 95.69	TNR_HS: 97.02
# LossALL: 0.179053	TPRALL: 95.74	TNRALL: 96.50
# Time: 50.42
#
# Epoch:47
# ValLoss_MF: 0.219759	TPR_MF: 91.29	TNR_MF: 96.69
# ValLoss_FF: 0.222530	TPR_FF: 92.50	TNR_FF: 95.44
# ValLoss_HS: 0.213013	TPR_HS: 93.48	TNR_HS: 96.89
# ValLossALL: 0.218434	TPRALL: 92.50	TNRALL: 96.69
# Time: 4.01
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 48
# Loss_MF: 0.174441	TPR_MF: 95.13	TNR_MF: 96.53
# Loss_FF: 0.205396	TPR_FF: 95.81	TNR_FF: 95.71
# Loss_HS: 0.161529	TPR_HS: 96.00	TNR_HS: 97.02
# LossALL: 0.180437	TPRALL: 95.42	TNRALL: 96.57
# Time: 49.66
#
# Epoch:48
# ValLoss_MF: 0.191149	TPR_MF: 93.62	TNR_MF: 95.93
# ValLoss_FF: 0.191071	TPR_FF: 96.20	TNR_FF: 95.07
# ValLoss_HS: 0.235252	TPR_HS: 93.53	TNR_HS: 96.48
# ValLossALL: 0.205824	TPRALL: 93.62	TNRALL: 95.93
# Time: 3.84
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 49
# Loss_MF: 0.173112	TPR_MF: 96.42	TNR_MF: 96.21
# Loss_FF: 0.212840	TPR_FF: 93.77	TNR_FF: 95.51
# Loss_HS: 0.164796	TPR_HS: 96.51	TNR_HS: 96.79
# LossALL: 0.183840	TPRALL: 96.38	TNRALL: 96.28
# Time: 50.39
#
# Epoch:49
# ValLoss_MF: 0.165542	TPR_MF: 94.70	TNR_MF: 96.92
# ValLoss_FF: 0.184959	TPR_FF: 93.06	TNR_FF: 97.16
# ValLoss_HS: 0.156098	TPR_HS: 95.86	TNR_HS: 97.13
# ValLossALL: 0.168866	TPRALL: 94.70	TNRALL: 97.13
# Time: 4.02
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 50
# Loss_MF: 0.176629	TPR_MF: 94.86	TNR_MF: 96.38
# Loss_FF: 0.207137	TPR_FF: 95.88	TNR_FF: 95.63
# Loss_HS: 0.163410	TPR_HS: 95.92	TNR_HS: 97.00
# LossALL: 0.181874	TPRALL: 95.68	TNRALL: 96.55
# Time: 52.57
#
# Epoch:50
# ValLoss_MF: 0.161250	TPR_MF: 95.77	TNR_MF: 96.58
# ValLoss_FF: 0.194015	TPR_FF: 96.18	TNR_FF: 95.32
# ValLoss_HS: 0.120847	TPR_HS: 98.84	TNR_HS: 97.14
# ValLossALL: 0.158704	TPRALL: 96.18	TNRALL: 96.58
# Time: 3.91
# EarlyStopping counter: 20 out of 20
#
# Early stopping
# Network(
#   (lstm): LSTM(18, 512, num_layers=5, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear): Linear(in_features=1024, out_features=1, bias=True)
# )
# TO-512-HS-5-NL-0.0001-LR-0.3-DO
#
# Epoch: 0
# Loss_MF: 0.913145	TPR_MF: 0.00	TNR_MF: 100.00
# Loss_FF: 0.669855	TPR_FF: 77.96	TNR_FF: 79.80
# Loss_HS: 0.405178	TPR_HS: 87.86	TNR_HS: 86.55
# LossALL: 0.642138	TPRALL: 80.66	TNRALL: 88.83
# Time: 59.55
#
# Epoch:0
# ValLoss_MF: 0.315981	TPR_MF: 88.75	TNR_MF: 91.86
# ValLoss_FF: 0.496966	TPR_FF: 86.68	TNR_FF: 91.49
# ValLoss_HS: 0.281280	TPR_HS: 92.20	TNR_HS: 92.19
# ValLossALL: 0.364743	TPRALL: 88.75	TNRALL: 91.86
# Time: 4.13
# Validation loss decreased (inf --> 0.364743).  Saving model
#
#
# Epoch: 1
# Loss_MF: 0.266739	TPR_MF: 94.44	TNR_MF: 92.96
# Loss_FF: 0.429929	TPR_FF: 91.99	TNR_FF: 92.98
# Loss_HS: 0.255916	TPR_HS: 94.94	TNR_HS: 94.62
# LossALL: 0.319380	TPRALL: 94.04	TNRALL: 93.25
# Time: 58.73
#
# Epoch:1
# ValLoss_MF: 0.345771	TPR_MF: 84.57	TNR_MF: 95.37
# ValLoss_FF: 0.328557	TPR_FF: 82.69	TNR_FF: 94.85
# ValLoss_HS: 0.213929	TPR_HS: 94.96	TNR_HS: 96.09
# ValLossALL: 0.296086	TPRALL: 84.57	TNRALL: 95.37
# Time: 4.12
# Validation loss decreased (0.364743 --> 0.296086).  Saving model
#
#
# Epoch: 2
# Loss_MF: 0.242653	TPR_MF: 92.72	TNR_MF: 95.71
# Loss_FF: 0.378011	TPR_FF: 93.08	TNR_FF: 92.58
# Loss_HS: 0.213712	TPR_HS: 95.33	TNR_HS: 96.20
# LossALL: 0.278256	TPRALL: 94.06	TNRALL: 95.10
# Time: 59.53
#
# Epoch:2
# ValLoss_MF: 0.264478	TPR_MF: 89.05	TNR_MF: 95.88
# ValLoss_FF: 0.436441	TPR_FF: 84.13	TNR_FF: 95.00
# ValLoss_HS: 0.329499	TPR_HS: 93.36	TNR_HS: 95.71
# ValLossALL: 0.343473	TPRALL: 89.05	TNRALL: 95.71
# Time: 4.10
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 3
# Loss_MF: 0.231292	TPR_MF: 94.00	TNR_MF: 95.56
# Loss_FF: 0.329091	TPR_FF: 92.03	TNR_FF: 93.72
# Loss_HS: 0.207022	TPR_HS: 95.35	TNR_HS: 96.28
# LossALL: 0.256307	TPRALL: 94.26	TNRALL: 95.49
# Time: 59.74
#
# Epoch:3
# ValLoss_MF: 0.174151	TPR_MF: 94.44	TNR_MF: 96.89
# ValLoss_FF: 0.347699	TPR_FF: 82.96	TNR_FF: 96.05
# ValLoss_HS: 0.226976	TPR_HS: 93.09	TNR_HS: 97.03
# ValLossALL: 0.249609	TPRALL: 93.09	TNRALL: 96.89
# Time: 4.24
# Validation loss decreased (0.296086 --> 0.249609).  Saving model
#
#
# Epoch: 4
# Loss_MF: 0.227204	TPR_MF: 92.62	TNR_MF: 95.98
# Loss_FF: 0.329187	TPR_FF: 91.81	TNR_FF: 94.11
# Loss_HS: 0.199483	TPR_HS: 96.06	TNR_HS: 96.17
# LossALL: 0.251899	TPRALL: 94.71	TNRALL: 95.27
# Time: 59.30
#
# Epoch:4
# ValLoss_MF: 0.221712	TPR_MF: 91.10	TNR_MF: 96.23
# ValLoss_FF: 0.299816	TPR_FF: 88.32	TNR_FF: 95.86
# ValLoss_HS: 0.156143	TPR_HS: 97.16	TNR_HS: 96.49
# ValLossALL: 0.225890	TPRALL: 91.10	TNRALL: 96.23
# Time: 3.90
# Validation loss decreased (0.249609 --> 0.225890).  Saving model
#
#
# Epoch: 5
# Loss_MF: 0.207599	TPR_MF: 94.26	TNR_MF: 96.26
# Loss_FF: 0.316401	TPR_FF: 92.65	TNR_FF: 94.44
# Loss_HS: 0.194211	TPR_HS: 96.20	TNR_HS: 96.27
# LossALL: 0.238878	TPRALL: 95.04	TNRALL: 95.74
# Time: 59.45
#
# Epoch:5
# ValLoss_MF: 0.277704	TPR_MF: 86.74	TNR_MF: 96.35
# ValLoss_FF: 0.406596	TPR_FF: 84.44	TNR_FF: 95.96
# ValLoss_HS: 0.160372	TPR_HS: 95.19	TNR_HS: 96.75
# ValLossALL: 0.281557	TPRALL: 86.74	TNRALL: 96.35
# Time: 3.97
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 6
# Loss_MF: 0.217391	TPR_MF: 94.39	TNR_MF: 95.83
# Loss_FF: 0.311631	TPR_FF: 96.51	TNR_FF: 94.23
# Loss_HS: 0.192704	TPR_HS: 95.06	TNR_HS: 96.47
# LossALL: 0.240052	TPRALL: 95.05	TNRALL: 95.88
# Time: 58.68
#
# Epoch:6
# ValLoss_MF: 0.160711	TPR_MF: 96.20	TNR_MF: 96.82
# ValLoss_FF: 0.382774	TPR_FF: 84.04	TNR_FF: 95.75
# ValLoss_HS: 0.159564	TPR_HS: 95.57	TNR_HS: 96.88
# ValLossALL: 0.234350	TPRALL: 95.57	TNRALL: 96.82
# Time: 3.99
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 7
# Loss_MF: 0.219300	TPR_MF: 94.62	TNR_MF: 95.46
# Loss_FF: 0.314322	TPR_FF: 95.22	TNR_FF: 94.04
# Loss_HS: 0.204266	TPR_HS: 95.70	TNR_HS: 96.03
# LossALL: 0.245895	TPRALL: 95.36	TNRALL: 95.70
# Time: 59.33
#
# Epoch:7
# ValLoss_MF: 0.185206	TPR_MF: 97.10	TNR_MF: 95.81
# ValLoss_FF: 0.344548	TPR_FF: 90.03	TNR_FF: 94.80
# ValLoss_HS: 0.155588	TPR_HS: 98.87	TNR_HS: 96.16
# ValLossALL: 0.228447	TPRALL: 97.10	TNRALL: 95.81
# Time: 3.99
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 8
# Loss_MF: 0.204084	TPR_MF: 93.82	TNR_MF: 96.14
# Loss_FF: 0.275611	TPR_FF: 91.46	TNR_FF: 95.13
# Loss_HS: 0.182437	TPR_HS: 95.42	TNR_HS: 96.31
# LossALL: 0.220947	TPRALL: 94.86	TNRALL: 95.81
# Time: 59.01
#
# Epoch:8
# ValLoss_MF: 0.206131	TPR_MF: 92.32	TNR_MF: 96.75
# ValLoss_FF: 0.399525	TPR_FF: 83.68	TNR_FF: 95.40
# ValLoss_HS: 0.165694	TPR_HS: 94.89	TNR_HS: 96.70
# ValLossALL: 0.257117	TPRALL: 92.32	TNRALL: 96.70
# Time: 3.96
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 9
# Loss_MF: 0.200539	TPR_MF: 94.40	TNR_MF: 95.81
# Loss_FF: 0.301333	TPR_FF: 95.54	TNR_FF: 94.45
# Loss_HS: 0.195895	TPR_HS: 96.04	TNR_HS: 96.56
# LossALL: 0.233137	TPRALL: 95.54	TNRALL: 95.96
# Time: 58.89
#
# Epoch:9
# ValLoss_MF: 0.160759	TPR_MF: 96.46	TNR_MF: 96.68
# ValLoss_FF: 0.301385	TPR_FF: 89.83	TNR_FF: 95.37
# ValLoss_HS: 0.149775	TPR_HS: 97.07	TNR_HS: 96.84
# ValLossALL: 0.203973	TPRALL: 96.46	TNRALL: 96.68
# Time: 3.89
# Validation loss decreased (0.225890 --> 0.203973).  Saving model
#
#
# Epoch: 10
# Loss_MF: 0.196202	TPR_MF: 94.75	TNR_MF: 96.33
# Loss_FF: 0.284646	TPR_FF: 93.81	TNR_FF: 94.81
# Loss_HS: 0.184304	TPR_HS: 96.22	TNR_HS: 96.29
# LossALL: 0.221752	TPRALL: 94.95	TNRALL: 96.08
# Time: 59.20
#
# Epoch:10
# ValLoss_MF: 0.242046	TPR_MF: 92.91	TNR_MF: 96.98
# ValLoss_FF: 0.231232	TPR_FF: 91.74	TNR_FF: 95.94
# ValLoss_HS: 0.210738	TPR_HS: 95.31	TNR_HS: 97.19
# ValLossALL: 0.228005	TPRALL: 92.91	TNRALL: 96.98
# Time: 4.12
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.191543	TPR_MF: 94.60	TNR_MF: 96.05
# Loss_FF: 0.275694	TPR_FF: 92.44	TNR_FF: 95.39
# Loss_HS: 0.181257	TPR_HS: 94.72	TNR_HS: 96.71
# LossALL: 0.216452	TPRALL: 94.42	TNRALL: 96.18
# Time: 60.69
#
# Epoch:11
# ValLoss_MF: 0.172979	TPR_MF: 95.00	TNR_MF: 96.45
# ValLoss_FF: 0.300645	TPR_FF: 87.97	TNR_FF: 95.05
# ValLoss_HS: 0.155221	TPR_HS: 97.22	TNR_HS: 96.60
# ValLossALL: 0.209615	TPRALL: 95.00	TNRALL: 96.45
# Time: 3.97
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.193487	TPR_MF: 94.93	TNR_MF: 95.80
# Loss_FF: 0.248212	TPR_FF: 93.52	TNR_FF: 94.97
# Loss_HS: 0.182427	TPR_HS: 95.64	TNR_HS: 96.61
# LossALL: 0.208112	TPRALL: 94.96	TNRALL: 95.87
# Time: 59.22
#
# Epoch:12
# ValLoss_MF: 0.153692	TPR_MF: 96.17	TNR_MF: 96.85
# ValLoss_FF: 0.342817	TPR_FF: 84.12	TNR_FF: 95.47
# ValLoss_HS: 0.151161	TPR_HS: 96.25	TNR_HS: 96.94
# ValLossALL: 0.215890	TPRALL: 96.17	TNRALL: 96.85
# Time: 3.89
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.191174	TPR_MF: 95.61	TNR_MF: 95.97
# Loss_FF: 0.302426	TPR_FF: 91.82	TNR_FF: 94.50
# Loss_HS: 0.188380	TPR_HS: 97.09	TNR_HS: 95.81
# LossALL: 0.228745	TPRALL: 95.45	TNRALL: 95.62
# Time: 59.00
#
# Epoch:13
# ValLoss_MF: 0.209450	TPR_MF: 94.73	TNR_MF: 95.28
# ValLoss_FF: 0.252795	TPR_FF: 93.40	TNR_FF: 95.05
# ValLoss_HS: 0.186550	TPR_HS: 97.18	TNR_HS: 95.82
# ValLossALL: 0.216265	TPRALL: 94.73	TNRALL: 95.28
# Time: 3.91
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.191035	TPR_MF: 94.87	TNR_MF: 96.17
# Loss_FF: 0.278929	TPR_FF: 91.61	TNR_FF: 95.55
# Loss_HS: 0.177138	TPR_HS: 96.84	TNR_HS: 96.40
# LossALL: 0.215916	TPRALL: 94.92	TNRALL: 96.18
# Time: 58.51
#
# Epoch:14
# ValLoss_MF: 0.157414	TPR_MF: 93.99	TNR_MF: 97.35
# ValLoss_FF: 0.269066	TPR_FF: 88.27	TNR_FF: 96.27
# ValLoss_HS: 0.279684	TPR_HS: 92.62	TNR_HS: 97.43
# ValLossALL: 0.235388	TPRALL: 92.62	TNRALL: 97.35
# Time: 4.07
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 15
# Loss_MF: 0.185829	TPR_MF: 95.11	TNR_MF: 96.12
# Loss_FF: 0.295964	TPR_FF: 91.94	TNR_FF: 94.77
# Loss_HS: 0.182920	TPR_HS: 95.40	TNR_HS: 96.64
# LossALL: 0.222970	TPRALL: 94.19	TNRALL: 96.18
# Time: 58.70
#
# Epoch:15
# ValLoss_MF: 0.219667	TPR_MF: 92.04	TNR_MF: 96.21
# ValLoss_FF: 0.192263	TPR_FF: 94.16	TNR_FF: 95.99
# ValLoss_HS: 0.172051	TPR_HS: 94.58	TNR_HS: 96.65
# ValLossALL: 0.194660	TPRALL: 94.16	TNRALL: 96.21
# Time: 3.93
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 16
# Loss_MF: 0.192233	TPR_MF: 95.23	TNR_MF: 96.09
# Loss_FF: 0.261488	TPR_FF: 95.49	TNR_FF: 94.59
# Loss_HS: 0.179754	TPR_HS: 95.84	TNR_HS: 96.58
# LossALL: 0.211676	TPRALL: 95.30	TNRALL: 95.88
# Time: 59.04
#
# Epoch:16
# ValLoss_MF: 0.160847	TPR_MF: 97.59	TNR_MF: 96.26
# ...
# ValLossALL: 0.289020	TPRALL: 89.32	TNRALL: 96.27
# Time: 5.10
# Validation loss decreased (0.322559 --> 0.289020).  Saving model
#
#
# Epoch: 2
# Loss_MF: 0.238327	TPR_MF: 95.32	TNR_MF: 94.56
# Loss_FF: 0.346398	TPR_FF: 93.61	TNR_FF: 93.97
# Loss_HS: 0.199693	TPR_HS: 94.46	TNR_HS: 96.47
# LossALL: 0.260390	TPRALL: 94.61	TNRALL: 95.18
# Time: 117.17
#
# Epoch:2
# ValLoss_MF: 0.215774	TPR_MF: 91.85	TNR_MF: 96.75
# ValLoss_FF: 0.385377	TPR_FF: 85.83	TNR_FF: 96.01
# ValLoss_HS: 0.171646	TPR_HS: 95.06	TNR_HS: 96.70
# ValLossALL: 0.257599	TPRALL: 91.85	TNRALL: 96.70
# Time: 5.31
# Validation loss decreased (0.289020 --> 0.257599).  Saving model
#
#
# Epoch: 3
# Loss_MF: 0.241057	TPR_MF: 95.84	TNR_MF: 94.72
# Loss_FF: 0.344379	TPR_FF: 90.23	TNR_FF: 94.68
# Loss_HS: 0.232571	TPR_HS: 96.04	TNR_HS: 95.87
# LossALL: 0.273786	TPRALL: 95.31	TNRALL: 95.02
# Time: 117.36
#
# Epoch:3
# ValLoss_MF: 0.173416	TPR_MF: 93.66	TNR_MF: 96.69
# ValLoss_FF: 0.395698	TPR_FF: 82.83	TNR_FF: 95.16
# ValLoss_HS: 0.167677	TPR_HS: 96.65	TNR_HS: 96.52
# ValLossALL: 0.245597	TPRALL: 93.66	TNRALL: 96.52
# Time: 5.21
# Validation loss decreased (0.257599 --> 0.245597).  Saving model
#
#
# Epoch: 4
# Loss_MF: 0.215427	TPR_MF: 94.94	TNR_MF: 95.43
# Loss_FF: 0.336026	TPR_FF: 94.82	TNR_FF: 94.34
# Loss_HS: 0.203535	TPR_HS: 95.61	TNR_HS: 96.29
# LossALL: 0.252899	TPRALL: 94.97	TNRALL: 95.36
# Time: 116.37
#
# Epoch:4
# ValLoss_MF: 0.157357	TPR_MF: 96.11	TNR_MF: 96.67
# ValLoss_FF: 0.276468	TPR_FF: 89.50	TNR_FF: 95.86
# ValLoss_HS: 0.164477	TPR_HS: 95.62	TNR_HS: 96.90
# ValLossALL: 0.199434	TPRALL: 95.62	TNRALL: 96.67
# Time: 5.18
# Validation loss decreased (0.245597 --> 0.199434).  Saving model
#
#
# Epoch: 5
# Loss_MF: 0.217280	TPR_MF: 95.08	TNR_MF: 95.07
# Loss_FF: 0.328776	TPR_FF: 93.01	TNR_FF: 94.49
# Loss_HS: 0.198036	TPR_HS: 96.38	TNR_HS: 96.44
# LossALL: 0.248261	TPRALL: 94.67	TNRALL: 95.17
# Time: 118.51
#
# Epoch:5
# ValLoss_MF: 0.202614	TPR_MF: 91.54	TNR_MF: 96.57
# ValLoss_FF: 0.412850	TPR_FF: 83.63	TNR_FF: 96.08
# ValLoss_HS: 0.160526	TPR_HS: 94.51	TNR_HS: 97.09
# ValLossALL: 0.258663	TPRALL: 91.54	TNRALL: 96.57
# Time: 5.24
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 6
# Loss_MF: 0.213809	TPR_MF: 94.51	TNR_MF: 95.66
# Loss_FF: 0.328012	TPR_FF: 94.86	TNR_FF: 94.15
# Loss_HS: 0.186381	TPR_HS: 95.24	TNR_HS: 96.77
# LossALL: 0.242215	TPRALL: 95.23	TNRALL: 96.11
# Time: 117.94
#
# Epoch:6
# ValLoss_MF: 0.193711	TPR_MF: 92.24	TNR_MF: 96.64
# ValLoss_FF: 0.243852	TPR_FF: 88.11	TNR_FF: 96.20
# ValLoss_HS: 0.163925	TPR_HS: 97.11	TNR_HS: 96.45
# ValLossALL: 0.200496	TPRALL: 92.24	TNRALL: 96.45
# Time: 5.30
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 7
# Loss_MF: 0.199812	TPR_MF: 95.19	TNR_MF: 95.34
# Loss_FF: 0.350018	TPR_FF: 94.04	TNR_FF: 94.18
# Loss_HS: 0.195802	TPR_HS: 95.08	TNR_HS: 96.55
# LossALL: 0.249439	TPRALL: 94.99	TNRALL: 95.90
# Time: 117.68
#
# Epoch:7
# ValLoss_MF: 0.176640	TPR_MF: 94.75	TNR_MF: 96.46
# ValLoss_FF: 0.240390	TPR_FF: 91.96	TNR_FF: 96.11
# ValLoss_HS: 0.228268	TPR_HS: 93.63	TNR_HS: 96.62
# ValLossALL: 0.215099	TPRALL: 93.63	TNRALL: 96.46
# Time: 5.26
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 8
# Loss_MF: 0.195739	TPR_MF: 95.84	TNR_MF: 95.58
# Loss_FF: 0.339137	TPR_FF: 90.36	TNR_FF: 95.41
# Loss_HS: 0.193147	TPR_HS: 95.93	TNR_HS: 96.85
# LossALL: 0.243561	TPRALL: 95.49	TNRALL: 95.75
# Time: 118.23
#
# Epoch:8
# ValLoss_MF: 0.234265	TPR_MF: 88.79	TNR_MF: 97.11
# ValLoss_FF: 0.266588	TPR_FF: 89.37	TNR_FF: 97.03
# ValLoss_HS: 0.171587	TPR_HS: 92.95	TNR_HS: 97.31
# ValLossALL: 0.224147	TPRALL: 89.37	TNRALL: 97.11
# Time: 5.08
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 9
# Loss_MF: 0.195859	TPR_MF: 95.94	TNR_MF: 95.57
# Loss_FF: 0.333408	TPR_FF: 92.69	TNR_FF: 95.15
# Loss_HS: 0.199228	TPR_HS: 96.05	TNR_HS: 96.52
# LossALL: 0.243838	TPRALL: 95.26	TNRALL: 95.79
# Time: 117.73
#
# Epoch:9
# ValLoss_MF: 0.193079	TPR_MF: 92.32	TNR_MF: 96.84
# ValLoss_FF: 0.275287	TPR_FF: 85.56	TNR_FF: 96.56
# ValLoss_HS: 0.203997	TPR_HS: 91.44	TNR_HS: 97.01
# ValLossALL: 0.224121	TPRALL: 91.44	TNRALL: 96.84
# Time: 5.05
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 10
# Loss_MF: 0.199409	TPR_MF: 95.12	TNR_MF: 96.23
# Loss_FF: 0.311830	TPR_FF: 91.94	TNR_FF: 95.03
# Loss_HS: 0.190049	TPR_HS: 95.52	TNR_HS: 96.50
# LossALL: 0.234263	TPRALL: 95.41	TNRALL: 96.13
# Time: 117.41
#
# Epoch:10
# ValLoss_MF: 0.203175	TPR_MF: 92.39	TNR_MF: 96.53
# ValLoss_FF: 0.284729	TPR_FF: 87.68	TNR_FF: 96.09
# ValLoss_HS: 0.156394	TPR_HS: 96.51	TNR_HS: 96.96
# ValLossALL: 0.214766	TPRALL: 92.39	TNRALL: 96.53
# Time: 5.20
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 11
# Loss_MF: 0.188358	TPR_MF: 95.28	TNR_MF: 96.21
# Loss_FF: 0.295822	TPR_FF: 94.06	TNR_FF: 95.06
# Loss_HS: 0.194524	TPR_HS: 95.47	TNR_HS: 96.36
# LossALL: 0.227906	TPRALL: 95.20	TNRALL: 95.82
# Time: 116.14
#
# Epoch:11
# ValLoss_MF: 0.245837	TPR_MF: 89.21	TNR_MF: 96.35
# ValLoss_FF: 0.337259	TPR_FF: 85.71	TNR_FF: 96.13
# ValLoss_HS: 0.172768	TPR_HS: 95.39	TNR_HS: 96.87
# ValLossALL: 0.251955	TPRALL: 89.21	TNRALL: 96.35
# Time: 5.16
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 12
# Loss_MF: 0.194088	TPR_MF: 95.28	TNR_MF: 95.93
# Loss_FF: 0.305641	TPR_FF: 93.75	TNR_FF: 95.20
# Loss_HS: 0.177035	TPR_HS: 95.50	TNR_HS: 96.78
# LossALL: 0.226526	TPRALL: 94.74	TNRALL: 96.00
# Time: 115.91
#
# Epoch:12
# ValLoss_MF: 0.182598	TPR_MF: 94.51	TNR_MF: 96.66
# ValLoss_FF: 0.258287	TPR_FF: 92.20	TNR_FF: 95.63
# ValLoss_HS: 0.223862	TPR_HS: 93.75	TNR_HS: 96.84
# ValLossALL: 0.221582	TPRALL: 93.75	TNRALL: 96.66
# Time: 5.34
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 13
# Loss_MF: 0.185585	TPR_MF: 95.39	TNR_MF: 96.11
# Loss_FF: 0.315600	TPR_FF: 91.31	TNR_FF: 94.05
# Loss_HS: 0.190193	TPR_HS: 95.96	TNR_HS: 96.66
# LossALL: 0.232385	TPRALL: 95.16	TNRALL: 95.73
# Time: 117.22
#
# Epoch:13
# ValLoss_MF: 0.160301	TPR_MF: 98.53	TNR_MF: 95.76
# ValLoss_FF: 0.238640	TPR_FF: 94.00	TNR_FF: 95.03
# ValLoss_HS: 0.177703	TPR_HS: 96.09	TNR_HS: 95.97
# ValLossALL: 0.192215	TPRALL: 96.09	TNRALL: 95.76
# Time: 5.22
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 14
# Loss_MF: 0.184963	TPR_MF: 96.16	TNR_MF: 95.88
# Loss_FF: 0.283279	TPR_FF: 93.94	TNR_FF: 95.18
# Loss_HS: 0.180044	TPR_HS: 96.37	TNR_HS: 96.66
# LossALL: 0.216521	TPRALL: 95.80	TNRALL: 95.89
# Time: 117.82
#
# Epoch:14
# ValLoss_MF: 0.242773	TPR_MF: 91.39	TNR_MF: 96.52
# ValLoss_FF: 0.245335	TPR_FF: 91.09	TNR_FF: 95.71
# ValLoss_HS: 0.159424	TPR_HS: 95.83	TNR_HS: 96.61
# ValLossALL: 0.215844	TPRALL: 91.39	TNRALL: 96.52
# Time: 5.29
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 15
# Loss_MF: 0.188399	TPR_MF: 95.96	TNR_MF: 95.83
# Loss_FF: 0.281393	TPR_FF: 89.98	TNR_FF: 95.43
# Loss_HS: 0.183450	TPR_HS: 96.15	TNR_HS: 95.79
# LossALL: 0.218844	TPRALL: 95.08	TNRALL: 95.51
# Time: 116.48
#
# Epoch:15
# ValLoss_MF: 0.160026	TPR_MF: 95.28	TNR_MF: 97.07
# ValLoss_FF: 0.206592	TPR_FF: 92.94	TNR_FF: 96.14
# ValLoss_HS: 0.166309	TPR_HS: 93.48	TNR_HS: 97.09
# ValLossALL: 0.177642	TPRALL: 93.48	TNRALL: 97.07
# Time: 5.29
# Validation loss decreased (0.199434 --> 0.177642).  Saving model
#
#
# Epoch: 16
# Loss_MF: 0.185176	TPR_MF: 95.25	TNR_MF: 96.02
# Loss_FF: 0.305234	TPR_FF: 90.26	TNR_FF: 94.91
# Loss_HS: 0.336104	TPR_HS: 91.79	TNR_HS: 97.11
# LossALL: 0.282272	TPRALL: 93.83	TNRALL: 96.08
# Time: 116.79
#
# Epoch:16
# ValLoss_MF: 0.332800	TPR_MF: 84.62	TNR_MF: 97.03
# ValLoss_FF: 0.528314	TPR_FF: 72.54	TNR_FF: 96.69
# ValLoss_HS: 0.431329	TPR_HS: 79.83	TNR_HS: 97.08
# ValLossALL: 0.430814	TPRALL: 79.83	TNRALL: 97.03
# Time: 5.20
# EarlyStopping counter: 1 out of 20
#
#
# Epoch: 17
# Loss_MF: 0.278134	TPR_MF: 89.07	TNR_MF: 96.49
# Loss_FF: 0.319384	TPR_FF: 94.14	TNR_FF: 94.71
# Loss_HS: 0.200618	TPR_HS: 96.14	TNR_HS: 96.16
# LossALL: 0.264253	TPRALL: 94.19	TNRALL: 96.09
# Time: 117.72
#
# Epoch:17
# ValLoss_MF: 0.189767	TPR_MF: 92.96	TNR_MF: 97.02
# ValLoss_FF: 0.310304	TPR_FF: 86.55	TNR_FF: 96.40
# ValLoss_HS: 0.215534	TPR_HS: 93.94	TNR_HS: 97.05
# ValLossALL: 0.238535	TPRALL: 92.96	TNRALL: 97.02
# Time: 5.23
# EarlyStopping counter: 2 out of 20
#
#
# Epoch: 18
# Loss_MF: 0.199103	TPR_MF: 95.42	TNR_MF: 95.41
# Loss_FF: 0.339062	TPR_FF: 89.30	TNR_FF: 95.33
# Loss_HS: 0.189451	TPR_HS: 95.69	TNR_HS: 96.75
# LossALL: 0.244115	TPRALL: 95.20	TNRALL: 95.85
# Time: 116.33
#
# Epoch:18
# ValLoss_MF: 0.182792	TPR_MF: 94.90	TNR_MF: 96.56
# ValLoss_FF: 0.207585	TPR_FF: 92.61	TNR_FF: 96.36
# ValLoss_HS: 0.207343	TPR_HS: 94.20	TNR_HS: 96.88
# ValLossALL: 0.199240	TPRALL: 94.20	TNRALL: 96.56
# Time: 5.32
# EarlyStopping counter: 3 out of 20
#
#
# Epoch: 19
# Loss_MF: 0.194481	TPR_MF: 95.81	TNR_MF: 95.91
# Loss_FF: 0.291998	TPR_FF: 95.90	TNR_FF: 95.21
# Loss_HS: 0.176449	TPR_HS: 95.93	TNR_HS: 97.03
# LossALL: 0.221689	TPRALL: 95.88	TNRALL: 95.96
# Time: 115.73
#
# Epoch:19
# ValLoss_MF: 0.174229	TPR_MF: 94.66	TNR_MF: 96.68
# ValLoss_FF: 0.254691	TPR_FF: 90.35	TNR_FF: 96.17
# ValLoss_HS: 0.179228	TPR_HS: 93.67	TNR_HS: 96.74
# ValLossALL: 0.202716	TPRALL: 93.67	TNRALL: 96.68
# Time: 5.17
# EarlyStopping counter: 4 out of 20
#
#
# Epoch: 20
# Loss_MF: 0.189724	TPR_MF: 94.32	TNR_MF: 96.28
# Loss_FF: 0.292323	TPR_FF: 95.00	TNR_FF: 94.71
# Loss_HS: 0.186366	TPR_HS: 95.33	TNR_HS: 96.63
# LossALL: 0.224086	TPRALL: 95.16	TNRALL: 96.32
# Time: 117.60
#
# Epoch:20
# ValLoss_MF: 0.203695	TPR_MF: 91.06	TNR_MF: 96.43
# ValLoss_FF: 0.313791	TPR_FF: 86.40	TNR_FF: 96.03
# ValLoss_HS: 0.210668	TPR_HS: 92.80	TNR_HS: 96.52
# ValLossALL: 0.242718	TPRALL: 91.06	TNRALL: 96.43
# Time: 5.39
# EarlyStopping counter: 5 out of 20
#
#
# Epoch: 21
# Loss_MF: 0.198168	TPR_MF: 95.01	TNR_MF: 95.80
# Loss_FF: 0.271653	TPR_FF: 93.28	TNR_FF: 95.66
# Loss_HS: 0.191690	TPR_HS: 95.68	TNR_HS: 95.45
# LossALL: 0.221283	TPRALL: 95.05	TNRALL: 95.66
# Time: 116.28
#
# Epoch:21
# ValLoss_MF: 0.183919	TPR_MF: 93.45	TNR_MF: 96.66
# ValLoss_FF: 0.256083	TPR_FF: 89.44	TNR_FF: 95.81
# ValLoss_HS: 0.265987	TPR_HS: 90.36	TNR_HS: 96.35
# ValLossALL: 0.235330	TPRALL: 90.36	TNRALL: 96.35
# Time: 5.11
# EarlyStopping counter: 6 out of 20
#
#
# Epoch: 22
# Loss_MF: 0.187049	TPR_MF: 95.37	TNR_MF: 95.92
# Loss_FF: 0.288395	TPR_FF: 93.13	TNR_FF: 95.30
# Loss_HS: 0.183298	TPR_HS: 95.87	TNR_HS: 96.93
# LossALL: 0.220832	TPRALL: 95.26	TNRALL: 95.84
# Time: 115.58
#
# Epoch:22
# ValLoss_MF: 0.242831	TPR_MF: 89.63	TNR_MF: 96.73
# ValLoss_FF: 0.280362	TPR_FF: 88.65	TNR_FF: 96.33
# ValLoss_HS: 0.163061	TPR_HS: 95.10	TNR_HS: 97.05
# ValLossALL: 0.228751	TPRALL: 89.63	TNRALL: 96.73
# Time: 5.22
# EarlyStopping counter: 7 out of 20
#
#
# Epoch: 23
# Loss_MF: 0.191750	TPR_MF: 95.66	TNR_MF: 95.78
# Loss_FF: 0.274362	TPR_FF: 95.90	TNR_FF: 95.74
# Loss_HS: 0.188204	TPR_HS: 96.28	TNR_HS: 96.35
# LossALL: 0.218562	TPRALL: 95.71	TNRALL: 95.78
# Time: 118.06
#
# Epoch:23
# ValLoss_MF: 0.183264	TPR_MF: 93.28	TNR_MF: 96.94
# ValLoss_FF: 0.383425	TPR_FF: 83.13	TNR_FF: 95.76
# ValLoss_HS: 0.145265	TPR_HS: 96.07	TNR_HS: 97.24
# ValLossALL: 0.237318	TPRALL: 93.28	TNRALL: 96.94
# Time: 5.29
# EarlyStopping counter: 8 out of 20
#
#
# Epoch: 24
# Loss_MF: 0.187484	TPR_MF: 94.71	TNR_MF: 96.19
# Loss_FF: 0.258171	TPR_FF: 94.79	TNR_FF: 94.89
# Loss_HS: 0.172081	TPR_HS: 96.25	TNR_HS: 96.94
# LossALL: 0.205664	TPRALL: 95.39	TNRALL: 96.21
# Time: 117.69
#
# Epoch:24
# ValLoss_MF: 0.188197	TPR_MF: 94.73	TNR_MF: 96.45
# ValLoss_FF: 0.307853	TPR_FF: 88.03	TNR_FF: 95.63
# ValLoss_HS: 0.184505	TPR_HS: 94.54	TNR_HS: 96.71
# ValLossALL: 0.226852	TPRALL: 94.54	TNRALL: 96.45
# Time: 5.18
# EarlyStopping counter: 9 out of 20
#
#
# Epoch: 25
# Loss_MF: 0.185591	TPR_MF: 95.42	TNR_MF: 96.36
# Loss_FF: 0.262418	TPR_FF: 96.09	TNR_FF: 95.21
# Loss_HS: 0.174926	TPR_HS: 96.04	TNR_HS: 96.92
# LossALL: 0.208327	TPRALL: 95.80	TNRALL: 96.34
# Time: 116.88
#
# Epoch:25
# ValLoss_MF: 0.200444	TPR_MF: 91.87	TNR_MF: 96.70
# ValLoss_FF: 0.372505	TPR_FF: 82.83	TNR_FF: 96.02
# ValLoss_HS: 0.149435	TPR_HS: 95.76	TNR_HS: 97.38
# ValLossALL: 0.240795	TPRALL: 91.87	TNRALL: 96.70
# Time: 5.34
# EarlyStopping counter: 10 out of 20
#
#
# Epoch: 26
# Loss_MF: 0.182749	TPR_MF: 95.19	TNR_MF: 96.43
# Loss_FF: 0.256610	TPR_FF: 92.57	TNR_FF: 95.11
# Loss_HS: 0.177235	TPR_HS: 96.77	TNR_HS: 96.56
# LossALL: 0.206349	TPRALL: 95.12	TNRALL: 96.12
# Time: 116.96
#
# Epoch:26
# ValLoss_MF: 0.187892	TPR_MF: 93.73	TNR_MF: 96.73
# ValLoss_FF: 0.320792	TPR_FF: 87.79	TNR_FF: 95.49
# ValLoss_HS: 0.193228	TPR_HS: 95.11	TNR_HS: 96.77
# ValLossALL: 0.233970	TPRALL: 93.73	TNRALL: 96.73
# Time: 5.15
# EarlyStopping counter: 11 out of 20
#
#
# Epoch: 27
# Loss_MF: 0.184966	TPR_MF: 95.90	TNR_MF: 96.03
# Loss_FF: 0.252111	TPR_FF: 93.62	TNR_FF: 95.52
# Loss_HS: 0.174935	TPR_HS: 96.64	TNR_HS: 96.74
# LossALL: 0.203610	TPRALL: 95.58	TNRALL: 96.28
# Time: 118.99
#
# Epoch:27
# ValLoss_MF: 0.161656	TPR_MF: 96.12	TNR_MF: 96.91
# ValLoss_FF: 0.292160	TPR_FF: 87.55	TNR_FF: 96.17
# ValLoss_HS: 0.155381	TPR_HS: 95.52	TNR_HS: 96.81
# ValLossALL: 0.203065	TPRALL: 95.52	TNRALL: 96.81
# Time: 5.06
# EarlyStopping counter: 12 out of 20
#
#
# Epoch: 28
# Loss_MF: 0.184621	TPR_MF: 95.53	TNR_MF: 96.17
# Loss_FF: 0.271915	TPR_FF: 93.21	TNR_FF: 95.42
# Loss_HS: 0.168445	TPR_HS: 95.41	TNR_HS: 96.85
# LossALL: 0.208154	TPRALL: 95.34	TNRALL: 96.21
# Time: 117.93
#
# Epoch:28
# ValLoss_MF: 0.232331	TPR_MF: 92.88	TNR_MF: 95.84
# ValLoss_FF: 0.268045	TPR_FF: 90.34	TNR_FF: 95.04
# ValLoss_HS: 0.160252	TPR_HS: 94.78	TNR_HS: 97.02
# ValLossALL: 0.220209	TPRALL: 92.88	TNRALL: 95.84
# Time: 5.25
# EarlyStopping counter: 13 out of 20
#
#
# Epoch: 29
# Loss_MF: 0.181665	TPR_MF: 95.65	TNR_MF: 95.96
# Loss_FF: 0.248944	TPR_FF: 93.18	TNR_FF: 94.96
# Loss_HS: 0.172736	TPR_HS: 96.22	TNR_HS: 96.40
# LossALL: 0.201325	TPRALL: 95.59	TNRALL: 95.82
# Time: 117.69
#
# Epoch:29
# ValLoss_MF: 0.180690	TPR_MF: 94.16	TNR_MF: 96.46
# ValLoss_FF: 0.313525	TPR_FF: 91.53	TNR_FF: 95.25
# ValLoss_HS: 0.190653	TPR_HS: 91.99	TNR_HS: 96.92
# ValLossALL: 0.228289	TPRALL: 91.99	TNRALL: 96.46
# Time: 5.16
# EarlyStopping counter: 14 out of 20
#
#
# Epoch: 30
# Loss_MF: 0.184329	TPR_MF: 96.62	TNR_MF: 95.86
# Loss_FF: 0.239383	TPR_FF: 94.14	TNR_FF: 95.57
# Loss_HS: 0.172429	TPR_HS: 95.23	TNR_HS: 96.89
# LossALL: 0.199058	TPRALL: 95.52	TNRALL: 96.20
# Time: 116.24
#
# Epoch:30
# ValLoss_MF: 0.153628	TPR_MF: 95.87	TNR_MF: 96.78
# ValLoss_FF: 0.222785	TPR_FF: 92.09	TNR_FF: 95.86
# ValLoss_HS: 0.148356	TPR_HS: 97.49	TNR_HS: 96.77
# ValLossALL: 0.174923	TPRALL: 95.87	TNRALL: 96.77
# Time: 5.33
# EarlyStopping counter: 15 out of 20
#
#
# Epoch: 31
# Loss_MF: 0.185551	TPR_MF: 96.14	TNR_MF: 95.83
# Loss_FF: 0.280559	TPR_FF: 93.82	TNR_FF: 95.14
# Loss_HS: 0.164551	TPR_HS: 96.06	TNR_HS: 96.83
# LossALL: 0.209397	TPRALL: 95.79	TNRALL: 96.14
# Time: 119.20
#
# Epoch:31
# ValLoss_MF: 0.176281	TPR_MF: 94.09	TNR_MF: 96.85
# ValLoss_FF: 0.262287	TPR_FF: 88.97	TNR_FF: 95.91
# ValLoss_HS: 0.266219	TPR_HS: 92.03	TNR_HS: 97.06
# ValLossALL: 0.234929	TPRALL: 92.03	TNRALL: 96.85
# Time: 5.13
# EarlyStopping counter: 16 out of 20
#
#
# Epoch: 32
# Loss_MF: 0.183456	TPR_MF: 95.52	TNR_MF: 95.87
# Loss_FF: 0.245729	TPR_FF: 93.02	TNR_FF: 95.30
# Loss_HS: 0.183705	TPR_HS: 96.28	TNR_HS: 96.35
# LossALL: 0.204718	TPRALL: 95.89	TNRALL: 95.88
# Time: 117.65
#
# Epoch:32
# ValLoss_MF: 0.175918	TPR_MF: 96.49	TNR_MF: 96.40
# ValLoss_FF: 0.241792	TPR_FF: 90.18	TNR_FF: 95.80
# ValLoss_HS: 0.172455	TPR_HS: 94.82	TNR_HS: 96.67
# ValLossALL: 0.196722	TPRALL: 94.82	TNRALL: 96.40
# Time: 5.19
# EarlyStopping counter: 17 out of 20
#
#
# Epoch: 33
# Loss_MF: 0.180625	TPR_MF: 94.90	TNR_MF: 96.25
# Loss_FF: 0.253310	TPR_FF: 93.62	TNR_FF: 95.55
# Loss_HS: 0.177635	TPR_HS: 96.46	TNR_HS: 96.58
# LossALL: 0.204262	TPRALL: 95.35	TNRALL: 96.23
# Time: 117.46
#
# Epoch:33
# ValLoss_MF: 0.159737	TPR_MF: 95.89	TNR_MF: 96.54
# ValLoss_FF: 0.217752	TPR_FF: 92.83	TNR_FF: 96.24
# ValLoss_HS: 0.154936	TPR_HS: 96.13	TNR_HS: 96.86
# ValLossALL: 0.177475	TPRALL: 95.89	TNRALL: 96.54
# Time: 5.17
# EarlyStopping counter: 18 out of 20
#
#
# Epoch: 34
# Loss_MF: 0.175479	TPR_MF: 96.42	TNR_MF: 96.10
# Loss_FF: 0.260269	TPR_FF: 94.22	TNR_FF: 94.83
# Loss_HS: 0.170827	TPR_HS: 97.02	TNR_HS: 96.61
# LossALL: 0.203187	TPRALL: 96.25	TNRALL: 96.07
# Time: 116.17
#
# Epoch:34
# ValLoss_MF: 0.207471	TPR_MF: 93.59	TNR_MF: 96.45
# ValLoss_FF: 0.236407	TPR_FF: 93.47	TNR_FF: 95.41
# ValLoss_HS: 0.146556	TPR_HS: 96.63	TNR_HS: 97.00
# ValLossALL: 0.196811	TPRALL: 93.59	TNRALL: 96.45
# Time: 5.25
# EarlyStopping counter: 19 out of 20
#
#
# Epoch: 35
# Loss_MF: 0.186495	TPR_MF: 95.45	TNR_MF: 95.89
# Loss_FF: 0.240790	TPR_FF: 94.84	TNR_FF: 95.18
# Loss_HS: 0.183512	TPR_HS: 95.87	TNR_HS: 96.59
# LossALL: 0.203881	TPRALL: 95.38	TNRALL: 96.29
# Time: 117.91
#
# Epoch:35
# ValLoss_MF: 0.162435	TPR_MF: 96.42	TNR_MF: 96.52
# ValLoss_FF: 0.349636	TPR_FF: 82.98	TNR_FF: 95.57
# ValLoss_HS: 0.151915	TPR_HS: 96.23	TNR_HS: 96.75
# ValLossALL: 0.221328	TPRALL: 96.23	TNRALL: 96.52
# Time: 5.34
# EarlyStopping counter: 20 out of 20
#
# Early stopping
